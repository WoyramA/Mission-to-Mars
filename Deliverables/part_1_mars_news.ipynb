# %% [markdown]
# # Module 12 Challenge
# ## Deliverable 1: Scrape Titles and Preview Text from Mars News

# %%
# Import Splinter and BeautifulSoup
from splinter import Browser
from bs4 import BeautifulSoup as soup
from webdriver_manager.chrome import ChromeDriverManager

# %%
executable_path = {'executable_path': ChromeDriverManager().install()}
browser = Browser('chrome', **executable_path, headless=False)

# %% [markdown]
# ### Step 1: Visit the Website
#
# 1. Use automated browsing to visit the [Mars NASA news site](https://redplanetscience.com). Inspect the page to identify which elements to scrape.
#
#       > **Hint** To identify which elements to scrape, you might want to inspect the page by using Chrome DevTools.

# %%
# Visit the Mars NASA news site: https://redplanetscience.com
url = 'https://redplanetscience.com'
browser.visit(url)

# %% [markdown]
# ### Step 2: Scrape the Website
#
# Create a Beautiful Soup object and use it to extract text elements from the website.

# %%
# Create a Beautiful Soup object
# Set up HTML parser
html = browser.html
html_soup = soup(html, 'html.parser')

# %%
# Extract all the text elements
for text in html_soup.find_all(text=True):
    print(text)
# Out:
# News - Mars Exploration Program
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# MARS Planet Science
#
#
# Exploration Program
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# The Red Planet
#
#
#
#
#
#
# The Program
#
#
#
#
#
#
# News & Events
#
#
#
#
#
#
# Multimedia
#
#
#
#
#
#
# Missions
#
#
#
#
#
#
# More
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# News
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Latest
#
#
# 2020
# 2019
#
#
#
#
#
#
#
#
# All Categories
#
#
# Feature Stories
# Press Releases
# Status Reports
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# March 7, 2023
#
#
# MAVEN Maps Electric Currents around Mars that are Fundamental to Atmospheric Loss
#
#
# Five years after NASA’s MAVEN spacecraft entered into orbit around Mars, data from the mission has led to the creation of a map of electric current systems in the Martian atmosphere.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# March 6, 2023
#
#
# NASA's Curiosity Keeps Rolling As Team Operates Rover From Home
#
#
# The team has learned to meet new challenges as they work remotely on the Mars mission.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# March 1, 2023
#
#
# AI Is Helping Scientists Discover Fresh Craters on Mars
#
#
# It's the first time machine learning has been used to find previously unknown craters on the Red Planet.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# February 26, 2023
#
#
# Scientists Explore Outback as Testbed for Mars
#
#
# Australia provides a great place for NASA's Mars 2020 and the ESA-Roscosmos ExoMars scientists to hone techniques in preparation for searching for signs ancient life on Mars.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# February 25, 2023
#
#
# What's Mars Solar Conjunction, and Why Does It Matter?
#
#
# NASA spacecraft at Mars are going to be on their own for a few weeks when the Sun comes between Mars and Earth, interrupting communications.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# February 24, 2023
#
#
# NASA's Mars Perseverance Rover Gets Its Sample Handling System
#
#
# The system will be collecting and storing Martian rock and soil. Its installation marks another milestone in the march toward the July launch period.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# February 24, 2023
#
#
# NASA's Perseverance Rover Is Midway to Mars
#
#
# Sometimes half measures can be a good thing – especially on a journey this long. The agency's latest rover only has about 146 million miles left to reach its destination.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# February 22, 2023
#
#
# How NASA's Perseverance Mars Team Adjusted to Work in the Time of Coronavirus
#
#
# Like much of the rest of the world, the Mars rover team is pushing forward with its mission-critical work while putting the health and safety of their colleagues and community first.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# February 20, 2023
#
#
# NASA's Perseverance Rover Goes Through Trials by Fire, Ice, Light and Sound
#
#
# The agency's new Mars rover is put through a series of tests in vacuum chambers, acoustic chambers and more to get ready for the Red Planet.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# February 19, 2023
#
#
# NASA Adds Return Sample Scientists to Mars 2020 Leadership Team
#
#
# The leadership council for Mars 2020 science added two new members who represent the interests of scientists destined to handle and study the first samples from Red Planet.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# February 18, 2023
#
#
# Virginia Middle School Student Earns Honor of Naming NASA's Next Mars Rover
#
#
# NASA chose a seventh-grader from Virginia as winner of the agency's "Name the Rover" essay contest. Alexander Mather's entry for "Perseverance" was voted tops among 28,000 entries.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# February 15, 2023
#
#
# New Selfie Shows Curiosity, the Mars Chemist
#
#
# The NASA rover performed a special chemistry experiment at the location captured in its newest self-portrait.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# February 13, 2023
#
#
# NASA's Mars 2020 Rover Completes Its First Drive
#
#
# In a 10-plus-hour marathon, the rover steered, turned and drove in 3-foot (1-meter) increments over small ramps.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# February 8, 2023
#
#
# NASA Administrator Statement on Moon to Mars Initiative, FY 2021 Budget
#
#
# Jim Bridenstine addresses NASA's ambitious plans for the coming years, including Mars Sample Return.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# February 8, 2023
#
#
# Heat and Dust Help Launch Martian Water Into Space, Scientists Find
#
#
# Scientists using an instrument aboard NASA’s Mars Atmosphere and Volatile EvolutioN, or MAVEN, spacecraft have discovered that water vapor near the surface of the Red Planet is lofted higher into the atmosphere than anyone expected was possible.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# More
#
#
#
#
#
#
#
#
#
#
#
#
# You Might Also Like
#
#
#
#
#   <a class=" prev" href="#carouselExampleIndicators2" role="button" data-slide="prev">
#                   <i class="fas fa-angle-left"></i>
#                   </a>
#                   <a class=" next" href="#carouselExampleIndicators2" role="button" data-slide="next">
#                   <i class="fas fa-angle-right"></i>
#                   </a>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# NASA to Broadcast Mars 2020 Perseverance Launch, Prelaunch Activities
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# The Launch Is Approaching for NASA's Next Mars Rover, Perseverance
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# NASA to Hold Mars 2020 Perseverance Rover Launch Briefing
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# With supporting text below as a natural lead-in to additional content.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# With supporting text below as a natural lead-in to additional content.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# With supporting text below as a natural lead-in to additional content.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# With supporting text below as a natural lead-in to additional content.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# With supporting text below as a natural lead-in to additional content.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# With supporting text below as a natural lead-in to additional content.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# The Red Planet
#
#
#
#
# Dashboard
#
#
# Science Goals
#
#
# The Planet
#
#
#
#
#
#
#
#
# The Program
#
#
#
#
# Mission Statement
#
#
# About the Program
#
#
# Organization Why Mars?
#
#
#
#
#
#
#
#
# Multimedia
#
#
#
#
# Images
#
#
# Videos
#
#
# More Resources
#
#
#
#
#
#
#
#
# Missions
#
#
#
#
# Past
#
#
# Present
#
#
# Future

# %% [markdown]
# ### Step 3: Store the Results
#
# Extract the titles and preview text of the news articles that you scraped. Store the scraping results in Python data structures as follows:
#
# * Store each title-and-preview pair in a Python dictionary. And, give each dictionary two keys: `title` and `preview`. An example is the following:
#
#   ```python
#   {'title': "Mars Rover Begins Mission!",
#         'preview': "NASA's Mars Rover begins a multiyear mission to collect data about the little-explored planet."}
#   ```
#
# * Store all the dictionaries in a Python list.
#
# * Print the list in your notebook.

# %%
div = html_soup.find_all("div")
print(div)
# Out:
# [<div class="col-md-12">
# <div class="row">
# <nav class="navbar navbar-expand-lg navbar-light fixed-top">
# <div class="container-fluid">
# <a class="navbar-brand" href="#">
# <img src="image/nasa.png" width="80"/><span class="logo">MARS Planet Science</span>
# <span class="logo1">Exploration Program</span>
# </a>
# <button aria-controls="navbarNav" aria-expanded="false" aria-label="Toggle navigation" class="navbar-toggler" data-bs-target="#navbarNav" data-bs-toggle="collapse" type="button">
# <span class="navbar-toggler-icon"></span>
# </button>
# <div class="collapse navbar-collapse justify-content-end" id="navbarNav">
# <ul class="navbar-nav">
# <li class="nav-item">
# <a aria-current="page" class="nav-link active" href="#">The Red Planet</a>
# </li>
# <li class="nav-item">
# <a class="nav-link" href="#">The Program</a>
# </li>
# <li class="nav-item">
# <a class="nav-link" href="#">News &amp; Events</a>
# </li>
# <li class="nav-item">
# <a class="nav-link" href="#">Multimedia</a>
# </li>
# <li class="nav-item">
# <a class="nav-link" href="#">Missions</a>
# </li>
# <li class="nav-item">
# <a class="nav-link" href="#">More</a>
# </li>
# <li class="nav-item nav_search">
# <a class="nav-link" href="#"></a>
# </li>
# </ul>
# </div>
# </div>
# </nav>
# <section class="search">
# <div class="container">
# <h1>News</h1>
# <div class="col-md-12 filter">
# <div class="row">
# <div class="col-md-3 search_binder">
# <input class="search_field" name="search" type="text"/>
# <input class="search_submit" name="search" type="text"/>
# </div>
# <div class="col-md-3">
# <select aria-label="Default select example" class="form-select" id="year">
# <option selected="">Latest</option>
# <option>2020</option><option>2019</option></select>
# </div>
# <div class="col-md-3">
# <select aria-label="Default select example" class="form-select" id="cat">
# <option selected="">All Categories</option>
# <option>Feature Stories</option><option>Press Releases</option><option>Status Reports</option></select>
# </div>
# <div class="col-md-3">
# </div>
# </div>
# </div>
# </div>
# </section>
# <section class="image_and_description_container">
# <div class="container" id="news">
# <div class="col-md-12">
# <hr/>
# <div class="row">
# <div class="col-md-4">
# <div class="list_image">
# <img src="https://mars.nasa.gov/system/news_items/list_view_images/8680_mavenmarselectriccurrents-320x240.jpg"/>
# </div>
# </div>
# <div class="col-md-8">
# <div class="list_text">
# <div class="list_date">March 7, 2023</div>
# <div class="content_title">MAVEN Maps Electric Currents around Mars that are Fundamental to Atmospheric Loss</div>
# <div class="article_teaser_body">Five years after NASA’s MAVEN spacecraft entered into orbit around Mars, data from the mission has led to the creation of a map of electric current systems in the Martian atmosphere.</div>
# </div>
# </div>
# </div>
# </div>
# <div class="col-md-12">
# <hr/>
# <div class="row">
# <div class="col-md-4">
# <div class="list_image">
# <img src="https://mars.nasa.gov/system/news_items/list_view_images/8647_PIA23773-32x24.jpg"/>
# </div>
# </div>
# <div class="col-md-8">
# <div class="list_text">
# <div class="list_date">March 6, 2023</div>
# <div class="content_title">NASA's Curiosity Keeps Rolling As Team Operates Rover From Home</div>
# <div class="article_teaser_body">The team has learned to meet new challenges as they work remotely on the Mars mission.</div>
# </div>
# </div>
# </div>
# </div>
# <div class="col-md-12">
# <hr/>
# <div class="row">
# <div class="col-md-4">
# <div class="list_image">
# <img src="https://mars.nasa.gov/system/news_items/list_view_images/8765_PIA24040-320.jpg"/>
# </div>
# </div>
# <div class="col-md-8">
# <div class="list_text">
# <div class="list_date">March 1, 2023</div>
# <div class="content_title">AI Is Helping Scientists Discover Fresh Craters on Mars</div>
# <div class="article_teaser_body">It's the first time machine learning has been used to find previously unknown craters on the Red Planet.</div>
# </div>
# </div>
# </div>
# </div>
# <div class="col-md-12">
# <hr/>
# <div class="row">
# <div class="col-md-4">
# <div class="list_image">
# <img src="https://mars.nasa.gov/system/news_items/list_view_images/8505_PIA23275-th.jpg"/>
# </div>
# </div>
# <div class="col-md-8">
# <div class="list_text">
# <div class="list_date">February 26, 2023</div>
# <div class="content_title">Scientists Explore Outback as Testbed for Mars </div>
# <div class="article_teaser_body">Australia provides a great place for NASA's Mars 2020 and the ESA-Roscosmos ExoMars scientists to hone techniques in preparation for searching for signs ancient life on Mars.</div>
# </div>
# </div>
# </div>
# </div>
# <div class="col-md-12">
# <hr/>
# <div class="row">
# <div class="col-md-4">
# <div class="list_image">
# <img src="https://mars.nasa.gov/system/news_items/list_view_images/8506_mars-solar-conjunction-th.jpg"/>
# </div>
# </div>
# <div class="col-md-8">
# <div class="list_text">
# <div class="list_date">February 25, 2023</div>
# <div class="content_title">What's Mars Solar Conjunction, and Why Does It Matter?</div>
# <div class="article_teaser_body">NASA spacecraft at Mars are going to be on their own for a few weeks when the Sun comes between Mars and Earth, interrupting communications.</div>
# </div>
# </div>
# </div>
# </div>
# <div class="col-md-12">
# <hr/>
# <div class="row">
# <div class="col-md-4">
# <div class="list_image">
# <img src="https://mars.nasa.gov/system/news_items/list_view_images/8630_PIA23768-320x240.jpg"/>
# </div>
# </div>
# <div class="col-md-8">
# <div class="list_text">
# <div class="list_date">February 24, 2023</div>
# <div class="content_title">NASA's Mars Perseverance Rover Gets Its Sample Handling System</div>
# <div class="article_teaser_body">The system will be collecting and storing Martian rock and soil. Its installation marks another milestone in the march toward the July launch period.</div>
# </div>
# </div>
# </div>
# </div>
# <div class="col-md-12">
# <hr/>
# <div class="row">
# <div class="col-md-4">
# <div class="list_image">
# <img src="https://mars.nasa.gov/system/news_items/list_view_images/8785_PIA24231-320.jpg"/>
# </div>
# </div>
# <div class="col-md-8">
# <div class="list_text">
# <div class="list_date">February 24, 2023</div>
# <div class="content_title">NASA's Perseverance Rover Is Midway to Mars </div>
# <div class="article_teaser_body">Sometimes half measures can be a good thing – especially on a journey this long. The agency's latest rover only has about 146 million miles left to reach its destination.</div>
# </div>
# </div>
# </div>
# </div>
# <div class="col-md-12">
# <hr/>
# <div class="row">
# <div class="col-md-4">
# <div class="list_image">
# <img src="https://mars.nasa.gov/system/news_items/list_view_images/8654_MAIN-IMAGE-PIA23881-320x240.jpg"/>
# </div>
# </div>
# <div class="col-md-8">
# <div class="list_text">
# <div class="list_date">February 22, 2023</div>
# <div class="content_title">How NASA's Perseverance Mars Team Adjusted to Work in the Time of Coronavirus </div>
# <div class="article_teaser_body">Like much of the rest of the world, the Mars rover team is pushing forward with its mission-critical work while putting the health and safety of their colleagues and community first.</div>
# </div>
# </div>
# </div>
# </div>
# <div class="col-md-12">
# <hr/>
# <div class="row">
# <div class="col-md-4">
# <div class="list_image">
# <img src="https://mars.nasa.gov/system/news_items/list_view_images/8671_PIA23890-320.jpg"/>
# </div>
# </div>
# <div class="col-md-8">
# <div class="list_text">
# <div class="list_date">February 20, 2023</div>
# <div class="content_title">NASA's Perseverance Rover Goes Through Trials by Fire, Ice, Light and Sound</div>
# <div class="article_teaser_body">The agency's new Mars rover is put through a series of tests in vacuum chambers, acoustic chambers and more to get ready for the Red Planet.</div>
# </div>
# </div>
# </div>
# </div>
# <div class="col-md-12">
# <hr/>
# <div class="row">
# <div class="col-md-4">
# <div class="list_image">
# <img src="https://mars.nasa.gov/system/news_items/list_view_images/8611_PIA22111-320x240.jpg"/>
# </div>
# </div>
# <div class="col-md-8">
# <div class="list_text">
# <div class="list_date">February 19, 2023</div>
# <div class="content_title">NASA Adds Return Sample Scientists to Mars 2020 Leadership Team</div>
# <div class="article_teaser_body">The leadership council for Mars 2020 science added two new members who represent the interests of scientists destined to handle and study the first samples from Red Planet.</div>
# </div>
# </div>
# </div>
# </div>
# <div class="col-md-12">
# <hr/>
# <div class="row">
# <div class="col-md-4">
# <div class="list_image">
# <img src="https://mars.nasa.gov/system/news_items/list_view_images/8622_1-PIA23764-RoverNamePlateonMars-320x240.jpg"/>
# </div>
# </div>
# <div class="col-md-8">
# <div class="list_text">
# <div class="list_date">February 18, 2023</div>
# <div class="content_title">Virginia Middle School Student Earns Honor of Naming NASA's Next Mars Rover</div>
# <div class="article_teaser_body">NASA chose a seventh-grader from Virginia as winner of the agency's "Name the Rover" essay contest. Alexander Mather's entry for "Perseverance" was voted tops among 28,000 entries. </div>
# </div>
# </div>
# </div>
# </div>
# <div class="col-md-12">
# <hr/>
# <div class="row">
# <div class="col-md-4">
# <div class="list_image">
# <img src="https://mars.nasa.gov/system/news_items/list_view_images/8536_Mars_chemist_320x240px.jpg"/>
# </div>
# </div>
# <div class="col-md-8">
# <div class="list_text">
# <div class="list_date">February 15, 2023</div>
# <div class="content_title">New Selfie Shows Curiosity, the Mars Chemist</div>
# <div class="article_teaser_body">The NASA rover performed a special chemistry experiment at the location captured in its newest self-portrait.</div>
# </div>
# </div>
# </div>
# </div>
# <div class="col-md-12">
# <hr/>
# <div class="row">
# <div class="col-md-4">
# <div class="list_image">
# <img src="https://mars.nasa.gov/system/news_items/list_view_images/8573_PIA23499-226.jpg"/>
# </div>
# </div>
# <div class="col-md-8">
# <div class="list_text">
# <div class="list_date">February 13, 2023</div>
# <div class="content_title">NASA's Mars 2020 Rover Completes Its First Drive</div>
# <div class="article_teaser_body">In a 10-plus-hour marathon, the rover steered, turned and drove in 3-foot (1-meter) increments over small ramps.</div>
# </div>
# </div>
# </div>
# </div>
# <div class="col-md-12">
# <hr/>
# <div class="row">
# <div class="col-md-4">
# <div class="list_image">
# <img src="https://mars.nasa.gov/system/news_items/list_view_images/8603_list_image.jpg"/>
# </div>
# </div>
# <div class="col-md-8">
# <div class="list_text">
# <div class="list_date">February 8, 2023</div>
# <div class="content_title">NASA Administrator Statement on Moon to Mars Initiative, FY 2021 Budget</div>
# <div class="article_teaser_body">Jim Bridenstine addresses NASA's ambitious plans for the coming years, including Mars Sample Return.</div>
# </div>
# </div>
# </div>
# </div>
# <div class="col-md-12">
# <hr/>
# <div class="row">
# <div class="col-md-4">
# <div class="list_image">
# <img src="https://mars.nasa.gov/system/news_items/list_view_images/8797_maven_illo_v7-320.jpg"/>
# </div>
# </div>
# <div class="col-md-8">
# <div class="list_text">
# <div class="list_date">February 8, 2023</div>
# <div class="content_title">Heat and Dust Help Launch Martian Water Into Space, Scientists Find</div>
# <div class="article_teaser_body">Scientists using an instrument aboard NASA’s Mars Atmosphere and Volatile EvolutioN, or MAVEN, spacecraft have discovered that water vapor near the surface of the Red Planet is lofted higher into the atmosphere than anyone expected was possible. </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <hr class="container" style="margin: 25px auto;width: 83%;"/>
# <button class="btn disable" id="more" onclick="populateContent()">More</button>
# </section>
# <section class="last_news">
# <div class="container">
# <div class="row">
# <div class="col-12">
# <h2>You Might Also Like</h2>
# </div>
# <!--  <a class=" prev" href="#carouselExampleIndicators2" role="button" data-slide="prev">
#                   <i class="fas fa-angle-left"></i>
#                   </a>
#                   <a class=" next" href="#carouselExampleIndicators2" role="button" data-slide="next">
#                   <i class="fas fa-angle-right"></i>
#                   </a> -->
# <div class="col-12">
# <div class="carousel slide" data-ride="carousel" id="carouselExampleIndicators2">
# <div class="carousel-inner">
# <div class="carousel-item active">
# <div class="row">
# <div class="col-md-4 mb-3">
# <div class="card">
# <img alt="100%x280" class="img-fluid" src="https://mars.nasa.gov/system/news_items/main_images/8716_PIA23499-16.jpg"/>
# <div class="card-body">
# <p class="card-text">NASA to Broadcast Mars 2020 Perseverance Launch, Prelaunch Activities</p>
# </div>
# </div>
# </div>
# <div class="col-md-4 mb-3">
# <div class="card">
# <img alt="100%x280" class="img-fluid" src="https://mars.nasa.gov/system/news_items/main_images/8716_PIA23499-16.jpg"/>
# <div class="card-body">
# <p class="card-text">The Launch Is Approaching for NASA's Next Mars Rover, Perseverance</p>
# </div>
# </div>
# </div>
# <div class="col-md-4 mb-3">
# <div class="card">
# <img alt="100%x280" class="img-fluid" src="https://mars.nasa.gov/system/news_items/main_images/8692_PIA23920-web.jpg"/>
# <div class="card-body">
# <p class="card-text">NASA to Hold Mars 2020 Perseverance Rover Launch Briefing</p>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="carousel-item">
# <div class="row">
# <div class="col-md-4 mb-3">
# <div class="card">
# <img alt="100%x280" class="img-fluid" src="https://images.unsplash.com/photo-1532771098148-525cefe10c23?ixlib=rb-0.3.5&amp;q=80&amp;fm=jpg&amp;crop=entropy&amp;cs=tinysrgb&amp;w=1080&amp;fit=max&amp;ixid=eyJhcHBfaWQiOjMyMDc0fQ&amp;s=3f317c1f7a16116dec454fbc267dd8e4"/>
# <div class="card-body">
# <p class="card-text">With supporting text below as a natural lead-in to additional content.</p>
# </div>
# </div>
# </div>
# <div class="col-md-4 mb-3">
# <div class="card">
# <img alt="100%x280" class="img-fluid" src="https://images.unsplash.com/photo-1532715088550-62f09305f765?ixlib=rb-0.3.5&amp;q=80&amp;fm=jpg&amp;crop=entropy&amp;cs=tinysrgb&amp;w=1080&amp;fit=max&amp;ixid=eyJhcHBfaWQiOjMyMDc0fQ&amp;s=ebadb044b374504ef8e81bdec4d0e840"/>
# <div class="card-body">
# <p class="card-text">With supporting text below as a natural lead-in to additional content.</p>
# </div>
# </div>
# </div>
# <div class="col-md-4 mb-3">
# <div class="card">
# <img alt="100%x280" class="img-fluid" src="https://images.unsplash.com/photo-1506197603052-3cc9c3a201bd?ixlib=rb-0.3.5&amp;q=80&amp;fm=jpg&amp;crop=entropy&amp;cs=tinysrgb&amp;w=1080&amp;fit=max&amp;ixid=eyJhcHBfaWQiOjMyMDc0fQ&amp;s=0754ab085804ae8a3b562548e6b4aa2e"/>
# <div class="card-body">
# <p class="card-text">With supporting text below as a natural lead-in to additional content.</p>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="carousel-item">
# <div class="row">
# <div class="col-md-4 mb-3">
# <div class="card">
# <img alt="100%x280" class="img-fluid" src="https://images.unsplash.com/photo-1507525428034-b723cf961d3e?ixlib=rb-0.3.5&amp;q=80&amp;fm=jpg&amp;crop=entropy&amp;cs=tinysrgb&amp;w=1080&amp;fit=max&amp;ixid=eyJhcHBfaWQiOjMyMDc0fQ&amp;s=ee8417f0ea2a50d53a12665820b54e23"/>
# <div class="card-body">
# <p class="card-text">With supporting text below as a natural lead-in to additional content.</p>
# </div>
# </div>
# </div>
# <div class="col-md-4 mb-3">
# <div class="card">
# <img alt="100%x280" class="img-fluid" src="https://images.unsplash.com/photo-1532777946373-b6783242f211?ixlib=rb-0.3.5&amp;q=80&amp;fm=jpg&amp;crop=entropy&amp;cs=tinysrgb&amp;w=1080&amp;fit=max&amp;ixid=eyJhcHBfaWQiOjMyMDc0fQ&amp;s=8ac55cf3a68785643998730839663129"/>
# <div class="card-body">
# <p class="card-text">With supporting text below as a natural lead-in to additional content.</p>
# </div>
# </div>
# </div>
# <div class="col-md-4 mb-3">
# <div class="card">
# <img alt="100%x280" class="img-fluid" src="https://images.unsplash.com/photo-1532763303805-529d595877c5?ixlib=rb-0.3.5&amp;q=80&amp;fm=jpg&amp;crop=entropy&amp;cs=tinysrgb&amp;w=1080&amp;fit=max&amp;ixid=eyJhcHBfaWQiOjMyMDc0fQ&amp;s=5ee4fd5d19b40f93eadb21871757eda6"/>
# <div class="card-body">
# <p class="card-text">With supporting text below as a natural lead-in to additional content.</p>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </section>
# <section class="footer">
# <div class="container">
# <div class="col-md-12">
# <div class="row">
# <div class="col-md-3">
# <h5>The Red Planet</h5>
# <ul>
# <li>Dashboard</li>
# <li>Science Goals</li>
# <li>The Planet</li>
# </ul>
# </div>
# <div class="col-md-3">
# <h5>The Program</h5>
# <ul>
# <li>Mission Statement</li>
# <li>About the Program</li>
# <li>Organization Why Mars?</li>
# </ul>
# </div>
# <div class="col-md-3">
# <h5>Multimedia</h5>
# <ul>
# <li>Images</li>
# <li>Videos</li>
# <li>More Resources</li>
# </ul>
# </div>
# <div class="col-md-3">
# <h5>Missions</h5>
# <ul>
# <li>Past</li>
# <li>Present</li>
# <li>Future</li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </section>
# <script src="https://code.jquery.com/jquery-1.12.4.min.js" type="text/javascript"></script>
# <script src="https://cdn.jsdelivr.net/npm/@popperjs/core@2.5.4/dist/umd/popper.min.js"></script>
# <script src="https://cdn.jsdelivr.net/npm/bootstrap@5.0.0-beta1/dist/js/bootstrap.min.js"></script>
# <script src="js/app.js"></script>
# </div></div>, <div class="row">
# <nav class="navbar navbar-expand-lg navbar-light fixed-top">
# <div class="container-fluid">
# <a class="navbar-brand" href="#">
# <img src="image/nasa.png" width="80"/><span class="logo">MARS Planet Science</span>
# <span class="logo1">Exploration Program</span>
# </a>
# <button aria-controls="navbarNav" aria-expanded="false" aria-label="Toggle navigation" class="navbar-toggler" data-bs-target="#navbarNav" data-bs-toggle="collapse" type="button">
# <span class="navbar-toggler-icon"></span>
# </button>
# <div class="collapse navbar-collapse justify-content-end" id="navbarNav">
# <ul class="navbar-nav">
# <li class="nav-item">
# <a aria-current="page" class="nav-link active" href="#">The Red Planet</a>
# </li>
# <li class="nav-item">
# <a class="nav-link" href="#">The Program</a>
# </li>
# <li class="nav-item">
# <a class="nav-link" href="#">News &amp; Events</a>
# </li>
# <li class="nav-item">
# <a class="nav-link" href="#">Multimedia</a>
# </li>
# <li class="nav-item">
# <a class="nav-link" href="#">Missions</a>
# </li>
# <li class="nav-item">
# <a class="nav-link" href="#">More</a>
# </li>
# <li class="nav-item nav_search">
# <a class="nav-link" href="#"></a>
# </li>
# </ul>
# </div>
# </div>
# </nav>
# <section class="search">
# <div class="container">
# <h1>News</h1>
# <div class="col-md-12 filter">
# <div class="row">
# <div class="col-md-3 search_binder">
# <input class="search_field" name="search" type="text"/>
# <input class="search_submit" name="search" type="text"/>
# </div>
# <div class="col-md-3">
# <select aria-label="Default select example" class="form-select" id="year">
# <option selected="">Latest</option>
# <option>2020</option><option>2019</option></select>
# </div>
# <div class="col-md-3">
# <select aria-label="Default select example" class="form-select" id="cat">
# <option selected="">All Categories</option>
# <option>Feature Stories</option><option>Press Releases</option><option>Status Reports</option></select>
# </div>
# <div class="col-md-3">
# </div>
# </div>
# </div>
# </div>
# </section>
# <section class="image_and_description_container">
# <div class="container" id="news">
# <div class="col-md-12">
# <hr/>
# <div class="row">
# <div class="col-md-4">
# <div class="list_image">
# <img src="https://mars.nasa.gov/system/news_items/list_view_images/8680_mavenmarselectriccurrents-320x240.jpg"/>
# </div>
# </div>
# <div class="col-md-8">
# <div class="list_text">
# <div class="list_date">March 7, 2023</div>
# <div class="content_title">MAVEN Maps Electric Currents around Mars that are Fundamental to Atmospheric Loss</div>
# <div class="article_teaser_body">Five years after NASA’s MAVEN spacecraft entered into orbit around Mars, data from the mission has led to the creation of a map of electric current systems in the Martian atmosphere.</div>
# </div>
# </div>
# </div>
# </div>
# <div class="col-md-12">
# <hr/>
# <div class="row">
# <div class="col-md-4">
# <div class="list_image">
# <img src="https://mars.nasa.gov/system/news_items/list_view_images/8647_PIA23773-32x24.jpg"/>
# </div>
# </div>
# <div class="col-md-8">
# <div class="list_text">
# <div class="list_date">March 6, 2023</div>
# <div class="content_title">NASA's Curiosity Keeps Rolling As Team Operates Rover From Home</div>
# <div class="article_teaser_body">The team has learned to meet new challenges as they work remotely on the Mars mission.</div>
# </div>
# </div>
# </div>
# </div>
# <div class="col-md-12">
# <hr/>
# <div class="row">
# <div class="col-md-4">
# <div class="list_image">
# <img src="https://mars.nasa.gov/system/news_items/list_view_images/8765_PIA24040-320.jpg"/>
# </div>
# </div>
# <div class="col-md-8">
# <div class="list_text">
# <div class="list_date">March 1, 2023</div>
# <div class="content_title">AI Is Helping Scientists Discover Fresh Craters on Mars</div>
# <div class="article_teaser_body">It's the first time machine learning has been used to find previously unknown craters on the Red Planet.</div>
# </div>
# </div>
# </div>
# </div>
# <div class="col-md-12">
# <hr/>
# <div class="row">
# <div class="col-md-4">
# <div class="list_image">
# <img src="https://mars.nasa.gov/system/news_items/list_view_images/8505_PIA23275-th.jpg"/>
# </div>
# </div>
# <div class="col-md-8">
# <div class="list_text">
# <div class="list_date">February 26, 2023</div>
# <div class="content_title">Scientists Explore Outback as Testbed for Mars </div>
# <div class="article_teaser_body">Australia provides a great place for NASA's Mars 2020 and the ESA-Roscosmos ExoMars scientists to hone techniques in preparation for searching for signs ancient life on Mars.</div>
# </div>
# </div>
# </div>
# </div>
# <div class="col-md-12">
# <hr/>
# <div class="row">
# <div class="col-md-4">
# <div class="list_image">
# <img src="https://mars.nasa.gov/system/news_items/list_view_images/8506_mars-solar-conjunction-th.jpg"/>
# </div>
# </div>
# <div class="col-md-8">
# <div class="list_text">
# <div class="list_date">February 25, 2023</div>
# <div class="content_title">What's Mars Solar Conjunction, and Why Does It Matter?</div>
# <div class="article_teaser_body">NASA spacecraft at Mars are going to be on their own for a few weeks when the Sun comes between Mars and Earth, interrupting communications.</div>
# </div>
# </div>
# </div>
# </div>
# <div class="col-md-12">
# <hr/>
# <div class="row">
# <div class="col-md-4">
# <div class="list_image">
# <img src="https://mars.nasa.gov/system/news_items/list_view_images/8630_PIA23768-320x240.jpg"/>
# </div>
# </div>
# <div class="col-md-8">
# <div class="list_text">
# <div class="list_date">February 24, 2023</div>
# <div class="content_title">NASA's Mars Perseverance Rover Gets Its Sample Handling System</div>
# <div class="article_teaser_body">The system will be collecting and storing Martian rock and soil. Its installation marks another milestone in the march toward the July launch period.</div>
# </div>
# </div>
# </div>
# </div>
# <div class="col-md-12">
# <hr/>
# <div class="row">
# <div class="col-md-4">
# <div class="list_image">
# <img src="https://mars.nasa.gov/system/news_items/list_view_images/8785_PIA24231-320.jpg"/>
# </div>
# </div>
# <div class="col-md-8">
# <div class="list_text">
# <div class="list_date">February 24, 2023</div>
# <div class="content_title">NASA's Perseverance Rover Is Midway to Mars </div>
# <div class="article_teaser_body">Sometimes half measures can be a good thing – especially on a journey this long. The agency's latest rover only has about 146 million miles left to reach its destination.</div>
# </div>
# </div>
# </div>
# </div>
# <div class="col-md-12">
# <hr/>
# <div class="row">
# <div class="col-md-4">
# <div class="list_image">
# <img src="https://mars.nasa.gov/system/news_items/list_view_images/8654_MAIN-IMAGE-PIA23881-320x240.jpg"/>
# </div>
# </div>
# <div class="col-md-8">
# <div class="list_text">
# <div class="list_date">February 22, 2023</div>
# <div class="content_title">How NASA's Perseverance Mars Team Adjusted to Work in the Time of Coronavirus </div>
# <div class="article_teaser_body">Like much of the rest of the world, the Mars rover team is pushing forward with its mission-critical work while putting the health and safety of their colleagues and community first.</div>
# </div>
# </div>
# </div>
# </div>
# <div class="col-md-12">
# <hr/>
# <div class="row">
# <div class="col-md-4">
# <div class="list_image">
# <img src="https://mars.nasa.gov/system/news_items/list_view_images/8671_PIA23890-320.jpg"/>
# </div>
# </div>
# <div class="col-md-8">
# <div class="list_text">
# <div class="list_date">February 20, 2023</div>
# <div class="content_title">NASA's Perseverance Rover Goes Through Trials by Fire, Ice, Light and Sound</div>
# <div class="article_teaser_body">The agency's new Mars rover is put through a series of tests in vacuum chambers, acoustic chambers and more to get ready for the Red Planet.</div>
# </div>
# </div>
# </div>
# </div>
# <div class="col-md-12">
# <hr/>
# <div class="row">
# <div class="col-md-4">
# <div class="list_image">
# <img src="https://mars.nasa.gov/system/news_items/list_view_images/8611_PIA22111-320x240.jpg"/>
# </div>
# </div>
# <div class="col-md-8">
# <div class="list_text">
# <div class="list_date">February 19, 2023</div>
# <div class="content_title">NASA Adds Return Sample Scientists to Mars 2020 Leadership Team</div>
# <div class="article_teaser_body">The leadership council for Mars 2020 science added two new members who represent the interests of scientists destined to handle and study the first samples from Red Planet.</div>
# </div>
# </div>
# </div>
# </div>
# <div class="col-md-12">
# <hr/>
# <div class="row">
# <div class="col-md-4">
# <div class="list_image">
# <img src="https://mars.nasa.gov/system/news_items/list_view_images/8622_1-PIA23764-RoverNamePlateonMars-320x240.jpg"/>
# </div>
# </div>
# <div class="col-md-8">
# <div class="list_text">
# <div class="list_date">February 18, 2023</div>
# <div class="content_title">Virginia Middle School Student Earns Honor of Naming NASA's Next Mars Rover</div>
# <div class="article_teaser_body">NASA chose a seventh-grader from Virginia as winner of the agency's "Name the Rover" essay contest. Alexander Mather's entry for "Perseverance" was voted tops among 28,000 entries. </div>
# </div>
# </div>
# </div>
# </div>
# <div class="col-md-12">
# <hr/>
# <div class="row">
# <div class="col-md-4">
# <div class="list_image">
# <img src="https://mars.nasa.gov/system/news_items/list_view_images/8536_Mars_chemist_320x240px.jpg"/>
# </div>
# </div>
# <div class="col-md-8">
# <div class="list_text">
# <div class="list_date">February 15, 2023</div>
# <div class="content_title">New Selfie Shows Curiosity, the Mars Chemist</div>
# <div class="article_teaser_body">The NASA rover performed a special chemistry experiment at the location captured in its newest self-portrait.</div>
# </div>
# </div>
# </div>
# </div>
# <div class="col-md-12">
# <hr/>
# <div class="row">
# <div class="col-md-4">
# <div class="list_image">
# <img src="https://mars.nasa.gov/system/news_items/list_view_images/8573_PIA23499-226.jpg"/>
# </div>
# </div>
# <div class="col-md-8">
# <div class="list_text">
# <div class="list_date">February 13, 2023</div>
# <div class="content_title">NASA's Mars 2020 Rover Completes Its First Drive</div>
# <div class="article_teaser_body">In a 10-plus-hour marathon, the rover steered, turned and drove in 3-foot (1-meter) increments over small ramps.</div>
# </div>
# </div>
# </div>
# </div>
# <div class="col-md-12">
# <hr/>
# <div class="row">
# <div class="col-md-4">
# <div class="list_image">
# <img src="https://mars.nasa.gov/system/news_items/list_view_images/8603_list_image.jpg"/>
# </div>
# </div>
# <div class="col-md-8">
# <div class="list_text">
# <div class="list_date">February 8, 2023</div>
# <div class="content_title">NASA Administrator Statement on Moon to Mars Initiative, FY 2021 Budget</div>
# <div class="article_teaser_body">Jim Bridenstine addresses NASA's ambitious plans for the coming years, including Mars Sample Return.</div>
# </div>
# </div>
# </div>
# </div>
# <div class="col-md-12">
# <hr/>
# <div class="row">
# <div class="col-md-4">
# <div class="list_image">
# <img src="https://mars.nasa.gov/system/news_items/list_view_images/8797_maven_illo_v7-320.jpg"/>
# </div>
# </div>
# <div class="col-md-8">
# <div class="list_text">
# <div class="list_date">February 8, 2023</div>
# <div class="content_title">Heat and Dust Help Launch Martian Water Into Space, Scientists Find</div>
# <div class="article_teaser_body">Scientists using an instrument aboard NASA’s Mars Atmosphere and Volatile EvolutioN, or MAVEN, spacecraft have discovered that water vapor near the surface of the Red Planet is lofted higher into the atmosphere than anyone expected was possible. </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <hr class="container" style="margin: 25px auto;width: 83%;"/>
# <button class="btn disable" id="more" onclick="populateContent()">More</button>
# </section>
# <section class="last_news">
# <div class="container">
# <div class="row">
# <div class="col-12">
# <h2>You Might Also Like</h2>
# </div>
# <!--  <a class=" prev" href="#carouselExampleIndicators2" role="button" data-slide="prev">
#                   <i class="fas fa-angle-left"></i>
#                   </a>
#                   <a class=" next" href="#carouselExampleIndicators2" role="button" data-slide="next">
#                   <i class="fas fa-angle-right"></i>
#                   </a> -->
# <div class="col-12">
# <div class="carousel slide" data-ride="carousel" id="carouselExampleIndicators2">
# <div class="carousel-inner">
# <div class="carousel-item active">
# <div class="row">
# <div class="col-md-4 mb-3">
# <div class="card">
# <img alt="100%x280" class="img-fluid" src="https://mars.nasa.gov/system/news_items/main_images/8716_PIA23499-16.jpg"/>
# <div class="card-body">
# <p class="card-text">NASA to Broadcast Mars 2020 Perseverance Launch, Prelaunch Activities</p>
# </div>
# </div>
# </div>
# <div class="col-md-4 mb-3">
# <div class="card">
# <img alt="100%x280" class="img-fluid" src="https://mars.nasa.gov/system/news_items/main_images/8716_PIA23499-16.jpg"/>
# <div class="card-body">
# <p class="card-text">The Launch Is Approaching for NASA's Next Mars Rover, Perseverance</p>
# </div>
# </div>
# </div>
# <div class="col-md-4 mb-3">
# <div class="card">
# <img alt="100%x280" class="img-fluid" src="https://mars.nasa.gov/system/news_items/main_images/8692_PIA23920-web.jpg"/>
# <div class="card-body">
# <p class="card-text">NASA to Hold Mars 2020 Perseverance Rover Launch Briefing</p>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="carousel-item">
# <div class="row">
# <div class="col-md-4 mb-3">
# <div class="card">
# <img alt="100%x280" class="img-fluid" src="https://images.unsplash.com/photo-1532771098148-525cefe10c23?ixlib=rb-0.3.5&amp;q=80&amp;fm=jpg&amp;crop=entropy&amp;cs=tinysrgb&amp;w=1080&amp;fit=max&amp;ixid=eyJhcHBfaWQiOjMyMDc0fQ&amp;s=3f317c1f7a16116dec454fbc267dd8e4"/>
# <div class="card-body">
# <p class="card-text">With supporting text below as a natural lead-in to additional content.</p>
# </div>
# </div>
# </div>
# <div class="col-md-4 mb-3">
# <div class="card">
# <img alt="100%x280" class="img-fluid" src="https://images.unsplash.com/photo-1532715088550-62f09305f765?ixlib=rb-0.3.5&amp;q=80&amp;fm=jpg&amp;crop=entropy&amp;cs=tinysrgb&amp;w=1080&amp;fit=max&amp;ixid=eyJhcHBfaWQiOjMyMDc0fQ&amp;s=ebadb044b374504ef8e81bdec4d0e840"/>
# <div class="card-body">
# <p class="card-text">With supporting text below as a natural lead-in to additional content.</p>
# </div>
# </div>
# </div>
# <div class="col-md-4 mb-3">
# <div class="card">
# <img alt="100%x280" class="img-fluid" src="https://images.unsplash.com/photo-1506197603052-3cc9c3a201bd?ixlib=rb-0.3.5&amp;q=80&amp;fm=jpg&amp;crop=entropy&amp;cs=tinysrgb&amp;w=1080&amp;fit=max&amp;ixid=eyJhcHBfaWQiOjMyMDc0fQ&amp;s=0754ab085804ae8a3b562548e6b4aa2e"/>
# <div class="card-body">
# <p class="card-text">With supporting text below as a natural lead-in to additional content.</p>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="carousel-item">
# <div class="row">
# <div class="col-md-4 mb-3">
# <div class="card">
# <img alt="100%x280" class="img-fluid" src="https://images.unsplash.com/photo-1507525428034-b723cf961d3e?ixlib=rb-0.3.5&amp;q=80&amp;fm=jpg&amp;crop=entropy&amp;cs=tinysrgb&amp;w=1080&amp;fit=max&amp;ixid=eyJhcHBfaWQiOjMyMDc0fQ&amp;s=ee8417f0ea2a50d53a12665820b54e23"/>
# <div class="card-body">
# <p class="card-text">With supporting text below as a natural lead-in to additional content.</p>
# </div>
# </div>
# </div>
# <div class="col-md-4 mb-3">
# <div class="card">
# <img alt="100%x280" class="img-fluid" src="https://images.unsplash.com/photo-1532777946373-b6783242f211?ixlib=rb-0.3.5&amp;q=80&amp;fm=jpg&amp;crop=entropy&amp;cs=tinysrgb&amp;w=1080&amp;fit=max&amp;ixid=eyJhcHBfaWQiOjMyMDc0fQ&amp;s=8ac55cf3a68785643998730839663129"/>
# <div class="card-body">
# <p class="card-text">With supporting text below as a natural lead-in to additional content.</p>
# </div>
# </div>
# </div>
# <div class="col-md-4 mb-3">
# <div class="card">
# <img alt="100%x280" class="img-fluid" src="https://images.unsplash.com/photo-1532763303805-529d595877c5?ixlib=rb-0.3.5&amp;q=80&amp;fm=jpg&amp;crop=entropy&amp;cs=tinysrgb&amp;w=1080&amp;fit=max&amp;ixid=eyJhcHBfaWQiOjMyMDc0fQ&amp;s=5ee4fd5d19b40f93eadb21871757eda6"/>
# <div class="card-body">
# <p class="card-text">With supporting text below as a natural lead-in to additional content.</p>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </section>
# <section class="footer">
# <div class="container">
# <div class="col-md-12">
# <div class="row">
# <div class="col-md-3">
# <h5>The Red Planet</h5>
# <ul>
# <li>Dashboard</li>
# <li>Science Goals</li>
# <li>The Planet</li>
# </ul>
# </div>
# <div class="col-md-3">
# <h5>The Program</h5>
# <ul>
# <li>Mission Statement</li>
# <li>About the Program</li>
# <li>Organization Why Mars?</li>
# </ul>
# </div>
# <div class="col-md-3">
# <h5>Multimedia</h5>
# <ul>
# <li>Images</li>
# <li>Videos</li>
# <li>More Resources</li>
# </ul>
# </div>
# <div class="col-md-3">
# <h5>Missions</h5>
# <ul>
# <li>Past</li>
# <li>Present</li>
# <li>Future</li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </section>
# <script src="https://code.jquery.com/jquery-1.12.4.min.js" type="text/javascript"></script>
# <script src="https://cdn.jsdelivr.net/npm/@popperjs/core@2.5.4/dist/umd/popper.min.js"></script>
# <script src="https://cdn.jsdelivr.net/npm/bootstrap@5.0.0-beta1/dist/js/bootstrap.min.js"></script>
# <script src="js/app.js"></script>
# </div>, <div class="container-fluid">
# <a class="navbar-brand" href="#">
# <img src="image/nasa.png" width="80"/><span class="logo">MARS Planet Science</span>
# <span class="logo1">Exploration Program</span>
# </a>
# <button aria-controls="navbarNav" aria-expanded="false" aria-label="Toggle navigation" class="navbar-toggler" data-bs-target="#navbarNav" data-bs-toggle="collapse" type="button">
# <span class="navbar-toggler-icon"></span>
# </button>
# <div class="collapse navbar-collapse justify-content-end" id="navbarNav">
# <ul class="navbar-nav">
# <li class="nav-item">
# <a aria-current="page" class="nav-link active" href="#">The Red Planet</a>
# </li>
# <li class="nav-item">
# <a class="nav-link" href="#">The Program</a>
# </li>
# <li class="nav-item">
# <a class="nav-link" href="#">News &amp; Events</a>
# </li>
# <li class="nav-item">
# <a class="nav-link" href="#">Multimedia</a>
# </li>
# <li class="nav-item">
# <a class="nav-link" href="#">Missions</a>
# </li>
# <li class="nav-item">
# <a class="nav-link" href="#">More</a>
# </li>
# <li class="nav-item nav_search">
# <a class="nav-link" href="#"></a>
# </li>
# </ul>
# </div>
# </div>, <div class="collapse navbar-collapse justify-content-end" id="navbarNav">
# <ul class="navbar-nav">
# <li class="nav-item">
# <a aria-current="page" class="nav-link active" href="#">The Red Planet</a>
# </li>
# <li class="nav-item">
# <a class="nav-link" href="#">The Program</a>
# </li>
# <li class="nav-item">
# <a class="nav-link" href="#">News &amp; Events</a>
# </li>
# <li class="nav-item">
# <a class="nav-link" href="#">Multimedia</a>
# </li>
# <li class="nav-item">
# <a class="nav-link" href="#">Missions</a>
# </li>
# <li class="nav-item">
# <a class="nav-link" href="#">More</a>
# </li>
# <li class="nav-item nav_search">
# <a class="nav-link" href="#"></a>
# </li>
# </ul>
# </div>, <div class="container">
# <h1>News</h1>
# <div class="col-md-12 filter">
# <div class="row">
# <div class="col-md-3 search_binder">
# <input class="search_field" name="search" type="text"/>
# <input class="search_submit" name="search" type="text"/>
# </div>
# <div class="col-md-3">
# <select aria-label="Default select example" class="form-select" id="year">
# <option selected="">Latest</option>
# <option>2020</option><option>2019</option></select>
# </div>
# <div class="col-md-3">
# <select aria-label="Default select example" class="form-select" id="cat">
# <option selected="">All Categories</option>
# <option>Feature Stories</option><option>Press Releases</option><option>Status Reports</option></select>
# </div>
# <div class="col-md-3">
# </div>
# </div>
# </div>
# </div>, <div class="col-md-12 filter">
# <div class="row">
# <div class="col-md-3 search_binder">
# <input class="search_field" name="search" type="text"/>
# <input class="search_submit" name="search" type="text"/>
# </div>
# <div class="col-md-3">
# <select aria-label="Default select example" class="form-select" id="year">
# <option selected="">Latest</option>
# <option>2020</option><option>2019</option></select>
# </div>
# <div class="col-md-3">
# <select aria-label="Default select example" class="form-select" id="cat">
# <option selected="">All Categories</option>
# <option>Feature Stories</option><option>Press Releases</option><option>Status Reports</option></select>
# </div>
# <div class="col-md-3">
# </div>
# </div>
# </div>, <div class="row">
# <div class="col-md-3 search_binder">
# <input class="search_field" name="search" type="text"/>
# <input class="search_submit" name="search" type="text"/>
# </div>
# <div class="col-md-3">
# <select aria-label="Default select example" class="form-select" id="year">
# <option selected="">Latest</option>
# <option>2020</option><option>2019</option></select>
# </div>
# <div class="col-md-3">
# <select aria-label="Default select example" class="form-select" id="cat">
# <option selected="">All Categories</option>
# <option>Feature Stories</option><option>Press Releases</option><option>Status Reports</option></select>
# </div>
# <div class="col-md-3">
# </div>
# </div>, <div class="col-md-3 search_binder">
# <input class="search_field" name="search" type="text"/>
# <input class="search_submit" name="search" type="text"/>
# </div>, <div class="col-md-3">
# <select aria-label="Default select example" class="form-select" id="year">
# <option selected="">Latest</option>
# <option>2020</option><option>2019</option></select>
# </div>, <div class="col-md-3">
# <select aria-label="Default select example" class="form-select" id="cat">
# <option selected="">All Categories</option>
# <option>Feature Stories</option><option>Press Releases</option><option>Status Reports</option></select>
# </div>, <div class="col-md-3">
# </div>, <div class="container" id="news">
# <div class="col-md-12">
# <hr/>
# <div class="row">
# <div class="col-md-4">
# <div class="list_image">
# <img src="https://mars.nasa.gov/system/news_items/list_view_images/8680_mavenmarselectriccurrents-320x240.jpg"/>
# </div>
# </div>
# <div class="col-md-8">
# <div class="list_text">
# <div class="list_date">March 7, 2023</div>
# <div class="content_title">MAVEN Maps Electric Currents around Mars that are Fundamental to Atmospheric Loss</div>
# <div class="article_teaser_body">Five years after NASA’s MAVEN spacecraft entered into orbit around Mars, data from the mission has led to the creation of a map of electric current systems in the Martian atmosphere.</div>
# </div>
# </div>
# </div>
# </div>
# <div class="col-md-12">
# <hr/>
# <div class="row">
# <div class="col-md-4">
# <div class="list_image">
# <img src="https://mars.nasa.gov/system/news_items/list_view_images/8647_PIA23773-32x24.jpg"/>
# </div>
# </div>
# <div class="col-md-8">
# <div class="list_text">
# <div class="list_date">March 6, 2023</div>
# <div class="content_title">NASA's Curiosity Keeps Rolling As Team Operates Rover From Home</div>
# <div class="article_teaser_body">The team has learned to meet new challenges as they work remotely on the Mars mission.</div>
# </div>
# </div>
# </div>
# </div>
# <div class="col-md-12">
# <hr/>
# <div class="row">
# <div class="col-md-4">
# <div class="list_image">
# <img src="https://mars.nasa.gov/system/news_items/list_view_images/8765_PIA24040-320.jpg"/>
# </div>
# </div>
# <div class="col-md-8">
# <div class="list_text">
# <div class="list_date">March 1, 2023</div>
# <div class="content_title">AI Is Helping Scientists Discover Fresh Craters on Mars</div>
# <div class="article_teaser_body">It's the first time machine learning has been used to find previously unknown craters on the Red Planet.</div>
# </div>
# </div>
# </div>
# </div>
# <div class="col-md-12">
# <hr/>
# <div class="row">
# <div class="col-md-4">
# <div class="list_image">
# <img src="https://mars.nasa.gov/system/news_items/list_view_images/8505_PIA23275-th.jpg"/>
# </div>
# </div>
# <div class="col-md-8">
# <div class="list_text">
# <div class="list_date">February 26, 2023</div>
# <div class="content_title">Scientists Explore Outback as Testbed for Mars </div>
# <div class="article_teaser_body">Australia provides a great place for NASA's Mars 2020 and the ESA-Roscosmos ExoMars scientists to hone techniques in preparation for searching for signs ancient life on Mars.</div>
# </div>
# </div>
# </div>
# </div>
# <div class="col-md-12">
# <hr/>
# <div class="row">
# <div class="col-md-4">
# <div class="list_image">
# <img src="https://mars.nasa.gov/system/news_items/list_view_images/8506_mars-solar-conjunction-th.jpg"/>
# </div>
# </div>
# <div class="col-md-8">
# <div class="list_text">
# <div class="list_date">February 25, 2023</div>
# <div class="content_title">What's Mars Solar Conjunction, and Why Does It Matter?</div>
# <div class="article_teaser_body">NASA spacecraft at Mars are going to be on their own for a few weeks when the Sun comes between Mars and Earth, interrupting communications.</div>
# </div>
# </div>
# </div>
# </div>
# <div class="col-md-12">
# <hr/>
# <div class="row">
# <div class="col-md-4">
# <div class="list_image">
# <img src="https://mars.nasa.gov/system/news_items/list_view_images/8630_PIA23768-320x240.jpg"/>
# </div>
# </div>
# <div class="col-md-8">
# <div class="list_text">
# <div class="list_date">February 24, 2023</div>
# <div class="content_title">NASA's Mars Perseverance Rover Gets Its Sample Handling System</div>
# <div class="article_teaser_body">The system will be collecting and storing Martian rock and soil. Its installation marks another milestone in the march toward the July launch period.</div>
# </div>
# </div>
# </div>
# </div>
# <div class="col-md-12">
# <hr/>
# <div class="row">
# <div class="col-md-4">
# <div class="list_image">
# <img src="https://mars.nasa.gov/system/news_items/list_view_images/8785_PIA24231-320.jpg"/>
# </div>
# </div>
# <div class="col-md-8">
# <div class="list_text">
# <div class="list_date">February 24, 2023</div>
# <div class="content_title">NASA's Perseverance Rover Is Midway to Mars </div>
# <div class="article_teaser_body">Sometimes half measures can be a good thing – especially on a journey this long. The agency's latest rover only has about 146 million miles left to reach its destination.</div>
# </div>
# </div>
# </div>
# </div>
# <div class="col-md-12">
# <hr/>
# <div class="row">
# <div class="col-md-4">
# <div class="list_image">
# <img src="https://mars.nasa.gov/system/news_items/list_view_images/8654_MAIN-IMAGE-PIA23881-320x240.jpg"/>
# </div>
# </div>
# <div class="col-md-8">
# <div class="list_text">
# <div class="list_date">February 22, 2023</div>
# <div class="content_title">How NASA's Perseverance Mars Team Adjusted to Work in the Time of Coronavirus </div>
# <div class="article_teaser_body">Like much of the rest of the world, the Mars rover team is pushing forward with its mission-critical work while putting the health and safety of their colleagues and community first.</div>
# </div>
# </div>
# </div>
# </div>
# <div class="col-md-12">
# <hr/>
# <div class="row">
# <div class="col-md-4">
# <div class="list_image">
# <img src="https://mars.nasa.gov/system/news_items/list_view_images/8671_PIA23890-320.jpg"/>
# </div>
# </div>
# <div class="col-md-8">
# <div class="list_text">
# <div class="list_date">February 20, 2023</div>
# <div class="content_title">NASA's Perseverance Rover Goes Through Trials by Fire, Ice, Light and Sound</div>
# <div class="article_teaser_body">The agency's new Mars rover is put through a series of tests in vacuum chambers, acoustic chambers and more to get ready for the Red Planet.</div>
# </div>
# </div>
# </div>
# </div>
# <div class="col-md-12">
# <hr/>
# <div class="row">
# <div class="col-md-4">
# <div class="list_image">
# <img src="https://mars.nasa.gov/system/news_items/list_view_images/8611_PIA22111-320x240.jpg"/>
# </div>
# </div>
# <div class="col-md-8">
# <div class="list_text">
# <div class="list_date">February 19, 2023</div>
# <div class="content_title">NASA Adds Return Sample Scientists to Mars 2020 Leadership Team</div>
# <div class="article_teaser_body">The leadership council for Mars 2020 science added two new members who represent the interests of scientists destined to handle and study the first samples from Red Planet.</div>
# </div>
# </div>
# </div>
# </div>
# <div class="col-md-12">
# <hr/>
# <div class="row">
# <div class="col-md-4">
# <div class="list_image">
# <img src="https://mars.nasa.gov/system/news_items/list_view_images/8622_1-PIA23764-RoverNamePlateonMars-320x240.jpg"/>
# </div>
# </div>
# <div class="col-md-8">
# <div class="list_text">
# <div class="list_date">February 18, 2023</div>
# <div class="content_title">Virginia Middle School Student Earns Honor of Naming NASA's Next Mars Rover</div>
# <div class="article_teaser_body">NASA chose a seventh-grader from Virginia as winner of the agency's "Name the Rover" essay contest. Alexander Mather's entry for "Perseverance" was voted tops among 28,000 entries. </div>
# </div>
# </div>
# </div>
# </div>
# <div class="col-md-12">
# <hr/>
# <div class="row">
# <div class="col-md-4">
# <div class="list_image">
# <img src="https://mars.nasa.gov/system/news_items/list_view_images/8536_Mars_chemist_320x240px.jpg"/>
# </div>
# </div>
# <div class="col-md-8">
# <div class="list_text">
# <div class="list_date">February 15, 2023</div>
# <div class="content_title">New Selfie Shows Curiosity, the Mars Chemist</div>
# <div class="article_teaser_body">The NASA rover performed a special chemistry experiment at the location captured in its newest self-portrait.</div>
# </div>
# </div>
# </div>
# </div>
# <div class="col-md-12">
# <hr/>
# <div class="row">
# <div class="col-md-4">
# <div class="list_image">
# <img src="https://mars.nasa.gov/system/news_items/list_view_images/8573_PIA23499-226.jpg"/>
# </div>
# </div>
# <div class="col-md-8">
# <div class="list_text">
# <div class="list_date">February 13, 2023</div>
# <div class="content_title">NASA's Mars 2020 Rover Completes Its First Drive</div>
# <div class="article_teaser_body">In a 10-plus-hour marathon, the rover steered, turned and drove in 3-foot (1-meter) increments over small ramps.</div>
# </div>
# </div>
# </div>
# </div>
# <div class="col-md-12">
# <hr/>
# <div class="row">
# <div class="col-md-4">
# <div class="list_image">
# <img src="https://mars.nasa.gov/system/news_items/list_view_images/8603_list_image.jpg"/>
# </div>
# </div>
# <div class="col-md-8">
# <div class="list_text">
# <div class="list_date">February 8, 2023</div>
# <div class="content_title">NASA Administrator Statement on Moon to Mars Initiative, FY 2021 Budget</div>
# <div class="article_teaser_body">Jim Bridenstine addresses NASA's ambitious plans for the coming years, including Mars Sample Return.</div>
# </div>
# </div>
# </div>
# </div>
# <div class="col-md-12">
# <hr/>
# <div class="row">
# <div class="col-md-4">
# <div class="list_image">
# <img src="https://mars.nasa.gov/system/news_items/list_view_images/8797_maven_illo_v7-320.jpg"/>
# </div>
# </div>
# <div class="col-md-8">
# <div class="list_text">
# <div class="list_date">February 8, 2023</div>
# <div class="content_title">Heat and Dust Help Launch Martian Water Into Space, Scientists Find</div>
# <div class="article_teaser_body">Scientists using an instrument aboard NASA’s Mars Atmosphere and Volatile EvolutioN, or MAVEN, spacecraft have discovered that water vapor near the surface of the Red Planet is lofted higher into the atmosphere than anyone expected was possible. </div>
# </div>
# </div>
# </div>
# </div>
# </div>, <div class="col-md-12">
# <hr/>
# <div class="row">
# <div class="col-md-4">
# <div class="list_image">
# <img src="https://mars.nasa.gov/system/news_items/list_view_images/8680_mavenmarselectriccurrents-320x240.jpg"/>
# </div>
# </div>
# <div class="col-md-8">
# <div class="list_text">
# <div class="list_date">March 7, 2023</div>
# <div class="content_title">MAVEN Maps Electric Currents around Mars that are Fundamental to Atmospheric Loss</div>
# ...
# </div>
# </div>
# </div>
# </div>, <div class="col-md-4 mb-3">
# <div class="card">
# <img alt="100%x280" class="img-fluid" src="https://mars.nasa.gov/system/news_items/main_images/8716_PIA23499-16.jpg"/>
# <div class="card-body">
# <p class="card-text">NASA to Broadcast Mars 2020 Perseverance Launch, Prelaunch Activities</p>
# </div>
# </div>
# </div>, <div class="card">
# <img alt="100%x280" class="img-fluid" src="https://mars.nasa.gov/system/news_items/main_images/8716_PIA23499-16.jpg"/>
# <div class="card-body">
# <p class="card-text">NASA to Broadcast Mars 2020 Perseverance Launch, Prelaunch Activities</p>
# </div>
# </div>, <div class="card-body">
# <p class="card-text">NASA to Broadcast Mars 2020 Perseverance Launch, Prelaunch Activities</p>
# </div>, <div class="col-md-4 mb-3">
# <div class="card">
# <img alt="100%x280" class="img-fluid" src="https://mars.nasa.gov/system/news_items/main_images/8716_PIA23499-16.jpg"/>
# <div class="card-body">
# <p class="card-text">The Launch Is Approaching for NASA's Next Mars Rover, Perseverance</p>
# </div>
# </div>
# </div>, <div class="card">
# <img alt="100%x280" class="img-fluid" src="https://mars.nasa.gov/system/news_items/main_images/8716_PIA23499-16.jpg"/>
# <div class="card-body">
# <p class="card-text">The Launch Is Approaching for NASA's Next Mars Rover, Perseverance</p>
# </div>
# </div>, <div class="card-body">
# <p class="card-text">The Launch Is Approaching for NASA's Next Mars Rover, Perseverance</p>
# </div>, <div class="col-md-4 mb-3">
# <div class="card">
# <img alt="100%x280" class="img-fluid" src="https://mars.nasa.gov/system/news_items/main_images/8692_PIA23920-web.jpg"/>
# <div class="card-body">
# <p class="card-text">NASA to Hold Mars 2020 Perseverance Rover Launch Briefing</p>
# </div>
# </div>
# </div>, <div class="card">
# <img alt="100%x280" class="img-fluid" src="https://mars.nasa.gov/system/news_items/main_images/8692_PIA23920-web.jpg"/>
# <div class="card-body">
# <p class="card-text">NASA to Hold Mars 2020 Perseverance Rover Launch Briefing</p>
# </div>
# </div>, <div class="card-body">
# <p class="card-text">NASA to Hold Mars 2020 Perseverance Rover Launch Briefing</p>
# </div>, <div class="carousel-item">
# <div class="row">
# <div class="col-md-4 mb-3">
# <div class="card">
# <img alt="100%x280" class="img-fluid" src="https://images.unsplash.com/photo-1532771098148-525cefe10c23?ixlib=rb-0.3.5&amp;q=80&amp;fm=jpg&amp;crop=entropy&amp;cs=tinysrgb&amp;w=1080&amp;fit=max&amp;ixid=eyJhcHBfaWQiOjMyMDc0fQ&amp;s=3f317c1f7a16116dec454fbc267dd8e4"/>
# <div class="card-body">
# <p class="card-text">With supporting text below as a natural lead-in to additional content.</p>
# </div>
# </div>
# </div>
# <div class="col-md-4 mb-3">
# <div class="card">
# <img alt="100%x280" class="img-fluid" src="https://images.unsplash.com/photo-1532715088550-62f09305f765?ixlib=rb-0.3.5&amp;q=80&amp;fm=jpg&amp;crop=entropy&amp;cs=tinysrgb&amp;w=1080&amp;fit=max&amp;ixid=eyJhcHBfaWQiOjMyMDc0fQ&amp;s=ebadb044b374504ef8e81bdec4d0e840"/>
# <div class="card-body">
# <p class="card-text">With supporting text below as a natural lead-in to additional content.</p>
# </div>
# </div>
# </div>
# <div class="col-md-4 mb-3">
# <div class="card">
# <img alt="100%x280" class="img-fluid" src="https://images.unsplash.com/photo-1506197603052-3cc9c3a201bd?ixlib=rb-0.3.5&amp;q=80&amp;fm=jpg&amp;crop=entropy&amp;cs=tinysrgb&amp;w=1080&amp;fit=max&amp;ixid=eyJhcHBfaWQiOjMyMDc0fQ&amp;s=0754ab085804ae8a3b562548e6b4aa2e"/>
# <div class="card-body">
# <p class="card-text">With supporting text below as a natural lead-in to additional content.</p>
# </div>
# </div>
# </div>
# </div>
# </div>, <div class="row">
# <div class="col-md-4 mb-3">
# <div class="card">
# <img alt="100%x280" class="img-fluid" src="https://images.unsplash.com/photo-1532771098148-525cefe10c23?ixlib=rb-0.3.5&amp;q=80&amp;fm=jpg&amp;crop=entropy&amp;cs=tinysrgb&amp;w=1080&amp;fit=max&amp;ixid=eyJhcHBfaWQiOjMyMDc0fQ&amp;s=3f317c1f7a16116dec454fbc267dd8e4"/>
# <div class="card-body">
# <p class="card-text">With supporting text below as a natural lead-in to additional content.</p>
# </div>
# </div>
# </div>
# <div class="col-md-4 mb-3">
# <div class="card">
# <img alt="100%x280" class="img-fluid" src="https://images.unsplash.com/photo-1532715088550-62f09305f765?ixlib=rb-0.3.5&amp;q=80&amp;fm=jpg&amp;crop=entropy&amp;cs=tinysrgb&amp;w=1080&amp;fit=max&amp;ixid=eyJhcHBfaWQiOjMyMDc0fQ&amp;s=ebadb044b374504ef8e81bdec4d0e840"/>
# <div class="card-body">
# <p class="card-text">With supporting text below as a natural lead-in to additional content.</p>
# </div>
# </div>
# </div>
# <div class="col-md-4 mb-3">
# <div class="card">
# <img alt="100%x280" class="img-fluid" src="https://images.unsplash.com/photo-1506197603052-3cc9c3a201bd?ixlib=rb-0.3.5&amp;q=80&amp;fm=jpg&amp;crop=entropy&amp;cs=tinysrgb&amp;w=1080&amp;fit=max&amp;ixid=eyJhcHBfaWQiOjMyMDc0fQ&amp;s=0754ab085804ae8a3b562548e6b4aa2e"/>
# <div class="card-body">
# <p class="card-text">With supporting text below as a natural lead-in to additional content.</p>
# </div>
# </div>
# </div>
# </div>, <div class="col-md-4 mb-3">
# <div class="card">
# <img alt="100%x280" class="img-fluid" src="https://images.unsplash.com/photo-1532771098148-525cefe10c23?ixlib=rb-0.3.5&amp;q=80&amp;fm=jpg&amp;crop=entropy&amp;cs=tinysrgb&amp;w=1080&amp;fit=max&amp;ixid=eyJhcHBfaWQiOjMyMDc0fQ&amp;s=3f317c1f7a16116dec454fbc267dd8e4"/>
# <div class="card-body">
# <p class="card-text">With supporting text below as a natural lead-in to additional content.</p>
# </div>
# </div>
# </div>, <div class="card">
# <img alt="100%x280" class="img-fluid" src="https://images.unsplash.com/photo-1532771098148-525cefe10c23?ixlib=rb-0.3.5&amp;q=80&amp;fm=jpg&amp;crop=entropy&amp;cs=tinysrgb&amp;w=1080&amp;fit=max&amp;ixid=eyJhcHBfaWQiOjMyMDc0fQ&amp;s=3f317c1f7a16116dec454fbc267dd8e4"/>
# <div class="card-body">
# <p class="card-text">With supporting text below as a natural lead-in to additional content.</p>
# </div>
# </div>, <div class="card-body">
# <p class="card-text">With supporting text below as a natural lead-in to additional content.</p>
# </div>, <div class="col-md-4 mb-3">
# <div class="card">
# <img alt="100%x280" class="img-fluid" src="https://images.unsplash.com/photo-1532715088550-62f09305f765?ixlib=rb-0.3.5&amp;q=80&amp;fm=jpg&amp;crop=entropy&amp;cs=tinysrgb&amp;w=1080&amp;fit=max&amp;ixid=eyJhcHBfaWQiOjMyMDc0fQ&amp;s=ebadb044b374504ef8e81bdec4d0e840"/>
# <div class="card-body">
# <p class="card-text">With supporting text below as a natural lead-in to additional content.</p>
# </div>
# </div>
# </div>, <div class="card">
# <img alt="100%x280" class="img-fluid" src="https://images.unsplash.com/photo-1532715088550-62f09305f765?ixlib=rb-0.3.5&amp;q=80&amp;fm=jpg&amp;crop=entropy&amp;cs=tinysrgb&amp;w=1080&amp;fit=max&amp;ixid=eyJhcHBfaWQiOjMyMDc0fQ&amp;s=ebadb044b374504ef8e81bdec4d0e840"/>
# <div class="card-body">
# <p class="card-text">With supporting text below as a natural lead-in to additional content.</p>
# </div>
# </div>, <div class="card-body">
# <p class="card-text">With supporting text below as a natural lead-in to additional content.</p>
# </div>, <div class="col-md-4 mb-3">
# <div class="card">
# <img alt="100%x280" class="img-fluid" src="https://images.unsplash.com/photo-1506197603052-3cc9c3a201bd?ixlib=rb-0.3.5&amp;q=80&amp;fm=jpg&amp;crop=entropy&amp;cs=tinysrgb&amp;w=1080&amp;fit=max&amp;ixid=eyJhcHBfaWQiOjMyMDc0fQ&amp;s=0754ab085804ae8a3b562548e6b4aa2e"/>
# <div class="card-body">
# <p class="card-text">With supporting text below as a natural lead-in to additional content.</p>
# </div>
# </div>
# </div>, <div class="card">
# <img alt="100%x280" class="img-fluid" src="https://images.unsplash.com/photo-1506197603052-3cc9c3a201bd?ixlib=rb-0.3.5&amp;q=80&amp;fm=jpg&amp;crop=entropy&amp;cs=tinysrgb&amp;w=1080&amp;fit=max&amp;ixid=eyJhcHBfaWQiOjMyMDc0fQ&amp;s=0754ab085804ae8a3b562548e6b4aa2e"/>
# <div class="card-body">
# <p class="card-text">With supporting text below as a natural lead-in to additional content.</p>
# </div>
# </div>, <div class="card-body">
# <p class="card-text">With supporting text below as a natural lead-in to additional content.</p>
# </div>, <div class="carousel-item">
# <div class="row">
# <div class="col-md-4 mb-3">
# <div class="card">
# <img alt="100%x280" class="img-fluid" src="https://images.unsplash.com/photo-1507525428034-b723cf961d3e?ixlib=rb-0.3.5&amp;q=80&amp;fm=jpg&amp;crop=entropy&amp;cs=tinysrgb&amp;w=1080&amp;fit=max&amp;ixid=eyJhcHBfaWQiOjMyMDc0fQ&amp;s=ee8417f0ea2a50d53a12665820b54e23"/>
# <div class="card-body">
# <p class="card-text">With supporting text below as a natural lead-in to additional content.</p>
# </div>
# </div>
# </div>
# <div class="col-md-4 mb-3">
# <div class="card">
# <img alt="100%x280" class="img-fluid" src="https://images.unsplash.com/photo-1532777946373-b6783242f211?ixlib=rb-0.3.5&amp;q=80&amp;fm=jpg&amp;crop=entropy&amp;cs=tinysrgb&amp;w=1080&amp;fit=max&amp;ixid=eyJhcHBfaWQiOjMyMDc0fQ&amp;s=8ac55cf3a68785643998730839663129"/>
# <div class="card-body">
# <p class="card-text">With supporting text below as a natural lead-in to additional content.</p>
# </div>
# </div>
# </div>
# <div class="col-md-4 mb-3">
# <div class="card">
# <img alt="100%x280" class="img-fluid" src="https://images.unsplash.com/photo-1532763303805-529d595877c5?ixlib=rb-0.3.5&amp;q=80&amp;fm=jpg&amp;crop=entropy&amp;cs=tinysrgb&amp;w=1080&amp;fit=max&amp;ixid=eyJhcHBfaWQiOjMyMDc0fQ&amp;s=5ee4fd5d19b40f93eadb21871757eda6"/>
# <div class="card-body">
# <p class="card-text">With supporting text below as a natural lead-in to additional content.</p>
# </div>
# </div>
# </div>
# </div>
# </div>, <div class="row">
# <div class="col-md-4 mb-3">
# <div class="card">
# <img alt="100%x280" class="img-fluid" src="https://images.unsplash.com/photo-1507525428034-b723cf961d3e?ixlib=rb-0.3.5&amp;q=80&amp;fm=jpg&amp;crop=entropy&amp;cs=tinysrgb&amp;w=1080&amp;fit=max&amp;ixid=eyJhcHBfaWQiOjMyMDc0fQ&amp;s=ee8417f0ea2a50d53a12665820b54e23"/>
# <div class="card-body">
# <p class="card-text">With supporting text below as a natural lead-in to additional content.</p>
# </div>
# </div>
# </div>
# <div class="col-md-4 mb-3">
# <div class="card">
# <img alt="100%x280" class="img-fluid" src="https://images.unsplash.com/photo-1532777946373-b6783242f211?ixlib=rb-0.3.5&amp;q=80&amp;fm=jpg&amp;crop=entropy&amp;cs=tinysrgb&amp;w=1080&amp;fit=max&amp;ixid=eyJhcHBfaWQiOjMyMDc0fQ&amp;s=8ac55cf3a68785643998730839663129"/>
# <div class="card-body">
# <p class="card-text">With supporting text below as a natural lead-in to additional content.</p>
# </div>
# </div>
# </div>
# <div class="col-md-4 mb-3">
# <div class="card">
# <img alt="100%x280" class="img-fluid" src="https://images.unsplash.com/photo-1532763303805-529d595877c5?ixlib=rb-0.3.5&amp;q=80&amp;fm=jpg&amp;crop=entropy&amp;cs=tinysrgb&amp;w=1080&amp;fit=max&amp;ixid=eyJhcHBfaWQiOjMyMDc0fQ&amp;s=5ee4fd5d19b40f93eadb21871757eda6"/>
# <div class="card-body">
# <p class="card-text">With supporting text below as a natural lead-in to additional content.</p>
# </div>
# </div>
# </div>
# </div>, <div class="col-md-4 mb-3">
# <div class="card">
# <img alt="100%x280" class="img-fluid" src="https://images.unsplash.com/photo-1507525428034-b723cf961d3e?ixlib=rb-0.3.5&amp;q=80&amp;fm=jpg&amp;crop=entropy&amp;cs=tinysrgb&amp;w=1080&amp;fit=max&amp;ixid=eyJhcHBfaWQiOjMyMDc0fQ&amp;s=ee8417f0ea2a50d53a12665820b54e23"/>
# <div class="card-body">
# <p class="card-text">With supporting text below as a natural lead-in to additional content.</p>
# </div>
# </div>
# </div>, <div class="card">
# <img alt="100%x280" class="img-fluid" src="https://images.unsplash.com/photo-1507525428034-b723cf961d3e?ixlib=rb-0.3.5&amp;q=80&amp;fm=jpg&amp;crop=entropy&amp;cs=tinysrgb&amp;w=1080&amp;fit=max&amp;ixid=eyJhcHBfaWQiOjMyMDc0fQ&amp;s=ee8417f0ea2a50d53a12665820b54e23"/>
# <div class="card-body">
# <p class="card-text">With supporting text below as a natural lead-in to additional content.</p>
# </div>
# </div>, <div class="card-body">
# <p class="card-text">With supporting text below as a natural lead-in to additional content.</p>
# </div>, <div class="col-md-4 mb-3">
# <div class="card">
# <img alt="100%x280" class="img-fluid" src="https://images.unsplash.com/photo-1532777946373-b6783242f211?ixlib=rb-0.3.5&amp;q=80&amp;fm=jpg&amp;crop=entropy&amp;cs=tinysrgb&amp;w=1080&amp;fit=max&amp;ixid=eyJhcHBfaWQiOjMyMDc0fQ&amp;s=8ac55cf3a68785643998730839663129"/>
# <div class="card-body">
# <p class="card-text">With supporting text below as a natural lead-in to additional content.</p>
# </div>
# </div>
# </div>, <div class="card">
# <img alt="100%x280" class="img-fluid" src="https://images.unsplash.com/photo-1532777946373-b6783242f211?ixlib=rb-0.3.5&amp;q=80&amp;fm=jpg&amp;crop=entropy&amp;cs=tinysrgb&amp;w=1080&amp;fit=max&amp;ixid=eyJhcHBfaWQiOjMyMDc0fQ&amp;s=8ac55cf3a68785643998730839663129"/>
# <div class="card-body">
# <p class="card-text">With supporting text below as a natural lead-in to additional content.</p>
# </div>
# </div>, <div class="card-body">
# <p class="card-text">With supporting text below as a natural lead-in to additional content.</p>
# </div>, <div class="col-md-4 mb-3">
# <div class="card">
# <img alt="100%x280" class="img-fluid" src="https://images.unsplash.com/photo-1532763303805-529d595877c5?ixlib=rb-0.3.5&amp;q=80&amp;fm=jpg&amp;crop=entropy&amp;cs=tinysrgb&amp;w=1080&amp;fit=max&amp;ixid=eyJhcHBfaWQiOjMyMDc0fQ&amp;s=5ee4fd5d19b40f93eadb21871757eda6"/>
# <div class="card-body">
# <p class="card-text">With supporting text below as a natural lead-in to additional content.</p>
# </div>
# </div>
# </div>, <div class="card">
# <img alt="100%x280" class="img-fluid" src="https://images.unsplash.com/photo-1532763303805-529d595877c5?ixlib=rb-0.3.5&amp;q=80&amp;fm=jpg&amp;crop=entropy&amp;cs=tinysrgb&amp;w=1080&amp;fit=max&amp;ixid=eyJhcHBfaWQiOjMyMDc0fQ&amp;s=5ee4fd5d19b40f93eadb21871757eda6"/>
# <div class="card-body">
# <p class="card-text">With supporting text below as a natural lead-in to additional content.</p>
# </div>
# </div>, <div class="card-body">
# <p class="card-text">With supporting text below as a natural lead-in to additional content.</p>
# </div>, <div class="container">
# <div class="col-md-12">
# <div class="row">
# <div class="col-md-3">
# <h5>The Red Planet</h5>
# <ul>
# <li>Dashboard</li>
# <li>Science Goals</li>
# <li>The Planet</li>
# </ul>
# </div>
# <div class="col-md-3">
# <h5>The Program</h5>
# <ul>
# <li>Mission Statement</li>
# <li>About the Program</li>
# <li>Organization Why Mars?</li>
# </ul>
# </div>
# <div class="col-md-3">
# <h5>Multimedia</h5>
# <ul>
# <li>Images</li>
# <li>Videos</li>
# <li>More Resources</li>
# </ul>
# </div>
# <div class="col-md-3">
# <h5>Missions</h5>
# <ul>
# <li>Past</li>
# <li>Present</li>
# <li>Future</li>
# </ul>
# </div>
# </div>
# </div>
# </div>, <div class="col-md-12">
# <div class="row">
# <div class="col-md-3">
# <h5>The Red Planet</h5>
# <ul>
# <li>Dashboard</li>
# <li>Science Goals</li>
# <li>The Planet</li>
# </ul>
# </div>
# <div class="col-md-3">
# <h5>The Program</h5>
# <ul>
# <li>Mission Statement</li>
# <li>About the Program</li>
# <li>Organization Why Mars?</li>
# </ul>
# </div>
# <div class="col-md-3">
# <h5>Multimedia</h5>
# <ul>
# <li>Images</li>
# <li>Videos</li>
# <li>More Resources</li>
# </ul>
# </div>
# <div class="col-md-3">
# <h5>Missions</h5>
# <ul>
# <li>Past</li>
# <li>Present</li>
# <li>Future</li>
# </ul>
# </div>
# </div>
# </div>, <div class="row">
# <div class="col-md-3">
# <h5>The Red Planet</h5>
# <ul>
# <li>Dashboard</li>
# <li>Science Goals</li>
# <li>The Planet</li>
# </ul>
# </div>
# <div class="col-md-3">
# <h5>The Program</h5>
# <ul>
# <li>Mission Statement</li>
# <li>About the Program</li>
# <li>Organization Why Mars?</li>
# </ul>
# </div>
# <div class="col-md-3">
# <h5>Multimedia</h5>
# <ul>
# <li>Images</li>
# <li>Videos</li>
# <li>More Resources</li>
# </ul>
# </div>
# <div class="col-md-3">
# <h5>Missions</h5>
# <ul>
# <li>Past</li>
# <li>Present</li>
# <li>Future</li>
# </ul>
# </div>
# </div>, <div class="col-md-3">
# <h5>The Red Planet</h5>
# <ul>
# <li>Dashboard</li>
# <li>Science Goals</li>
# <li>The Planet</li>
# </ul>
# </div>, <div class="col-md-3">
# <h5>The Program</h5>
# <ul>
# <li>Mission Statement</li>
# <li>About the Program</li>
# <li>Organization Why Mars?</li>
# </ul>
# </div>, <div class="col-md-3">
# <h5>Multimedia</h5>
# <ul>
# <li>Images</li>
# <li>Videos</li>
# <li>More Resources</li>
# </ul>
# </div>, <div class="col-md-3">
# <h5>Missions</h5>
# <ul>
# <li>Past</li>
# <li>Present</li>
# <li>Future</li>
# </ul>
# </div>]

# %%
title= [tag.text for tag in html_soup.find_all('div', class_='content_title')]
title
# Out:
# ['MAVEN Maps Electric Currents around Mars that are Fundamental to Atmospheric Loss',
#  "NASA's Curiosity Keeps Rolling As Team Operates Rover From Home",
#  'AI Is Helping Scientists Discover Fresh Craters on Mars',
#  'Scientists Explore Outback as Testbed for Mars ',
#  "What's Mars Solar Conjunction, and Why Does It Matter?",
#  "NASA's Mars Perseverance Rover Gets Its Sample Handling System",
#  "NASA's Perseverance Rover Is Midway to Mars ",
#  "How NASA's Perseverance Mars Team Adjusted to Work in the Time of Coronavirus ",
#  "NASA's Perseverance Rover Goes Through Trials by Fire, Ice, Light and Sound",
#  'NASA Adds Return Sample Scientists to Mars 2020 Leadership Team',
#  "Virginia Middle School Student Earns Honor of Naming NASA's Next Mars Rover",
#  'New Selfie Shows Curiosity, the Mars Chemist',
#  "NASA's Mars 2020 Rover Completes Its First Drive",
#  'NASA Administrator Statement on Moon to Mars Initiative, FY 2021 Budget',
#  'Heat and Dust Help Launch Martian Water Into Space, Scientists Find']

# %%
preview = [tag.text for tag in html_soup.find_all('div', class_='article_teaser_body')]
#preview = html_soup.find_all('div', class_='article_teaser_body')
preview
# Out:
# ['Five years after NASA’s MAVEN spacecraft entered into orbit around Mars, data from the mission has led to the creation of a map of electric current systems in the Martian atmosphere.',
#  'The team has learned to meet new challenges as they work remotely on the Mars mission.',
#  "It's the first time machine learning has been used to find previously unknown craters on the Red Planet.",
#  "Australia provides a great place for NASA's Mars 2020 and the ESA-Roscosmos ExoMars scientists to hone techniques in preparation for searching for signs ancient life on Mars.",
#  'NASA spacecraft at Mars are going to be on their own for a few weeks when the Sun comes between Mars and Earth, interrupting communications.',
#  'The system will be collecting and storing Martian rock and soil. Its installation marks another milestone in the march toward the July launch period.',
#  "Sometimes half measures can be a good thing – especially on a journey this long. The agency's latest rover only has about 146 million miles left to reach its destination.",
#  'Like much of the rest of the world, the Mars rover team is pushing forward with its mission-critical work while putting the health and safety of their colleagues and community first.',
#  "The agency's new Mars rover is put through a series of tests in vacuum chambers, acoustic chambers and more to get ready for the Red Planet.",
#  'The leadership council for Mars 2020 science added two new members who represent the interests of scientists destined to handle and study the first samples from Red Planet.',
#  'NASA chose a seventh-grader from Virginia as winner of the agency\'s "Name the Rover" essay contest. Alexander Mather\'s entry for "Perseverance" was voted tops among 28,000 entries. ',
#  'The NASA rover performed a special chemistry experiment at the location captured in its newest self-portrait.',
#  'In a 10-plus-hour marathon, the rover steered, turned and drove in 3-foot (1-meter) increments over small ramps.',
#  "Jim Bridenstine addresses NASA's ambitious plans for the coming years, including Mars Sample Return.",
#  'Scientists using an instrument aboard NASA’s Mars Atmosphere and Volatile EvolutioN, or MAVEN, spacecraft have discovered that water vapor near the surface of the Red Planet is lofted higher into the atmosphere than anyone expected was possible. ']

# %%
# Create an empty list to store the dictionaries
articles_list = []

# %%
# Loop through the text elements
articles= html_soup.find_all('div',class_= 'list_text')
for article in articles:
    
# Extract the title and preview text from the elements
    title =  article.find(class_='content_title').text
    preview = article.find(class_='article_teaser_body').text
   
#Store each title and preview pair in a dictionary
    article_dict={}
    article_dict['title'] = title
    article_dict['preview'] = preview

    
#Add the dictionary to the list
    articles_list.append(article_dict)

# %%
print(articles_list)
# Out:
# [{'title': 'MAVEN Maps Electric Currents around Mars that are Fundamental to Atmospheric Loss', 'preview': 'Five years after NASA’s MAVEN spacecraft entered into orbit around Mars, data from the mission has led to the creation of a map of electric current systems in the Martian atmosphere.'}, {'title': "NASA's Curiosity Keeps Rolling As Team Operates Rover From Home", 'preview': 'The team has learned to meet new challenges as they work remotely on the Mars mission.'}, {'title': 'AI Is Helping Scientists Discover Fresh Craters on Mars', 'preview': "It's the first time machine learning has been used to find previously unknown craters on the Red Planet."}, {'title': 'Scientists Explore Outback as Testbed for Mars ', 'preview': "Australia provides a great place for NASA's Mars 2020 and the ESA-Roscosmos ExoMars scientists to hone techniques in preparation for searching for signs ancient life on Mars."}, {'title': "What's Mars Solar Conjunction, and Why Does It Matter?", 'preview': 'NASA spacecraft at Mars are going to be on their own for a few weeks when the Sun comes between Mars and Earth, interrupting communications.'}, {'title': "NASA's Mars Perseverance Rover Gets Its Sample Handling System", 'preview': 'The system will be collecting and storing Martian rock and soil. Its installation marks another milestone in the march toward the July launch period.'}, {'title': "NASA's Perseverance Rover Is Midway to Mars ", 'preview': "Sometimes half measures can be a good thing – especially on a journey this long. The agency's latest rover only has about 146 million miles left to reach its destination."}, {'title': "How NASA's Perseverance Mars Team Adjusted to Work in the Time of Coronavirus ", 'preview': 'Like much of the rest of the world, the Mars rover team is pushing forward with its mission-critical work while putting the health and safety of their colleagues and community first.'}, {'title': "NASA's Perseverance Rover Goes Through Trials by Fire, Ice, Light and Sound", 'preview': "The agency's new Mars rover is put through a series of tests in vacuum chambers, acoustic chambers and more to get ready for the Red Planet."}, {'title': 'NASA Adds Return Sample Scientists to Mars 2020 Leadership Team', 'preview': 'The leadership council for Mars 2020 science added two new members who represent the interests of scientists destined to handle and study the first samples from Red Planet.'}, {'title': "Virginia Middle School Student Earns Honor of Naming NASA's Next Mars Rover", 'preview': 'NASA chose a seventh-grader from Virginia as winner of the agency\'s "Name the Rover" essay contest. Alexander Mather\'s entry for "Perseverance" was voted tops among 28,000 entries. '}, {'title': 'New Selfie Shows Curiosity, the Mars Chemist', 'preview': 'The NASA rover performed a special chemistry experiment at the location captured in its newest self-portrait.'}, {'title': "NASA's Mars 2020 Rover Completes Its First Drive", 'preview': 'In a 10-plus-hour marathon, the rover steered, turned and drove in 3-foot (1-meter) increments over small ramps.'}, {'title': 'NASA Administrator Statement on Moon to Mars Initiative, FY 2021 Budget', 'preview': "Jim Bridenstine addresses NASA's ambitious plans for the coming years, including Mars Sample Return."}, {'title': 'Heat and Dust Help Launch Martian Water Into Space, Scientists Find', 'preview': 'Scientists using an instrument aboard NASA’s Mars Atmosphere and Volatile EvolutioN, or MAVEN, spacecraft have discovered that water vapor near the surface of the Red Planet is lofted higher into the atmosphere than anyone expected was possible. '}]

# %%
# browser.quit()

# %% [markdown]
# ### (Optional) Step 4: Export the Data
#
# Optionally, store the scraped data in a file or database (to ease sharing the data with others). To do so, export the scraped data to either a JSON file or a MongoDB database.

# %%
# Export data to JSON
import json 
json_string = json.dumps(articles_list)
print(json_string)
#with open("data.json", "w") as outfile:
    #outfile.write(json_string)
# Out:
# [{"title": "MAVEN Maps Electric Currents around Mars that are Fundamental to Atmospheric Loss", "preview": "Five years after NASA\u2019s MAVEN spacecraft entered into orbit around Mars, data from the mission has led to the creation of a map of electric current systems in the Martian atmosphere."}, {"title": "NASA's Curiosity Keeps Rolling As Team Operates Rover From Home", "preview": "The team has learned to meet new challenges as they work remotely on the Mars mission."}, {"title": "AI Is Helping Scientists Discover Fresh Craters on Mars", "preview": "It's the first time machine learning has been used to find previously unknown craters on the Red Planet."}, {"title": "Scientists Explore Outback as Testbed for Mars ", "preview": "Australia provides a great place for NASA's Mars 2020 and the ESA-Roscosmos ExoMars scientists to hone techniques in preparation for searching for signs ancient life on Mars."}, {"title": "What's Mars Solar Conjunction, and Why Does It Matter?", "preview": "NASA spacecraft at Mars are going to be on their own for a few weeks when the Sun comes between Mars and Earth, interrupting communications."}, {"title": "NASA's Mars Perseverance Rover Gets Its Sample Handling System", "preview": "The system will be collecting and storing Martian rock and soil. Its installation marks another milestone in the march toward the July launch period."}, {"title": "NASA's Perseverance Rover Is Midway to Mars ", "preview": "Sometimes half measures can be a good thing \u2013 especially on a journey this long. The agency's latest rover only has about 146 million miles left to reach its destination."}, {"title": "How NASA's Perseverance Mars Team Adjusted to Work in the Time of Coronavirus ", "preview": "Like much of the rest of the world, the Mars rover team is pushing forward with its mission-critical work while putting the health and safety of their colleagues and community first."}, {"title": "NASA's Perseverance Rover Goes Through Trials by Fire, Ice, Light and Sound", "preview": "The agency's new Mars rover is put through a series of tests in vacuum chambers, acoustic chambers and more to get ready for the Red Planet."}, {"title": "NASA Adds Return Sample Scientists to Mars 2020 Leadership Team", "preview": "The leadership council for Mars 2020 science added two new members who represent the interests of scientists destined to handle and study the first samples from Red Planet."}, {"title": "Virginia Middle School Student Earns Honor of Naming NASA's Next Mars Rover", "preview": "NASA chose a seventh-grader from Virginia as winner of the agency's \"Name the Rover\" essay contest. Alexander Mather's entry for \"Perseverance\" was voted tops among 28,000 entries. "}, {"title": "New Selfie Shows Curiosity, the Mars Chemist", "preview": "The NASA rover performed a special chemistry experiment at the location captured in its newest self-portrait."}, {"title": "NASA's Mars 2020 Rover Completes Its First Drive", "preview": "In a 10-plus-hour marathon, the rover steered, turned and drove in 3-foot (1-meter) increments over small ramps."}, {"title": "NASA Administrator Statement on Moon to Mars Initiative, FY 2021 Budget", "preview": "Jim Bridenstine addresses NASA's ambitious plans for the coming years, including Mars Sample Return."}, {"title": "Heat and Dust Help Launch Martian Water Into Space, Scientists Find", "preview": "Scientists using an instrument aboard NASA\u2019s Mars Atmosphere and Volatile EvolutioN, or MAVEN, spacecraft have discovered that water vapor near the surface of the Red Planet is lofted higher into the atmosphere than anyone expected was possible. "}]

# %%
# Export data to MongoDB
from pymongo import MongoClient
mongo = MongoClient(port=27017)

# Testing Mongo db
print(mongo.list_database_names())
# Out:
# ['admin', 'config', 'local']

# %%
mongoimport --db mydatabase --collection mycollection --json_string.json
# Out:
#   File "C:\Users\Woyram\AppData\Local\Temp\ipykernel_35572\1204245541.py", line 1
#     mongoimport --db mydatabase --collection mycollection --json_string.json
#                               ^
# SyntaxError: invalid syntax
