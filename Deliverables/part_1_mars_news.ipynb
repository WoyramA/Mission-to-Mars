# %% [markdown]
# # Module 12 Challenge
# ## Deliverable 1: Scrape Titles and Preview Text from Mars News

# %%
# Import Splinter and BeautifulSoup
from splinter import Browser
from bs4 import BeautifulSoup as soup
from webdriver_manager.chrome import ChromeDriverManager

# %%
executable_path = {'executable_path': ChromeDriverManager().install()}
browser = Browser('chrome', **executable_path, headless=False)

# %% [markdown]
# ### Step 1: Visit the Website
#
# 1. Use automated browsing to visit the [Mars NASA news site](https://redplanetscience.com). Inspect the page to identify which elements to scrape.
#
#       > **Hint** To identify which elements to scrape, you might want to inspect the page by using Chrome DevTools.

# %%
# Visit the Mars NASA news site: https://redplanetscience.com
url = 'https://redplanetscience.com'
browser.visit(url)

# %% [markdown]
# ### Step 2: Scrape the Website
#
# Create a Beautiful Soup object and use it to extract text elements from the website.

# %%
# Create a Beautiful Soup object
# Set up HTML parser
html = browser.html
html_soup = soup(html, 'html.parser')

# %%
# Extract all the text elements
for text in html_soup.find_all(text=True):
    print(text)
# Out:
# News - Mars Exploration Program
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# MARS Planet Science
#
#
# Exploration Program
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# The Red Planet
#
#
#
#
#
#
# The Program
#
#
#
#
#
#
# News & Events
#
#
#
#
#
#
# Multimedia
#
#
#
#
#
#
# Missions
#
#
#
#
#
#
# More
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# News
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Latest
#
#
# 2020
# 2019
#
#
#
#
#
#
#
#
# All Categories
#
#
# Feature Stories
# Status Reports
# Press Releases
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# March 7, 2023
#
#
# NASA's MAVEN Maps Winds in the Martian Upper Atmosphere that Mirror the Terrain Below and Gives Clues to Martian Climate
#
#
# Researchers have created the first map of wind circulation in the upper atmosphere of a planet besides Earth, using data from NASA’s MAVEN spacecraft that were collected during the last two years.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# March 6, 2023
#
#
# NASA's Perseverance Rover 100 Days Out
#
#
# Mark your calendars: The agency's latest rover has only about 8,640,000 seconds to go before it touches down on the Red Planet, becoming history's next Mars car.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# March 5, 2023
#
#
# NASA InSight's 'Mole' Is Out of Sight
#
#
# Now that the heat probe is just below the Martian surface, InSight's arm will scoop some additional soil on top to help it keep digging so it can take Mars' temperature.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# March 5, 2023
#
#
# Join NASA for the Launch of the Mars 2020 Perseverance Rover
#
#
# No matter where you live, choose from a menu of activities to join NASA as we "Countdown to Mars" and launch the Perseverance rover to the Red Planet.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# February 28, 2023
#
#
# NASA Wins 4 Webbys, 4 People's Voice Awards
#
#
# Winners include the JPL-managed "Send Your Name to Mars" campaign, NASA's Global Climate Change website and Solar System Interactive.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# February 26, 2023
#
#
# The Detective Aboard NASA's Perseverance Rover
#
#
# An instrument called SHERLOC will, with the help of its partner WATSON, hunt for signs of ancient life by detecting organic molecules and minerals.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# February 24, 2023
#
#
# NASA's Curiosity Keeps Rolling As Team Operates Rover From Home
#
#
# The team has learned to meet new challenges as they work remotely on the Mars mission.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# February 18, 2023
#
#
# 3 Things We've Learned From NASA's Mars InSight
#
#
# Scientists are finding new mysteries since the geophysics mission landed two years ago.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# February 18, 2023
#
#
# NASA's Mars 2020 Rover Tests Descent-Stage Separation
#
#
# A crane lifts the rocket-powered descent stage away from NASA's Mars 2020 rover after technicians tested the pyrotechnic charges that separate the two spacecraft.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# February 17, 2023
#
#
# 7 Things to Know About the Mars 2020 Perseverance Rover Mission
#
#
# NASA's next rover to the Red Planet is slated to launch no earlier than July 30. These highlights will get you up to speed on the ambitious mission.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# February 17, 2023
#
#
# How NASA's Perseverance Mars Team Adjusted to Work in the Time of Coronavirus
#
#
# Like much of the rest of the world, the Mars rover team is pushing forward with its mission-critical work while putting the health and safety of their colleagues and community first.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# February 15, 2023
#
#
# Curiosity Mars Rover's Summer Road Trip Has Begun
#
#
# After more than a year in the "clay-bearing unit," Curiosity is making a mile-long journey around some deep sand so that it can explore higher up Mount Sharp.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# February 12, 2023
#
#
# NASA's Mars Perseverance Rover Gets Its Sample Handling System
#
#
# The system will be collecting and storing Martian rock and soil. Its installation marks another milestone in the march toward the July launch period.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# February 11, 2023
#
#
# NASA's MAVEN Observes Martian Night Sky Pulsing in Ultraviolet Light
#
#
# Vast areas of the Martian night sky pulse in ultraviolet light, according to images from NASA’s MAVEN spacecraft. The results are being used to illuminate complex circulation patterns in the Martian atmosphere.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# February 7, 2023
#
#
# NASA's Perseverance Rover Will Carry First Spacesuit Materials to Mars
#
#
# In a Q&A, spacesuit designer Amy Ross explains how five samples, including a piece of helmet visor, will be tested aboard the rover, which is targeting a July 30 launch.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# More
#
#
#
#
#
#
#
#
#
#
#
#
# You Might Also Like
#
#
#
#
#   <a class=" prev" href="#carouselExampleIndicators2" role="button" data-slide="prev">
#                   <i class="fas fa-angle-left"></i>
#                   </a>
#                   <a class=" next" href="#carouselExampleIndicators2" role="button" data-slide="next">
#                   <i class="fas fa-angle-right"></i>
#                   </a>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# NASA to Broadcast Mars 2020 Perseverance Launch, Prelaunch Activities
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# The Launch Is Approaching for NASA's Next Mars Rover, Perseverance
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# NASA to Hold Mars 2020 Perseverance Rover Launch Briefing
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# With supporting text below as a natural lead-in to additional content.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# With supporting text below as a natural lead-in to additional content.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# With supporting text below as a natural lead-in to additional content.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# With supporting text below as a natural lead-in to additional content.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# With supporting text below as a natural lead-in to additional content.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# With supporting text below as a natural lead-in to additional content.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# The Red Planet
#
#
#
#
# Dashboard
#
#
# Science Goals
#
#
# The Planet
#
#
#
#
#
#
#
#
# The Program
#
#
#
#
# Mission Statement
#
#
# About the Program
#
#
# Organization Why Mars?
#
#
#
#
#
#
#
#
# Multimedia
#
#
#
#
# Images
#
#
# Videos
#
#
# More Resources
#
#
#
#
#
#
#
#
# Missions
#
#
#
#
# Past
#
#
# Present
#
#
# Future

# %% [markdown]
# ### Step 3: Store the Results
#
# Extract the titles and preview text of the news articles that you scraped. Store the scraping results in Python data structures as follows:
#
# * Store each title-and-preview pair in a Python dictionary. And, give each dictionary two keys: `title` and `preview`. An example is the following:
#
#   ```python
#   {'title': "Mars Rover Begins Mission!",
#         'preview': "NASA's Mars Rover begins a multiyear mission to collect data about the little-explored planet."}
#   ```
#
# * Store all the dictionaries in a Python list.
#
# * Print the list in your notebook.

# %%
div = html_soup.find_all("div")
print(div)
# Out:
# [<div class="col-md-12">
# <div class="row">
# <nav class="navbar navbar-expand-lg navbar-light fixed-top">
# <div class="container-fluid">
# <a class="navbar-brand" href="#">
# <img src="image/nasa.png" width="80"/><span class="logo">MARS Planet Science</span>
# <span class="logo1">Exploration Program</span>
# </a>
# <button aria-controls="navbarNav" aria-expanded="false" aria-label="Toggle navigation" class="navbar-toggler" data-bs-target="#navbarNav" data-bs-toggle="collapse" type="button">
# <span class="navbar-toggler-icon"></span>
# </button>
# <div class="collapse navbar-collapse justify-content-end" id="navbarNav">
# <ul class="navbar-nav">
# <li class="nav-item">
# <a aria-current="page" class="nav-link active" href="#">The Red Planet</a>
# </li>
# <li class="nav-item">
# <a class="nav-link" href="#">The Program</a>
# </li>
# <li class="nav-item">
# <a class="nav-link" href="#">News &amp; Events</a>
# </li>
# <li class="nav-item">
# <a class="nav-link" href="#">Multimedia</a>
# </li>
# <li class="nav-item">
# <a class="nav-link" href="#">Missions</a>
# </li>
# <li class="nav-item">
# <a class="nav-link" href="#">More</a>
# </li>
# <li class="nav-item nav_search">
# <a class="nav-link" href="#"></a>
# </li>
# </ul>
# </div>
# </div>
# </nav>
# <section class="search">
# <div class="container">
# <h1>News</h1>
# <div class="col-md-12 filter">
# <div class="row">
# <div class="col-md-3 search_binder">
# <input class="search_field" name="search" type="text"/>
# <input class="search_submit" name="search" type="text"/>
# </div>
# <div class="col-md-3">
# <select aria-label="Default select example" class="form-select" id="year">
# <option selected="">Latest</option>
# <option>2020</option><option>2019</option></select>
# </div>
# <div class="col-md-3">
# <select aria-label="Default select example" class="form-select" id="cat">
# <option selected="">All Categories</option>
# <option>Feature Stories</option><option>Status Reports</option><option>Press Releases</option></select>
# </div>
# <div class="col-md-3">
# </div>
# </div>
# </div>
# </div>
# </section>
# <section class="image_and_description_container">
# <div class="container" id="news">
# <div class="col-md-12">
# <hr/>
# <div class="row">
# <div class="col-md-4">
# <div class="list_image">
# <img src="https://mars.nasa.gov/system/news_items/list_view_images/8595_mars_winds_preview_4-320x240.jpg"/>
# </div>
# </div>
# <div class="col-md-8">
# <div class="list_text">
# <div class="list_date">March 7, 2023</div>
# <div class="content_title">NASA's MAVEN Maps Winds in the Martian Upper Atmosphere that Mirror the Terrain Below and Gives Clues to Martian Climate</div>
# <div class="article_teaser_body">Researchers have created the first map of wind circulation in the upper atmosphere of a planet besides Earth, using data from NASA’s MAVEN spacecraft that were collected during the last two years.</div>
# </div>
# </div>
# </div>
# </div>
# <div class="col-md-12">
# <hr/>
# <div class="row">
# <div class="col-md-4">
# <div class="list_image">
# <img src="https://mars.nasa.gov/system/news_items/list_view_images/8792_parachute-320x240.jpg"/>
# </div>
# </div>
# <div class="col-md-8">
# <div class="list_text">
# <div class="list_date">March 6, 2023</div>
# <div class="content_title">NASA's Perseverance Rover 100 Days Out</div>
# <div class="article_teaser_body">Mark your calendars: The agency's latest rover has only about 8,640,000 seconds to go before it touches down on the Red Planet, becoming history's next Mars car.</div>
# </div>
# </div>
# </div>
# </div>
# <div class="col-md-12">
# <hr/>
# <div class="row">
# <div class="col-md-4">
# <div class="list_image">
# <img src="https://mars.nasa.gov/system/news_items/list_view_images/8776_PIA24098-320.gif"/>
# </div>
# </div>
# <div class="col-md-8">
# <div class="list_text">
# <div class="list_date">March 5, 2023</div>
# <div class="content_title">NASA InSight's 'Mole' Is Out of Sight</div>
# <div class="article_teaser_body">Now that the heat probe is just below the Martian surface, InSight's arm will scoop some additional soil on top to help it keep digging so it can take Mars' temperature.</div>
# </div>
# </div>
# </div>
# </div>
# <div class="col-md-12">
# <hr/>
# <div class="row">
# <div class="col-md-4">
# <div class="list_image">
# <img src="https://mars.nasa.gov/system/news_items/list_view_images/8710_MARS2020_LAUNCH_320.jpg"/>
# </div>
# </div>
# <div class="col-md-8">
# <div class="list_text">
# <div class="list_date">March 5, 2023</div>
# <div class="content_title">Join NASA for the Launch of the Mars 2020 Perseverance Rover</div>
# <div class="article_teaser_body">No matter where you live, choose from a menu of activities to join NASA as we "Countdown to Mars" and launch the Perseverance rover to the Red Planet.</div>
# </div>
# </div>
# </div>
# </div>
# <div class="col-md-12">
# <hr/>
# <div class="row">
# <div class="col-md-4">
# <div class="list_image">
# <img src="https://mars.nasa.gov/system/news_items/list_view_images/8675_Webby_main_320x240.jpg"/>
# </div>
# </div>
# <div class="col-md-8">
# <div class="list_text">
# <div class="list_date">February 28, 2023</div>
# <div class="content_title">NASA Wins 4 Webbys, 4 People's Voice Awards</div>
# <div class="article_teaser_body">Winners include the JPL-managed "Send Your Name to Mars" campaign, NASA's Global Climate Change website and Solar System Interactive.</div>
# </div>
# </div>
# </div>
# </div>
# <div class="col-md-12">
# <hr/>
# <div class="row">
# <div class="col-md-4">
# <div class="list_image">
# <img src="https://mars.nasa.gov/system/news_items/list_view_images/8678_21379_PIA22107-320x240.jpg"/>
# </div>
# </div>
# <div class="col-md-8">
# <div class="list_text">
# <div class="list_date">February 26, 2023</div>
# <div class="content_title">The Detective Aboard NASA's Perseverance Rover</div>
# <div class="article_teaser_body">An instrument called SHERLOC will, with the help of its partner WATSON, hunt for signs of ancient life by detecting organic molecules and minerals.</div>
# </div>
# </div>
# </div>
# </div>
# <div class="col-md-12">
# <hr/>
# <div class="row">
# <div class="col-md-4">
# <div class="list_image">
# <img src="https://mars.nasa.gov/system/news_items/list_view_images/8647_PIA23773-32x24.jpg"/>
# </div>
# </div>
# <div class="col-md-8">
# <div class="list_text">
# <div class="list_date">February 24, 2023</div>
# <div class="content_title">NASA's Curiosity Keeps Rolling As Team Operates Rover From Home</div>
# <div class="article_teaser_body">The team has learned to meet new challenges as they work remotely on the Mars mission.</div>
# </div>
# </div>
# </div>
# </div>
# <div class="col-md-12">
# <hr/>
# <div class="row">
# <div class="col-md-4">
# <div class="list_image">
# <img src="https://mars.nasa.gov/system/news_items/list_view_images/8817_PIA23180_320.gif"/>
# </div>
# </div>
# <div class="col-md-8">
# <div class="list_text">
# <div class="list_date">February 18, 2023</div>
# <div class="content_title">3 Things We've Learned From NASA's Mars InSight </div>
# <div class="article_teaser_body">Scientists are finding new mysteries since the geophysics mission landed two years ago.</div>
# </div>
# </div>
# </div>
# </div>
# <div class="col-md-12">
# <hr/>
# <div class="row">
# <div class="col-md-4">
# <div class="list_image">
# <img src="https://mars.nasa.gov/system/news_items/list_view_images/8520_PIA23466-226.jpg"/>
# </div>
# </div>
# <div class="col-md-8">
# <div class="list_text">
# <div class="list_date">February 18, 2023</div>
# <div class="content_title">NASA's Mars 2020 Rover Tests Descent-Stage Separation</div>
# <div class="article_teaser_body">A crane lifts the rocket-powered descent stage away from NASA's Mars 2020 rover after technicians tested the pyrotechnic charges that separate the two spacecraft.</div>
# </div>
# </div>
# </div>
# </div>
# <div class="col-md-12">
# <hr/>
# <div class="row">
# <div class="col-md-4">
# <div class="list_image">
# <img src="https://mars.nasa.gov/system/news_items/list_view_images/8707_PIA23764-320.jpg"/>
# </div>
# </div>
# <div class="col-md-8">
# <div class="list_text">
# <div class="list_date">February 17, 2023</div>
# <div class="content_title">7 Things to Know About the Mars 2020 Perseverance Rover Mission</div>
# <div class="article_teaser_body">NASA's next rover to the Red Planet is slated to launch no earlier than July 30. These highlights will get you up to speed on the ambitious mission.</div>
# </div>
# </div>
# </div>
# </div>
# <div class="col-md-12">
# <hr/>
# <div class="row">
# <div class="col-md-4">
# <div class="list_image">
# <img src="https://mars.nasa.gov/system/news_items/list_view_images/8654_MAIN-IMAGE-PIA23881-320x240.jpg"/>
# </div>
# </div>
# <div class="col-md-8">
# <div class="list_text">
# <div class="list_date">February 17, 2023</div>
# <div class="content_title">How NASA's Perseverance Mars Team Adjusted to Work in the Time of Coronavirus </div>
# <div class="article_teaser_body">Like much of the rest of the world, the Mars rover team is pushing forward with its mission-critical work while putting the health and safety of their colleagues and community first.</div>
# </div>
# </div>
# </div>
# </div>
# <div class="col-md-12">
# <hr/>
# <div class="row">
# <div class="col-md-4">
# <div class="list_image">
# <img src="https://mars.nasa.gov/system/news_items/list_view_images/8704_PIA23973-320x240.jpg"/>
# </div>
# </div>
# <div class="col-md-8">
# <div class="list_text">
# <div class="list_date">February 15, 2023</div>
# <div class="content_title">Curiosity Mars Rover's Summer Road Trip Has Begun</div>
# <div class="article_teaser_body">After more than a year in the "clay-bearing unit," Curiosity is making a mile-long journey around some deep sand so that it can explore higher up Mount Sharp.</div>
# </div>
# </div>
# </div>
# </div>
# <div class="col-md-12">
# <hr/>
# <div class="row">
# <div class="col-md-4">
# <div class="list_image">
# <img src="https://mars.nasa.gov/system/news_items/list_view_images/8630_PIA23768-320x240.jpg"/>
# </div>
# </div>
# <div class="col-md-8">
# <div class="list_text">
# <div class="list_date">February 12, 2023</div>
# <div class="content_title">NASA's Mars Perseverance Rover Gets Its Sample Handling System</div>
# <div class="article_teaser_body">The system will be collecting and storing Martian rock and soil. Its installation marks another milestone in the march toward the July launch period.</div>
# </div>
# </div>
# </div>
# </div>
# <div class="col-md-12">
# <hr/>
# <div class="row">
# <div class="col-md-4">
# <div class="list_image">
# <img src="https://mars.nasa.gov/system/news_items/list_view_images/8731_MAVEN_nightglow_pulsating_spot-320x240.jpg"/>
# </div>
# </div>
# <div class="col-md-8">
# <div class="list_text">
# <div class="list_date">February 11, 2023</div>
# <div class="content_title">NASA's MAVEN Observes Martian Night Sky Pulsing in Ultraviolet Light</div>
# <div class="article_teaser_body">Vast areas of the Martian night sky pulse in ultraviolet light, according to images from NASA’s MAVEN spacecraft. The results are being used to illuminate complex circulation patterns in the Martian atmosphere.</div>
# </div>
# </div>
# </div>
# </div>
# <div class="col-md-12">
# <hr/>
# <div class="row">
# <div class="col-md-4">
# <div class="list_image">
# <img src="https://mars.nasa.gov/system/news_items/list_view_images/8723_PIA24031-320.jpg"/>
# </div>
# </div>
# <div class="col-md-8">
# <div class="list_text">
# <div class="list_date">February 7, 2023</div>
# <div class="content_title">NASA's Perseverance Rover Will Carry First Spacesuit Materials to Mars</div>
# <div class="article_teaser_body">In a Q&amp;A, spacesuit designer Amy Ross explains how five samples, including a piece of helmet visor, will be tested aboard the rover, which is targeting a July 30 launch. </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <hr class="container" style="margin: 25px auto;width: 83%;"/>
# <button class="btn disable" id="more" onclick="populateContent()">More</button>
# </section>
# <section class="last_news">
# <div class="container">
# <div class="row">
# <div class="col-12">
# <h2>You Might Also Like</h2>
# </div>
# <!--  <a class=" prev" href="#carouselExampleIndicators2" role="button" data-slide="prev">
#                   <i class="fas fa-angle-left"></i>
#                   </a>
#                   <a class=" next" href="#carouselExampleIndicators2" role="button" data-slide="next">
#                   <i class="fas fa-angle-right"></i>
#                   </a> -->
# <div class="col-12">
# <div class="carousel slide" data-ride="carousel" id="carouselExampleIndicators2">
# <div class="carousel-inner">
# <div class="carousel-item active">
# <div class="row">
# <div class="col-md-4 mb-3">
# <div class="card">
# <img alt="100%x280" class="img-fluid" src="https://mars.nasa.gov/system/news_items/main_images/8716_PIA23499-16.jpg"/>
# <div class="card-body">
# <p class="card-text">NASA to Broadcast Mars 2020 Perseverance Launch, Prelaunch Activities</p>
# </div>
# </div>
# </div>
# <div class="col-md-4 mb-3">
# <div class="card">
# <img alt="100%x280" class="img-fluid" src="https://mars.nasa.gov/system/news_items/main_images/8716_PIA23499-16.jpg"/>
# <div class="card-body">
# <p class="card-text">The Launch Is Approaching for NASA's Next Mars Rover, Perseverance</p>
# </div>
# </div>
# </div>
# <div class="col-md-4 mb-3">
# <div class="card">
# <img alt="100%x280" class="img-fluid" src="https://mars.nasa.gov/system/news_items/main_images/8692_PIA23920-web.jpg"/>
# <div class="card-body">
# <p class="card-text">NASA to Hold Mars 2020 Perseverance Rover Launch Briefing</p>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="carousel-item">
# <div class="row">
# <div class="col-md-4 mb-3">
# <div class="card">
# <img alt="100%x280" class="img-fluid" src="https://images.unsplash.com/photo-1532771098148-525cefe10c23?ixlib=rb-0.3.5&amp;q=80&amp;fm=jpg&amp;crop=entropy&amp;cs=tinysrgb&amp;w=1080&amp;fit=max&amp;ixid=eyJhcHBfaWQiOjMyMDc0fQ&amp;s=3f317c1f7a16116dec454fbc267dd8e4"/>
# <div class="card-body">
# <p class="card-text">With supporting text below as a natural lead-in to additional content.</p>
# </div>
# </div>
# </div>
# <div class="col-md-4 mb-3">
# <div class="card">
# <img alt="100%x280" class="img-fluid" src="https://images.unsplash.com/photo-1532715088550-62f09305f765?ixlib=rb-0.3.5&amp;q=80&amp;fm=jpg&amp;crop=entropy&amp;cs=tinysrgb&amp;w=1080&amp;fit=max&amp;ixid=eyJhcHBfaWQiOjMyMDc0fQ&amp;s=ebadb044b374504ef8e81bdec4d0e840"/>
# <div class="card-body">
# <p class="card-text">With supporting text below as a natural lead-in to additional content.</p>
# </div>
# </div>
# </div>
# <div class="col-md-4 mb-3">
# <div class="card">
# <img alt="100%x280" class="img-fluid" src="https://images.unsplash.com/photo-1506197603052-3cc9c3a201bd?ixlib=rb-0.3.5&amp;q=80&amp;fm=jpg&amp;crop=entropy&amp;cs=tinysrgb&amp;w=1080&amp;fit=max&amp;ixid=eyJhcHBfaWQiOjMyMDc0fQ&amp;s=0754ab085804ae8a3b562548e6b4aa2e"/>
# <div class="card-body">
# <p class="card-text">With supporting text below as a natural lead-in to additional content.</p>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="carousel-item">
# <div class="row">
# <div class="col-md-4 mb-3">
# <div class="card">
# <img alt="100%x280" class="img-fluid" src="https://images.unsplash.com/photo-1507525428034-b723cf961d3e?ixlib=rb-0.3.5&amp;q=80&amp;fm=jpg&amp;crop=entropy&amp;cs=tinysrgb&amp;w=1080&amp;fit=max&amp;ixid=eyJhcHBfaWQiOjMyMDc0fQ&amp;s=ee8417f0ea2a50d53a12665820b54e23"/>
# <div class="card-body">
# <p class="card-text">With supporting text below as a natural lead-in to additional content.</p>
# </div>
# </div>
# </div>
# <div class="col-md-4 mb-3">
# <div class="card">
# <img alt="100%x280" class="img-fluid" src="https://images.unsplash.com/photo-1532777946373-b6783242f211?ixlib=rb-0.3.5&amp;q=80&amp;fm=jpg&amp;crop=entropy&amp;cs=tinysrgb&amp;w=1080&amp;fit=max&amp;ixid=eyJhcHBfaWQiOjMyMDc0fQ&amp;s=8ac55cf3a68785643998730839663129"/>
# <div class="card-body">
# <p class="card-text">With supporting text below as a natural lead-in to additional content.</p>
# </div>
# </div>
# </div>
# <div class="col-md-4 mb-3">
# <div class="card">
# <img alt="100%x280" class="img-fluid" src="https://images.unsplash.com/photo-1532763303805-529d595877c5?ixlib=rb-0.3.5&amp;q=80&amp;fm=jpg&amp;crop=entropy&amp;cs=tinysrgb&amp;w=1080&amp;fit=max&amp;ixid=eyJhcHBfaWQiOjMyMDc0fQ&amp;s=5ee4fd5d19b40f93eadb21871757eda6"/>
# <div class="card-body">
# <p class="card-text">With supporting text below as a natural lead-in to additional content.</p>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </section>
# <section class="footer">
# <div class="container">
# <div class="col-md-12">
# <div class="row">
# <div class="col-md-3">
# <h5>The Red Planet</h5>
# <ul>
# <li>Dashboard</li>
# <li>Science Goals</li>
# <li>The Planet</li>
# </ul>
# </div>
# <div class="col-md-3">
# <h5>The Program</h5>
# <ul>
# <li>Mission Statement</li>
# <li>About the Program</li>
# <li>Organization Why Mars?</li>
# </ul>
# </div>
# <div class="col-md-3">
# <h5>Multimedia</h5>
# <ul>
# <li>Images</li>
# <li>Videos</li>
# <li>More Resources</li>
# </ul>
# </div>
# <div class="col-md-3">
# <h5>Missions</h5>
# <ul>
# <li>Past</li>
# <li>Present</li>
# <li>Future</li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </section>
# <script src="https://code.jquery.com/jquery-1.12.4.min.js" type="text/javascript"></script>
# <script src="https://cdn.jsdelivr.net/npm/@popperjs/core@2.5.4/dist/umd/popper.min.js"></script>
# <script src="https://cdn.jsdelivr.net/npm/bootstrap@5.0.0-beta1/dist/js/bootstrap.min.js"></script>
# <script src="js/app.js"></script>
# </div></div>, <div class="row">
# <nav class="navbar navbar-expand-lg navbar-light fixed-top">
# <div class="container-fluid">
# <a class="navbar-brand" href="#">
# <img src="image/nasa.png" width="80"/><span class="logo">MARS Planet Science</span>
# <span class="logo1">Exploration Program</span>
# </a>
# <button aria-controls="navbarNav" aria-expanded="false" aria-label="Toggle navigation" class="navbar-toggler" data-bs-target="#navbarNav" data-bs-toggle="collapse" type="button">
# <span class="navbar-toggler-icon"></span>
# </button>
# <div class="collapse navbar-collapse justify-content-end" id="navbarNav">
# <ul class="navbar-nav">
# <li class="nav-item">
# <a aria-current="page" class="nav-link active" href="#">The Red Planet</a>
# </li>
# <li class="nav-item">
# <a class="nav-link" href="#">The Program</a>
# </li>
# <li class="nav-item">
# <a class="nav-link" href="#">News &amp; Events</a>
# </li>
# <li class="nav-item">
# <a class="nav-link" href="#">Multimedia</a>
# </li>
# <li class="nav-item">
# <a class="nav-link" href="#">Missions</a>
# </li>
# <li class="nav-item">
# <a class="nav-link" href="#">More</a>
# </li>
# <li class="nav-item nav_search">
# <a class="nav-link" href="#"></a>
# </li>
# </ul>
# </div>
# </div>
# </nav>
# <section class="search">
# <div class="container">
# <h1>News</h1>
# <div class="col-md-12 filter">
# <div class="row">
# <div class="col-md-3 search_binder">
# <input class="search_field" name="search" type="text"/>
# <input class="search_submit" name="search" type="text"/>
# </div>
# <div class="col-md-3">
# <select aria-label="Default select example" class="form-select" id="year">
# <option selected="">Latest</option>
# <option>2020</option><option>2019</option></select>
# </div>
# <div class="col-md-3">
# <select aria-label="Default select example" class="form-select" id="cat">
# <option selected="">All Categories</option>
# <option>Feature Stories</option><option>Status Reports</option><option>Press Releases</option></select>
# </div>
# <div class="col-md-3">
# </div>
# </div>
# </div>
# </div>
# </section>
# <section class="image_and_description_container">
# <div class="container" id="news">
# <div class="col-md-12">
# <hr/>
# <div class="row">
# <div class="col-md-4">
# <div class="list_image">
# <img src="https://mars.nasa.gov/system/news_items/list_view_images/8595_mars_winds_preview_4-320x240.jpg"/>
# </div>
# </div>
# <div class="col-md-8">
# <div class="list_text">
# <div class="list_date">March 7, 2023</div>
# <div class="content_title">NASA's MAVEN Maps Winds in the Martian Upper Atmosphere that Mirror the Terrain Below and Gives Clues to Martian Climate</div>
# <div class="article_teaser_body">Researchers have created the first map of wind circulation in the upper atmosphere of a planet besides Earth, using data from NASA’s MAVEN spacecraft that were collected during the last two years.</div>
# </div>
# </div>
# </div>
# </div>
# <div class="col-md-12">
# <hr/>
# <div class="row">
# <div class="col-md-4">
# <div class="list_image">
# <img src="https://mars.nasa.gov/system/news_items/list_view_images/8792_parachute-320x240.jpg"/>
# </div>
# </div>
# <div class="col-md-8">
# <div class="list_text">
# <div class="list_date">March 6, 2023</div>
# <div class="content_title">NASA's Perseverance Rover 100 Days Out</div>
# <div class="article_teaser_body">Mark your calendars: The agency's latest rover has only about 8,640,000 seconds to go before it touches down on the Red Planet, becoming history's next Mars car.</div>
# </div>
# </div>
# </div>
# </div>
# <div class="col-md-12">
# <hr/>
# <div class="row">
# <div class="col-md-4">
# <div class="list_image">
# <img src="https://mars.nasa.gov/system/news_items/list_view_images/8776_PIA24098-320.gif"/>
# </div>
# </div>
# <div class="col-md-8">
# <div class="list_text">
# <div class="list_date">March 5, 2023</div>
# <div class="content_title">NASA InSight's 'Mole' Is Out of Sight</div>
# <div class="article_teaser_body">Now that the heat probe is just below the Martian surface, InSight's arm will scoop some additional soil on top to help it keep digging so it can take Mars' temperature.</div>
# </div>
# </div>
# </div>
# </div>
# <div class="col-md-12">
# <hr/>
# <div class="row">
# <div class="col-md-4">
# <div class="list_image">
# <img src="https://mars.nasa.gov/system/news_items/list_view_images/8710_MARS2020_LAUNCH_320.jpg"/>
# </div>
# </div>
# <div class="col-md-8">
# <div class="list_text">
# <div class="list_date">March 5, 2023</div>
# <div class="content_title">Join NASA for the Launch of the Mars 2020 Perseverance Rover</div>
# <div class="article_teaser_body">No matter where you live, choose from a menu of activities to join NASA as we "Countdown to Mars" and launch the Perseverance rover to the Red Planet.</div>
# </div>
# </div>
# </div>
# </div>
# <div class="col-md-12">
# <hr/>
# <div class="row">
# <div class="col-md-4">
# <div class="list_image">
# <img src="https://mars.nasa.gov/system/news_items/list_view_images/8675_Webby_main_320x240.jpg"/>
# </div>
# </div>
# <div class="col-md-8">
# <div class="list_text">
# <div class="list_date">February 28, 2023</div>
# <div class="content_title">NASA Wins 4 Webbys, 4 People's Voice Awards</div>
# <div class="article_teaser_body">Winners include the JPL-managed "Send Your Name to Mars" campaign, NASA's Global Climate Change website and Solar System Interactive.</div>
# </div>
# </div>
# </div>
# </div>
# <div class="col-md-12">
# <hr/>
# <div class="row">
# <div class="col-md-4">
# <div class="list_image">
# <img src="https://mars.nasa.gov/system/news_items/list_view_images/8678_21379_PIA22107-320x240.jpg"/>
# </div>
# </div>
# <div class="col-md-8">
# <div class="list_text">
# <div class="list_date">February 26, 2023</div>
# <div class="content_title">The Detective Aboard NASA's Perseverance Rover</div>
# <div class="article_teaser_body">An instrument called SHERLOC will, with the help of its partner WATSON, hunt for signs of ancient life by detecting organic molecules and minerals.</div>
# </div>
# </div>
# </div>
# </div>
# <div class="col-md-12">
# <hr/>
# <div class="row">
# <div class="col-md-4">
# <div class="list_image">
# <img src="https://mars.nasa.gov/system/news_items/list_view_images/8647_PIA23773-32x24.jpg"/>
# </div>
# </div>
# <div class="col-md-8">
# <div class="list_text">
# <div class="list_date">February 24, 2023</div>
# <div class="content_title">NASA's Curiosity Keeps Rolling As Team Operates Rover From Home</div>
# <div class="article_teaser_body">The team has learned to meet new challenges as they work remotely on the Mars mission.</div>
# </div>
# </div>
# </div>
# </div>
# <div class="col-md-12">
# <hr/>
# <div class="row">
# <div class="col-md-4">
# <div class="list_image">
# <img src="https://mars.nasa.gov/system/news_items/list_view_images/8817_PIA23180_320.gif"/>
# </div>
# </div>
# <div class="col-md-8">
# <div class="list_text">
# <div class="list_date">February 18, 2023</div>
# <div class="content_title">3 Things We've Learned From NASA's Mars InSight </div>
# <div class="article_teaser_body">Scientists are finding new mysteries since the geophysics mission landed two years ago.</div>
# </div>
# </div>
# </div>
# </div>
# <div class="col-md-12">
# <hr/>
# <div class="row">
# <div class="col-md-4">
# <div class="list_image">
# <img src="https://mars.nasa.gov/system/news_items/list_view_images/8520_PIA23466-226.jpg"/>
# </div>
# </div>
# <div class="col-md-8">
# <div class="list_text">
# <div class="list_date">February 18, 2023</div>
# <div class="content_title">NASA's Mars 2020 Rover Tests Descent-Stage Separation</div>
# <div class="article_teaser_body">A crane lifts the rocket-powered descent stage away from NASA's Mars 2020 rover after technicians tested the pyrotechnic charges that separate the two spacecraft.</div>
# </div>
# </div>
# </div>
# </div>
# <div class="col-md-12">
# <hr/>
# <div class="row">
# <div class="col-md-4">
# <div class="list_image">
# <img src="https://mars.nasa.gov/system/news_items/list_view_images/8707_PIA23764-320.jpg"/>
# </div>
# </div>
# <div class="col-md-8">
# <div class="list_text">
# <div class="list_date">February 17, 2023</div>
# <div class="content_title">7 Things to Know About the Mars 2020 Perseverance Rover Mission</div>
# <div class="article_teaser_body">NASA's next rover to the Red Planet is slated to launch no earlier than July 30. These highlights will get you up to speed on the ambitious mission.</div>
# </div>
# </div>
# </div>
# </div>
# <div class="col-md-12">
# <hr/>
# <div class="row">
# <div class="col-md-4">
# <div class="list_image">
# <img src="https://mars.nasa.gov/system/news_items/list_view_images/8654_MAIN-IMAGE-PIA23881-320x240.jpg"/>
# </div>
# </div>
# <div class="col-md-8">
# <div class="list_text">
# <div class="list_date">February 17, 2023</div>
# <div class="content_title">How NASA's Perseverance Mars Team Adjusted to Work in the Time of Coronavirus </div>
# <div class="article_teaser_body">Like much of the rest of the world, the Mars rover team is pushing forward with its mission-critical work while putting the health and safety of their colleagues and community first.</div>
# </div>
# </div>
# </div>
# </div>
# <div class="col-md-12">
# <hr/>
# <div class="row">
# <div class="col-md-4">
# <div class="list_image">
# <img src="https://mars.nasa.gov/system/news_items/list_view_images/8704_PIA23973-320x240.jpg"/>
# </div>
# </div>
# <div class="col-md-8">
# <div class="list_text">
# <div class="list_date">February 15, 2023</div>
# <div class="content_title">Curiosity Mars Rover's Summer Road Trip Has Begun</div>
# <div class="article_teaser_body">After more than a year in the "clay-bearing unit," Curiosity is making a mile-long journey around some deep sand so that it can explore higher up Mount Sharp.</div>
# </div>
# </div>
# </div>
# </div>
# <div class="col-md-12">
# <hr/>
# <div class="row">
# <div class="col-md-4">
# <div class="list_image">
# <img src="https://mars.nasa.gov/system/news_items/list_view_images/8630_PIA23768-320x240.jpg"/>
# </div>
# </div>
# <div class="col-md-8">
# <div class="list_text">
# <div class="list_date">February 12, 2023</div>
# <div class="content_title">NASA's Mars Perseverance Rover Gets Its Sample Handling System</div>
# <div class="article_teaser_body">The system will be collecting and storing Martian rock and soil. Its installation marks another milestone in the march toward the July launch period.</div>
# </div>
# </div>
# </div>
# </div>
# <div class="col-md-12">
# <hr/>
# <div class="row">
# <div class="col-md-4">
# <div class="list_image">
# <img src="https://mars.nasa.gov/system/news_items/list_view_images/8731_MAVEN_nightglow_pulsating_spot-320x240.jpg"/>
# </div>
# </div>
# <div class="col-md-8">
# <div class="list_text">
# <div class="list_date">February 11, 2023</div>
# <div class="content_title">NASA's MAVEN Observes Martian Night Sky Pulsing in Ultraviolet Light</div>
# <div class="article_teaser_body">Vast areas of the Martian night sky pulse in ultraviolet light, according to images from NASA’s MAVEN spacecraft. The results are being used to illuminate complex circulation patterns in the Martian atmosphere.</div>
# </div>
# </div>
# </div>
# </div>
# <div class="col-md-12">
# <hr/>
# <div class="row">
# <div class="col-md-4">
# <div class="list_image">
# <img src="https://mars.nasa.gov/system/news_items/list_view_images/8723_PIA24031-320.jpg"/>
# </div>
# </div>
# <div class="col-md-8">
# <div class="list_text">
# <div class="list_date">February 7, 2023</div>
# <div class="content_title">NASA's Perseverance Rover Will Carry First Spacesuit Materials to Mars</div>
# <div class="article_teaser_body">In a Q&amp;A, spacesuit designer Amy Ross explains how five samples, including a piece of helmet visor, will be tested aboard the rover, which is targeting a July 30 launch. </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <hr class="container" style="margin: 25px auto;width: 83%;"/>
# <button class="btn disable" id="more" onclick="populateContent()">More</button>
# </section>
# <section class="last_news">
# <div class="container">
# <div class="row">
# <div class="col-12">
# <h2>You Might Also Like</h2>
# </div>
# <!--  <a class=" prev" href="#carouselExampleIndicators2" role="button" data-slide="prev">
#                   <i class="fas fa-angle-left"></i>
#                   </a>
#                   <a class=" next" href="#carouselExampleIndicators2" role="button" data-slide="next">
#                   <i class="fas fa-angle-right"></i>
#                   </a> -->
# <div class="col-12">
# <div class="carousel slide" data-ride="carousel" id="carouselExampleIndicators2">
# <div class="carousel-inner">
# <div class="carousel-item active">
# <div class="row">
# <div class="col-md-4 mb-3">
# <div class="card">
# <img alt="100%x280" class="img-fluid" src="https://mars.nasa.gov/system/news_items/main_images/8716_PIA23499-16.jpg"/>
# <div class="card-body">
# <p class="card-text">NASA to Broadcast Mars 2020 Perseverance Launch, Prelaunch Activities</p>
# </div>
# </div>
# </div>
# <div class="col-md-4 mb-3">
# <div class="card">
# <img alt="100%x280" class="img-fluid" src="https://mars.nasa.gov/system/news_items/main_images/8716_PIA23499-16.jpg"/>
# <div class="card-body">
# <p class="card-text">The Launch Is Approaching for NASA's Next Mars Rover, Perseverance</p>
# </div>
# </div>
# </div>
# <div class="col-md-4 mb-3">
# <div class="card">
# <img alt="100%x280" class="img-fluid" src="https://mars.nasa.gov/system/news_items/main_images/8692_PIA23920-web.jpg"/>
# <div class="card-body">
# <p class="card-text">NASA to Hold Mars 2020 Perseverance Rover Launch Briefing</p>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="carousel-item">
# <div class="row">
# <div class="col-md-4 mb-3">
# <div class="card">
# <img alt="100%x280" class="img-fluid" src="https://images.unsplash.com/photo-1532771098148-525cefe10c23?ixlib=rb-0.3.5&amp;q=80&amp;fm=jpg&amp;crop=entropy&amp;cs=tinysrgb&amp;w=1080&amp;fit=max&amp;ixid=eyJhcHBfaWQiOjMyMDc0fQ&amp;s=3f317c1f7a16116dec454fbc267dd8e4"/>
# <div class="card-body">
# <p class="card-text">With supporting text below as a natural lead-in to additional content.</p>
# </div>
# </div>
# </div>
# <div class="col-md-4 mb-3">
# <div class="card">
# <img alt="100%x280" class="img-fluid" src="https://images.unsplash.com/photo-1532715088550-62f09305f765?ixlib=rb-0.3.5&amp;q=80&amp;fm=jpg&amp;crop=entropy&amp;cs=tinysrgb&amp;w=1080&amp;fit=max&amp;ixid=eyJhcHBfaWQiOjMyMDc0fQ&amp;s=ebadb044b374504ef8e81bdec4d0e840"/>
# <div class="card-body">
# <p class="card-text">With supporting text below as a natural lead-in to additional content.</p>
# </div>
# </div>
# </div>
# <div class="col-md-4 mb-3">
# <div class="card">
# <img alt="100%x280" class="img-fluid" src="https://images.unsplash.com/photo-1506197603052-3cc9c3a201bd?ixlib=rb-0.3.5&amp;q=80&amp;fm=jpg&amp;crop=entropy&amp;cs=tinysrgb&amp;w=1080&amp;fit=max&amp;ixid=eyJhcHBfaWQiOjMyMDc0fQ&amp;s=0754ab085804ae8a3b562548e6b4aa2e"/>
# <div class="card-body">
# <p class="card-text">With supporting text below as a natural lead-in to additional content.</p>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="carousel-item">
# <div class="row">
# <div class="col-md-4 mb-3">
# <div class="card">
# <img alt="100%x280" class="img-fluid" src="https://images.unsplash.com/photo-1507525428034-b723cf961d3e?ixlib=rb-0.3.5&amp;q=80&amp;fm=jpg&amp;crop=entropy&amp;cs=tinysrgb&amp;w=1080&amp;fit=max&amp;ixid=eyJhcHBfaWQiOjMyMDc0fQ&amp;s=ee8417f0ea2a50d53a12665820b54e23"/>
# <div class="card-body">
# <p class="card-text">With supporting text below as a natural lead-in to additional content.</p>
# </div>
# </div>
# </div>
# <div class="col-md-4 mb-3">
# <div class="card">
# <img alt="100%x280" class="img-fluid" src="https://images.unsplash.com/photo-1532777946373-b6783242f211?ixlib=rb-0.3.5&amp;q=80&amp;fm=jpg&amp;crop=entropy&amp;cs=tinysrgb&amp;w=1080&amp;fit=max&amp;ixid=eyJhcHBfaWQiOjMyMDc0fQ&amp;s=8ac55cf3a68785643998730839663129"/>
# <div class="card-body">
# <p class="card-text">With supporting text below as a natural lead-in to additional content.</p>
# </div>
# </div>
# </div>
# <div class="col-md-4 mb-3">
# <div class="card">
# <img alt="100%x280" class="img-fluid" src="https://images.unsplash.com/photo-1532763303805-529d595877c5?ixlib=rb-0.3.5&amp;q=80&amp;fm=jpg&amp;crop=entropy&amp;cs=tinysrgb&amp;w=1080&amp;fit=max&amp;ixid=eyJhcHBfaWQiOjMyMDc0fQ&amp;s=5ee4fd5d19b40f93eadb21871757eda6"/>
# <div class="card-body">
# <p class="card-text">With supporting text below as a natural lead-in to additional content.</p>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </section>
# <section class="footer">
# <div class="container">
# <div class="col-md-12">
# <div class="row">
# <div class="col-md-3">
# <h5>The Red Planet</h5>
# <ul>
# <li>Dashboard</li>
# <li>Science Goals</li>
# <li>The Planet</li>
# </ul>
# </div>
# <div class="col-md-3">
# <h5>The Program</h5>
# <ul>
# <li>Mission Statement</li>
# <li>About the Program</li>
# <li>Organization Why Mars?</li>
# </ul>
# </div>
# <div class="col-md-3">
# <h5>Multimedia</h5>
# <ul>
# <li>Images</li>
# <li>Videos</li>
# <li>More Resources</li>
# </ul>
# </div>
# <div class="col-md-3">
# <h5>Missions</h5>
# <ul>
# <li>Past</li>
# <li>Present</li>
# <li>Future</li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </section>
# <script src="https://code.jquery.com/jquery-1.12.4.min.js" type="text/javascript"></script>
# <script src="https://cdn.jsdelivr.net/npm/@popperjs/core@2.5.4/dist/umd/popper.min.js"></script>
# <script src="https://cdn.jsdelivr.net/npm/bootstrap@5.0.0-beta1/dist/js/bootstrap.min.js"></script>
# <script src="js/app.js"></script>
# </div>, <div class="container-fluid">
# <a class="navbar-brand" href="#">
# <img src="image/nasa.png" width="80"/><span class="logo">MARS Planet Science</span>
# <span class="logo1">Exploration Program</span>
# </a>
# <button aria-controls="navbarNav" aria-expanded="false" aria-label="Toggle navigation" class="navbar-toggler" data-bs-target="#navbarNav" data-bs-toggle="collapse" type="button">
# <span class="navbar-toggler-icon"></span>
# </button>
# <div class="collapse navbar-collapse justify-content-end" id="navbarNav">
# <ul class="navbar-nav">
# <li class="nav-item">
# <a aria-current="page" class="nav-link active" href="#">The Red Planet</a>
# </li>
# <li class="nav-item">
# <a class="nav-link" href="#">The Program</a>
# </li>
# <li class="nav-item">
# <a class="nav-link" href="#">News &amp; Events</a>
# </li>
# <li class="nav-item">
# <a class="nav-link" href="#">Multimedia</a>
# </li>
# <li class="nav-item">
# <a class="nav-link" href="#">Missions</a>
# </li>
# <li class="nav-item">
# <a class="nav-link" href="#">More</a>
# </li>
# <li class="nav-item nav_search">
# <a class="nav-link" href="#"></a>
# </li>
# </ul>
# </div>
# </div>, <div class="collapse navbar-collapse justify-content-end" id="navbarNav">
# <ul class="navbar-nav">
# <li class="nav-item">
# <a aria-current="page" class="nav-link active" href="#">The Red Planet</a>
# </li>
# <li class="nav-item">
# <a class="nav-link" href="#">The Program</a>
# </li>
# <li class="nav-item">
# <a class="nav-link" href="#">News &amp; Events</a>
# </li>
# <li class="nav-item">
# <a class="nav-link" href="#">Multimedia</a>
# </li>
# <li class="nav-item">
# <a class="nav-link" href="#">Missions</a>
# </li>
# <li class="nav-item">
# <a class="nav-link" href="#">More</a>
# </li>
# <li class="nav-item nav_search">
# <a class="nav-link" href="#"></a>
# </li>
# </ul>
# </div>, <div class="container">
# <h1>News</h1>
# <div class="col-md-12 filter">
# <div class="row">
# <div class="col-md-3 search_binder">
# <input class="search_field" name="search" type="text"/>
# <input class="search_submit" name="search" type="text"/>
# </div>
# <div class="col-md-3">
# <select aria-label="Default select example" class="form-select" id="year">
# <option selected="">Latest</option>
# <option>2020</option><option>2019</option></select>
# </div>
# <div class="col-md-3">
# <select aria-label="Default select example" class="form-select" id="cat">
# <option selected="">All Categories</option>
# <option>Feature Stories</option><option>Status Reports</option><option>Press Releases</option></select>
# </div>
# <div class="col-md-3">
# </div>
# </div>
# </div>
# </div>, <div class="col-md-12 filter">
# <div class="row">
# <div class="col-md-3 search_binder">
# <input class="search_field" name="search" type="text"/>
# <input class="search_submit" name="search" type="text"/>
# </div>
# <div class="col-md-3">
# <select aria-label="Default select example" class="form-select" id="year">
# <option selected="">Latest</option>
# <option>2020</option><option>2019</option></select>
# </div>
# <div class="col-md-3">
# <select aria-label="Default select example" class="form-select" id="cat">
# <option selected="">All Categories</option>
# <option>Feature Stories</option><option>Status Reports</option><option>Press Releases</option></select>
# </div>
# <div class="col-md-3">
# </div>
# </div>
# </div>, <div class="row">
# <div class="col-md-3 search_binder">
# <input class="search_field" name="search" type="text"/>
# <input class="search_submit" name="search" type="text"/>
# </div>
# <div class="col-md-3">
# <select aria-label="Default select example" class="form-select" id="year">
# <option selected="">Latest</option>
# <option>2020</option><option>2019</option></select>
# </div>
# <div class="col-md-3">
# <select aria-label="Default select example" class="form-select" id="cat">
# <option selected="">All Categories</option>
# <option>Feature Stories</option><option>Status Reports</option><option>Press Releases</option></select>
# </div>
# <div class="col-md-3">
# </div>
# </div>, <div class="col-md-3 search_binder">
# <input class="search_field" name="search" type="text"/>
# <input class="search_submit" name="search" type="text"/>
# </div>, <div class="col-md-3">
# <select aria-label="Default select example" class="form-select" id="year">
# <option selected="">Latest</option>
# <option>2020</option><option>2019</option></select>
# </div>, <div class="col-md-3">
# <select aria-label="Default select example" class="form-select" id="cat">
# <option selected="">All Categories</option>
# <option>Feature Stories</option><option>Status Reports</option><option>Press Releases</option></select>
# </div>, <div class="col-md-3">
# </div>, <div class="container" id="news">
# <div class="col-md-12">
# <hr/>
# <div class="row">
# <div class="col-md-4">
# <div class="list_image">
# <img src="https://mars.nasa.gov/system/news_items/list_view_images/8595_mars_winds_preview_4-320x240.jpg"/>
# </div>
# </div>
# <div class="col-md-8">
# <div class="list_text">
# <div class="list_date">March 7, 2023</div>
# <div class="content_title">NASA's MAVEN Maps Winds in the Martian Upper Atmosphere that Mirror the Terrain Below and Gives Clues to Martian Climate</div>
# <div class="article_teaser_body">Researchers have created the first map of wind circulation in the upper atmosphere of a planet besides Earth, using data from NASA’s MAVEN spacecraft that were collected during the last two years.</div>
# </div>
# </div>
# </div>
# </div>
# <div class="col-md-12">
# <hr/>
# <div class="row">
# <div class="col-md-4">
# <div class="list_image">
# <img src="https://mars.nasa.gov/system/news_items/list_view_images/8792_parachute-320x240.jpg"/>
# </div>
# </div>
# <div class="col-md-8">
# <div class="list_text">
# <div class="list_date">March 6, 2023</div>
# <div class="content_title">NASA's Perseverance Rover 100 Days Out</div>
# <div class="article_teaser_body">Mark your calendars: The agency's latest rover has only about 8,640,000 seconds to go before it touches down on the Red Planet, becoming history's next Mars car.</div>
# </div>
# </div>
# </div>
# </div>
# <div class="col-md-12">
# <hr/>
# <div class="row">
# <div class="col-md-4">
# <div class="list_image">
# <img src="https://mars.nasa.gov/system/news_items/list_view_images/8776_PIA24098-320.gif"/>
# </div>
# </div>
# <div class="col-md-8">
# <div class="list_text">
# <div class="list_date">March 5, 2023</div>
# <div class="content_title">NASA InSight's 'Mole' Is Out of Sight</div>
# <div class="article_teaser_body">Now that the heat probe is just below the Martian surface, InSight's arm will scoop some additional soil on top to help it keep digging so it can take Mars' temperature.</div>
# </div>
# </div>
# </div>
# </div>
# <div class="col-md-12">
# <hr/>
# <div class="row">
# <div class="col-md-4">
# <div class="list_image">
# <img src="https://mars.nasa.gov/system/news_items/list_view_images/8710_MARS2020_LAUNCH_320.jpg"/>
# </div>
# </div>
# <div class="col-md-8">
# <div class="list_text">
# <div class="list_date">March 5, 2023</div>
# <div class="content_title">Join NASA for the Launch of the Mars 2020 Perseverance Rover</div>
# <div class="article_teaser_body">No matter where you live, choose from a menu of activities to join NASA as we "Countdown to Mars" and launch the Perseverance rover to the Red Planet.</div>
# </div>
# </div>
# </div>
# </div>
# <div class="col-md-12">
# <hr/>
# <div class="row">
# <div class="col-md-4">
# <div class="list_image">
# <img src="https://mars.nasa.gov/system/news_items/list_view_images/8675_Webby_main_320x240.jpg"/>
# </div>
# </div>
# <div class="col-md-8">
# <div class="list_text">
# <div class="list_date">February 28, 2023</div>
# <div class="content_title">NASA Wins 4 Webbys, 4 People's Voice Awards</div>
# <div class="article_teaser_body">Winners include the JPL-managed "Send Your Name to Mars" campaign, NASA's Global Climate Change website and Solar System Interactive.</div>
# </div>
# </div>
# </div>
# </div>
# <div class="col-md-12">
# <hr/>
# <div class="row">
# <div class="col-md-4">
# <div class="list_image">
# <img src="https://mars.nasa.gov/system/news_items/list_view_images/8678_21379_PIA22107-320x240.jpg"/>
# </div>
# </div>
# <div class="col-md-8">
# <div class="list_text">
# <div class="list_date">February 26, 2023</div>
# <div class="content_title">The Detective Aboard NASA's Perseverance Rover</div>
# <div class="article_teaser_body">An instrument called SHERLOC will, with the help of its partner WATSON, hunt for signs of ancient life by detecting organic molecules and minerals.</div>
# </div>
# </div>
# </div>
# </div>
# <div class="col-md-12">
# <hr/>
# <div class="row">
# <div class="col-md-4">
# <div class="list_image">
# <img src="https://mars.nasa.gov/system/news_items/list_view_images/8647_PIA23773-32x24.jpg"/>
# </div>
# </div>
# <div class="col-md-8">
# <div class="list_text">
# <div class="list_date">February 24, 2023</div>
# <div class="content_title">NASA's Curiosity Keeps Rolling As Team Operates Rover From Home</div>
# <div class="article_teaser_body">The team has learned to meet new challenges as they work remotely on the Mars mission.</div>
# </div>
# </div>
# </div>
# </div>
# <div class="col-md-12">
# <hr/>
# <div class="row">
# <div class="col-md-4">
# <div class="list_image">
# <img src="https://mars.nasa.gov/system/news_items/list_view_images/8817_PIA23180_320.gif"/>
# </div>
# </div>
# <div class="col-md-8">
# <div class="list_text">
# <div class="list_date">February 18, 2023</div>
# <div class="content_title">3 Things We've Learned From NASA's Mars InSight </div>
# <div class="article_teaser_body">Scientists are finding new mysteries since the geophysics mission landed two years ago.</div>
# </div>
# </div>
# </div>
# </div>
# <div class="col-md-12">
# <hr/>
# <div class="row">
# <div class="col-md-4">
# <div class="list_image">
# <img src="https://mars.nasa.gov/system/news_items/list_view_images/8520_PIA23466-226.jpg"/>
# </div>
# </div>
# <div class="col-md-8">
# <div class="list_text">
# <div class="list_date">February 18, 2023</div>
# <div class="content_title">NASA's Mars 2020 Rover Tests Descent-Stage Separation</div>
# <div class="article_teaser_body">A crane lifts the rocket-powered descent stage away from NASA's Mars 2020 rover after technicians tested the pyrotechnic charges that separate the two spacecraft.</div>
# </div>
# </div>
# </div>
# </div>
# <div class="col-md-12">
# <hr/>
# <div class="row">
# <div class="col-md-4">
# <div class="list_image">
# <img src="https://mars.nasa.gov/system/news_items/list_view_images/8707_PIA23764-320.jpg"/>
# </div>
# </div>
# <div class="col-md-8">
# <div class="list_text">
# <div class="list_date">February 17, 2023</div>
# <div class="content_title">7 Things to Know About the Mars 2020 Perseverance Rover Mission</div>
# <div class="article_teaser_body">NASA's next rover to the Red Planet is slated to launch no earlier than July 30. These highlights will get you up to speed on the ambitious mission.</div>
# </div>
# </div>
# </div>
# </div>
# <div class="col-md-12">
# <hr/>
# <div class="row">
# <div class="col-md-4">
# <div class="list_image">
# <img src="https://mars.nasa.gov/system/news_items/list_view_images/8654_MAIN-IMAGE-PIA23881-320x240.jpg"/>
# </div>
# </div>
# <div class="col-md-8">
# <div class="list_text">
# <div class="list_date">February 17, 2023</div>
# <div class="content_title">How NASA's Perseverance Mars Team Adjusted to Work in the Time of Coronavirus </div>
# <div class="article_teaser_body">Like much of the rest of the world, the Mars rover team is pushing forward with its mission-critical work while putting the health and safety of their colleagues and community first.</div>
# </div>
# </div>
# </div>
# </div>
# <div class="col-md-12">
# <hr/>
# <div class="row">
# <div class="col-md-4">
# <div class="list_image">
# <img src="https://mars.nasa.gov/system/news_items/list_view_images/8704_PIA23973-320x240.jpg"/>
# </div>
# </div>
# <div class="col-md-8">
# <div class="list_text">
# <div class="list_date">February 15, 2023</div>
# <div class="content_title">Curiosity Mars Rover's Summer Road Trip Has Begun</div>
# <div class="article_teaser_body">After more than a year in the "clay-bearing unit," Curiosity is making a mile-long journey around some deep sand so that it can explore higher up Mount Sharp.</div>
# </div>
# </div>
# </div>
# </div>
# <div class="col-md-12">
# <hr/>
# <div class="row">
# <div class="col-md-4">
# <div class="list_image">
# <img src="https://mars.nasa.gov/system/news_items/list_view_images/8630_PIA23768-320x240.jpg"/>
# </div>
# </div>
# <div class="col-md-8">
# <div class="list_text">
# <div class="list_date">February 12, 2023</div>
# <div class="content_title">NASA's Mars Perseverance Rover Gets Its Sample Handling System</div>
# <div class="article_teaser_body">The system will be collecting and storing Martian rock and soil. Its installation marks another milestone in the march toward the July launch period.</div>
# </div>
# </div>
# </div>
# </div>
# <div class="col-md-12">
# <hr/>
# <div class="row">
# <div class="col-md-4">
# <div class="list_image">
# <img src="https://mars.nasa.gov/system/news_items/list_view_images/8731_MAVEN_nightglow_pulsating_spot-320x240.jpg"/>
# </div>
# </div>
# <div class="col-md-8">
# <div class="list_text">
# <div class="list_date">February 11, 2023</div>
# <div class="content_title">NASA's MAVEN Observes Martian Night Sky Pulsing in Ultraviolet Light</div>
# <div class="article_teaser_body">Vast areas of the Martian night sky pulse in ultraviolet light, according to images from NASA’s MAVEN spacecraft. The results are being used to illuminate complex circulation patterns in the Martian atmosphere.</div>
# </div>
# </div>
# </div>
# </div>
# <div class="col-md-12">
# <hr/>
# <div class="row">
# <div class="col-md-4">
# <div class="list_image">
# <img src="https://mars.nasa.gov/system/news_items/list_view_images/8723_PIA24031-320.jpg"/>
# </div>
# </div>
# <div class="col-md-8">
# <div class="list_text">
# <div class="list_date">February 7, 2023</div>
# <div class="content_title">NASA's Perseverance Rover Will Carry First Spacesuit Materials to Mars</div>
# <div class="article_teaser_body">In a Q&amp;A, spacesuit designer Amy Ross explains how five samples, including a piece of helmet visor, will be tested aboard the rover, which is targeting a July 30 launch. </div>
# </div>
# </div>
# </div>
# </div>
# </div>, <div class="col-md-12">
# <hr/>
# <div class="row">
# <div class="col-md-4">
# <div class="list_image">
# <img src="https://mars.nasa.gov/system/news_items/list_view_images/8595_mars_winds_preview_4-320x240.jpg"/>
# </div>
# </div>
# <div class="col-md-8">
# <div class="list_text">
# <div class="list_date">March 7, 2023</div>
# ...
# </div>
# </div>
# </div>
# </div>, <div class="col-md-4 mb-3">
# <div class="card">
# <img alt="100%x280" class="img-fluid" src="https://mars.nasa.gov/system/news_items/main_images/8716_PIA23499-16.jpg"/>
# <div class="card-body">
# <p class="card-text">NASA to Broadcast Mars 2020 Perseverance Launch, Prelaunch Activities</p>
# </div>
# </div>
# </div>, <div class="card">
# <img alt="100%x280" class="img-fluid" src="https://mars.nasa.gov/system/news_items/main_images/8716_PIA23499-16.jpg"/>
# <div class="card-body">
# <p class="card-text">NASA to Broadcast Mars 2020 Perseverance Launch, Prelaunch Activities</p>
# </div>
# </div>, <div class="card-body">
# <p class="card-text">NASA to Broadcast Mars 2020 Perseverance Launch, Prelaunch Activities</p>
# </div>, <div class="col-md-4 mb-3">
# <div class="card">
# <img alt="100%x280" class="img-fluid" src="https://mars.nasa.gov/system/news_items/main_images/8716_PIA23499-16.jpg"/>
# <div class="card-body">
# <p class="card-text">The Launch Is Approaching for NASA's Next Mars Rover, Perseverance</p>
# </div>
# </div>
# </div>, <div class="card">
# <img alt="100%x280" class="img-fluid" src="https://mars.nasa.gov/system/news_items/main_images/8716_PIA23499-16.jpg"/>
# <div class="card-body">
# <p class="card-text">The Launch Is Approaching for NASA's Next Mars Rover, Perseverance</p>
# </div>
# </div>, <div class="card-body">
# <p class="card-text">The Launch Is Approaching for NASA's Next Mars Rover, Perseverance</p>
# </div>, <div class="col-md-4 mb-3">
# <div class="card">
# <img alt="100%x280" class="img-fluid" src="https://mars.nasa.gov/system/news_items/main_images/8692_PIA23920-web.jpg"/>
# <div class="card-body">
# <p class="card-text">NASA to Hold Mars 2020 Perseverance Rover Launch Briefing</p>
# </div>
# </div>
# </div>, <div class="card">
# <img alt="100%x280" class="img-fluid" src="https://mars.nasa.gov/system/news_items/main_images/8692_PIA23920-web.jpg"/>
# <div class="card-body">
# <p class="card-text">NASA to Hold Mars 2020 Perseverance Rover Launch Briefing</p>
# </div>
# </div>, <div class="card-body">
# <p class="card-text">NASA to Hold Mars 2020 Perseverance Rover Launch Briefing</p>
# </div>, <div class="carousel-item">
# <div class="row">
# <div class="col-md-4 mb-3">
# <div class="card">
# <img alt="100%x280" class="img-fluid" src="https://images.unsplash.com/photo-1532771098148-525cefe10c23?ixlib=rb-0.3.5&amp;q=80&amp;fm=jpg&amp;crop=entropy&amp;cs=tinysrgb&amp;w=1080&amp;fit=max&amp;ixid=eyJhcHBfaWQiOjMyMDc0fQ&amp;s=3f317c1f7a16116dec454fbc267dd8e4"/>
# <div class="card-body">
# <p class="card-text">With supporting text below as a natural lead-in to additional content.</p>
# </div>
# </div>
# </div>
# <div class="col-md-4 mb-3">
# <div class="card">
# <img alt="100%x280" class="img-fluid" src="https://images.unsplash.com/photo-1532715088550-62f09305f765?ixlib=rb-0.3.5&amp;q=80&amp;fm=jpg&amp;crop=entropy&amp;cs=tinysrgb&amp;w=1080&amp;fit=max&amp;ixid=eyJhcHBfaWQiOjMyMDc0fQ&amp;s=ebadb044b374504ef8e81bdec4d0e840"/>
# <div class="card-body">
# <p class="card-text">With supporting text below as a natural lead-in to additional content.</p>
# </div>
# </div>
# </div>
# <div class="col-md-4 mb-3">
# <div class="card">
# <img alt="100%x280" class="img-fluid" src="https://images.unsplash.com/photo-1506197603052-3cc9c3a201bd?ixlib=rb-0.3.5&amp;q=80&amp;fm=jpg&amp;crop=entropy&amp;cs=tinysrgb&amp;w=1080&amp;fit=max&amp;ixid=eyJhcHBfaWQiOjMyMDc0fQ&amp;s=0754ab085804ae8a3b562548e6b4aa2e"/>
# <div class="card-body">
# <p class="card-text">With supporting text below as a natural lead-in to additional content.</p>
# </div>
# </div>
# </div>
# </div>
# </div>, <div class="row">
# <div class="col-md-4 mb-3">
# <div class="card">
# <img alt="100%x280" class="img-fluid" src="https://images.unsplash.com/photo-1532771098148-525cefe10c23?ixlib=rb-0.3.5&amp;q=80&amp;fm=jpg&amp;crop=entropy&amp;cs=tinysrgb&amp;w=1080&amp;fit=max&amp;ixid=eyJhcHBfaWQiOjMyMDc0fQ&amp;s=3f317c1f7a16116dec454fbc267dd8e4"/>
# <div class="card-body">
# <p class="card-text">With supporting text below as a natural lead-in to additional content.</p>
# </div>
# </div>
# </div>
# <div class="col-md-4 mb-3">
# <div class="card">
# <img alt="100%x280" class="img-fluid" src="https://images.unsplash.com/photo-1532715088550-62f09305f765?ixlib=rb-0.3.5&amp;q=80&amp;fm=jpg&amp;crop=entropy&amp;cs=tinysrgb&amp;w=1080&amp;fit=max&amp;ixid=eyJhcHBfaWQiOjMyMDc0fQ&amp;s=ebadb044b374504ef8e81bdec4d0e840"/>
# <div class="card-body">
# <p class="card-text">With supporting text below as a natural lead-in to additional content.</p>
# </div>
# </div>
# </div>
# <div class="col-md-4 mb-3">
# <div class="card">
# <img alt="100%x280" class="img-fluid" src="https://images.unsplash.com/photo-1506197603052-3cc9c3a201bd?ixlib=rb-0.3.5&amp;q=80&amp;fm=jpg&amp;crop=entropy&amp;cs=tinysrgb&amp;w=1080&amp;fit=max&amp;ixid=eyJhcHBfaWQiOjMyMDc0fQ&amp;s=0754ab085804ae8a3b562548e6b4aa2e"/>
# <div class="card-body">
# <p class="card-text">With supporting text below as a natural lead-in to additional content.</p>
# </div>
# </div>
# </div>
# </div>, <div class="col-md-4 mb-3">
# <div class="card">
# <img alt="100%x280" class="img-fluid" src="https://images.unsplash.com/photo-1532771098148-525cefe10c23?ixlib=rb-0.3.5&amp;q=80&amp;fm=jpg&amp;crop=entropy&amp;cs=tinysrgb&amp;w=1080&amp;fit=max&amp;ixid=eyJhcHBfaWQiOjMyMDc0fQ&amp;s=3f317c1f7a16116dec454fbc267dd8e4"/>
# <div class="card-body">
# <p class="card-text">With supporting text below as a natural lead-in to additional content.</p>
# </div>
# </div>
# </div>, <div class="card">
# <img alt="100%x280" class="img-fluid" src="https://images.unsplash.com/photo-1532771098148-525cefe10c23?ixlib=rb-0.3.5&amp;q=80&amp;fm=jpg&amp;crop=entropy&amp;cs=tinysrgb&amp;w=1080&amp;fit=max&amp;ixid=eyJhcHBfaWQiOjMyMDc0fQ&amp;s=3f317c1f7a16116dec454fbc267dd8e4"/>
# <div class="card-body">
# <p class="card-text">With supporting text below as a natural lead-in to additional content.</p>
# </div>
# </div>, <div class="card-body">
# <p class="card-text">With supporting text below as a natural lead-in to additional content.</p>
# </div>, <div class="col-md-4 mb-3">
# <div class="card">
# <img alt="100%x280" class="img-fluid" src="https://images.unsplash.com/photo-1532715088550-62f09305f765?ixlib=rb-0.3.5&amp;q=80&amp;fm=jpg&amp;crop=entropy&amp;cs=tinysrgb&amp;w=1080&amp;fit=max&amp;ixid=eyJhcHBfaWQiOjMyMDc0fQ&amp;s=ebadb044b374504ef8e81bdec4d0e840"/>
# <div class="card-body">
# <p class="card-text">With supporting text below as a natural lead-in to additional content.</p>
# </div>
# </div>
# </div>, <div class="card">
# <img alt="100%x280" class="img-fluid" src="https://images.unsplash.com/photo-1532715088550-62f09305f765?ixlib=rb-0.3.5&amp;q=80&amp;fm=jpg&amp;crop=entropy&amp;cs=tinysrgb&amp;w=1080&amp;fit=max&amp;ixid=eyJhcHBfaWQiOjMyMDc0fQ&amp;s=ebadb044b374504ef8e81bdec4d0e840"/>
# <div class="card-body">
# <p class="card-text">With supporting text below as a natural lead-in to additional content.</p>
# </div>
# </div>, <div class="card-body">
# <p class="card-text">With supporting text below as a natural lead-in to additional content.</p>
# </div>, <div class="col-md-4 mb-3">
# <div class="card">
# <img alt="100%x280" class="img-fluid" src="https://images.unsplash.com/photo-1506197603052-3cc9c3a201bd?ixlib=rb-0.3.5&amp;q=80&amp;fm=jpg&amp;crop=entropy&amp;cs=tinysrgb&amp;w=1080&amp;fit=max&amp;ixid=eyJhcHBfaWQiOjMyMDc0fQ&amp;s=0754ab085804ae8a3b562548e6b4aa2e"/>
# <div class="card-body">
# <p class="card-text">With supporting text below as a natural lead-in to additional content.</p>
# </div>
# </div>
# </div>, <div class="card">
# <img alt="100%x280" class="img-fluid" src="https://images.unsplash.com/photo-1506197603052-3cc9c3a201bd?ixlib=rb-0.3.5&amp;q=80&amp;fm=jpg&amp;crop=entropy&amp;cs=tinysrgb&amp;w=1080&amp;fit=max&amp;ixid=eyJhcHBfaWQiOjMyMDc0fQ&amp;s=0754ab085804ae8a3b562548e6b4aa2e"/>
# <div class="card-body">
# <p class="card-text">With supporting text below as a natural lead-in to additional content.</p>
# </div>
# </div>, <div class="card-body">
# <p class="card-text">With supporting text below as a natural lead-in to additional content.</p>
# </div>, <div class="carousel-item">
# <div class="row">
# <div class="col-md-4 mb-3">
# <div class="card">
# <img alt="100%x280" class="img-fluid" src="https://images.unsplash.com/photo-1507525428034-b723cf961d3e?ixlib=rb-0.3.5&amp;q=80&amp;fm=jpg&amp;crop=entropy&amp;cs=tinysrgb&amp;w=1080&amp;fit=max&amp;ixid=eyJhcHBfaWQiOjMyMDc0fQ&amp;s=ee8417f0ea2a50d53a12665820b54e23"/>
# <div class="card-body">
# <p class="card-text">With supporting text below as a natural lead-in to additional content.</p>
# </div>
# </div>
# </div>
# <div class="col-md-4 mb-3">
# <div class="card">
# <img alt="100%x280" class="img-fluid" src="https://images.unsplash.com/photo-1532777946373-b6783242f211?ixlib=rb-0.3.5&amp;q=80&amp;fm=jpg&amp;crop=entropy&amp;cs=tinysrgb&amp;w=1080&amp;fit=max&amp;ixid=eyJhcHBfaWQiOjMyMDc0fQ&amp;s=8ac55cf3a68785643998730839663129"/>
# <div class="card-body">
# <p class="card-text">With supporting text below as a natural lead-in to additional content.</p>
# </div>
# </div>
# </div>
# <div class="col-md-4 mb-3">
# <div class="card">
# <img alt="100%x280" class="img-fluid" src="https://images.unsplash.com/photo-1532763303805-529d595877c5?ixlib=rb-0.3.5&amp;q=80&amp;fm=jpg&amp;crop=entropy&amp;cs=tinysrgb&amp;w=1080&amp;fit=max&amp;ixid=eyJhcHBfaWQiOjMyMDc0fQ&amp;s=5ee4fd5d19b40f93eadb21871757eda6"/>
# <div class="card-body">
# <p class="card-text">With supporting text below as a natural lead-in to additional content.</p>
# </div>
# </div>
# </div>
# </div>
# </div>, <div class="row">
# <div class="col-md-4 mb-3">
# <div class="card">
# <img alt="100%x280" class="img-fluid" src="https://images.unsplash.com/photo-1507525428034-b723cf961d3e?ixlib=rb-0.3.5&amp;q=80&amp;fm=jpg&amp;crop=entropy&amp;cs=tinysrgb&amp;w=1080&amp;fit=max&amp;ixid=eyJhcHBfaWQiOjMyMDc0fQ&amp;s=ee8417f0ea2a50d53a12665820b54e23"/>
# <div class="card-body">
# <p class="card-text">With supporting text below as a natural lead-in to additional content.</p>
# </div>
# </div>
# </div>
# <div class="col-md-4 mb-3">
# <div class="card">
# <img alt="100%x280" class="img-fluid" src="https://images.unsplash.com/photo-1532777946373-b6783242f211?ixlib=rb-0.3.5&amp;q=80&amp;fm=jpg&amp;crop=entropy&amp;cs=tinysrgb&amp;w=1080&amp;fit=max&amp;ixid=eyJhcHBfaWQiOjMyMDc0fQ&amp;s=8ac55cf3a68785643998730839663129"/>
# <div class="card-body">
# <p class="card-text">With supporting text below as a natural lead-in to additional content.</p>
# </div>
# </div>
# </div>
# <div class="col-md-4 mb-3">
# <div class="card">
# <img alt="100%x280" class="img-fluid" src="https://images.unsplash.com/photo-1532763303805-529d595877c5?ixlib=rb-0.3.5&amp;q=80&amp;fm=jpg&amp;crop=entropy&amp;cs=tinysrgb&amp;w=1080&amp;fit=max&amp;ixid=eyJhcHBfaWQiOjMyMDc0fQ&amp;s=5ee4fd5d19b40f93eadb21871757eda6"/>
# <div class="card-body">
# <p class="card-text">With supporting text below as a natural lead-in to additional content.</p>
# </div>
# </div>
# </div>
# </div>, <div class="col-md-4 mb-3">
# <div class="card">
# <img alt="100%x280" class="img-fluid" src="https://images.unsplash.com/photo-1507525428034-b723cf961d3e?ixlib=rb-0.3.5&amp;q=80&amp;fm=jpg&amp;crop=entropy&amp;cs=tinysrgb&amp;w=1080&amp;fit=max&amp;ixid=eyJhcHBfaWQiOjMyMDc0fQ&amp;s=ee8417f0ea2a50d53a12665820b54e23"/>
# <div class="card-body">
# <p class="card-text">With supporting text below as a natural lead-in to additional content.</p>
# </div>
# </div>
# </div>, <div class="card">
# <img alt="100%x280" class="img-fluid" src="https://images.unsplash.com/photo-1507525428034-b723cf961d3e?ixlib=rb-0.3.5&amp;q=80&amp;fm=jpg&amp;crop=entropy&amp;cs=tinysrgb&amp;w=1080&amp;fit=max&amp;ixid=eyJhcHBfaWQiOjMyMDc0fQ&amp;s=ee8417f0ea2a50d53a12665820b54e23"/>
# <div class="card-body">
# <p class="card-text">With supporting text below as a natural lead-in to additional content.</p>
# </div>
# </div>, <div class="card-body">
# <p class="card-text">With supporting text below as a natural lead-in to additional content.</p>
# </div>, <div class="col-md-4 mb-3">
# <div class="card">
# <img alt="100%x280" class="img-fluid" src="https://images.unsplash.com/photo-1532777946373-b6783242f211?ixlib=rb-0.3.5&amp;q=80&amp;fm=jpg&amp;crop=entropy&amp;cs=tinysrgb&amp;w=1080&amp;fit=max&amp;ixid=eyJhcHBfaWQiOjMyMDc0fQ&amp;s=8ac55cf3a68785643998730839663129"/>
# <div class="card-body">
# <p class="card-text">With supporting text below as a natural lead-in to additional content.</p>
# </div>
# </div>
# </div>, <div class="card">
# <img alt="100%x280" class="img-fluid" src="https://images.unsplash.com/photo-1532777946373-b6783242f211?ixlib=rb-0.3.5&amp;q=80&amp;fm=jpg&amp;crop=entropy&amp;cs=tinysrgb&amp;w=1080&amp;fit=max&amp;ixid=eyJhcHBfaWQiOjMyMDc0fQ&amp;s=8ac55cf3a68785643998730839663129"/>
# <div class="card-body">
# <p class="card-text">With supporting text below as a natural lead-in to additional content.</p>
# </div>
# </div>, <div class="card-body">
# <p class="card-text">With supporting text below as a natural lead-in to additional content.</p>
# </div>, <div class="col-md-4 mb-3">
# <div class="card">
# <img alt="100%x280" class="img-fluid" src="https://images.unsplash.com/photo-1532763303805-529d595877c5?ixlib=rb-0.3.5&amp;q=80&amp;fm=jpg&amp;crop=entropy&amp;cs=tinysrgb&amp;w=1080&amp;fit=max&amp;ixid=eyJhcHBfaWQiOjMyMDc0fQ&amp;s=5ee4fd5d19b40f93eadb21871757eda6"/>
# <div class="card-body">
# <p class="card-text">With supporting text below as a natural lead-in to additional content.</p>
# </div>
# </div>
# </div>, <div class="card">
# <img alt="100%x280" class="img-fluid" src="https://images.unsplash.com/photo-1532763303805-529d595877c5?ixlib=rb-0.3.5&amp;q=80&amp;fm=jpg&amp;crop=entropy&amp;cs=tinysrgb&amp;w=1080&amp;fit=max&amp;ixid=eyJhcHBfaWQiOjMyMDc0fQ&amp;s=5ee4fd5d19b40f93eadb21871757eda6"/>
# <div class="card-body">
# <p class="card-text">With supporting text below as a natural lead-in to additional content.</p>
# </div>
# </div>, <div class="card-body">
# <p class="card-text">With supporting text below as a natural lead-in to additional content.</p>
# </div>, <div class="container">
# <div class="col-md-12">
# <div class="row">
# <div class="col-md-3">
# <h5>The Red Planet</h5>
# <ul>
# <li>Dashboard</li>
# <li>Science Goals</li>
# <li>The Planet</li>
# </ul>
# </div>
# <div class="col-md-3">
# <h5>The Program</h5>
# <ul>
# <li>Mission Statement</li>
# <li>About the Program</li>
# <li>Organization Why Mars?</li>
# </ul>
# </div>
# <div class="col-md-3">
# <h5>Multimedia</h5>
# <ul>
# <li>Images</li>
# <li>Videos</li>
# <li>More Resources</li>
# </ul>
# </div>
# <div class="col-md-3">
# <h5>Missions</h5>
# <ul>
# <li>Past</li>
# <li>Present</li>
# <li>Future</li>
# </ul>
# </div>
# </div>
# </div>
# </div>, <div class="col-md-12">
# <div class="row">
# <div class="col-md-3">
# <h5>The Red Planet</h5>
# <ul>
# <li>Dashboard</li>
# <li>Science Goals</li>
# <li>The Planet</li>
# </ul>
# </div>
# <div class="col-md-3">
# <h5>The Program</h5>
# <ul>
# <li>Mission Statement</li>
# <li>About the Program</li>
# <li>Organization Why Mars?</li>
# </ul>
# </div>
# <div class="col-md-3">
# <h5>Multimedia</h5>
# <ul>
# <li>Images</li>
# <li>Videos</li>
# <li>More Resources</li>
# </ul>
# </div>
# <div class="col-md-3">
# <h5>Missions</h5>
# <ul>
# <li>Past</li>
# <li>Present</li>
# <li>Future</li>
# </ul>
# </div>
# </div>
# </div>, <div class="row">
# <div class="col-md-3">
# <h5>The Red Planet</h5>
# <ul>
# <li>Dashboard</li>
# <li>Science Goals</li>
# <li>The Planet</li>
# </ul>
# </div>
# <div class="col-md-3">
# <h5>The Program</h5>
# <ul>
# <li>Mission Statement</li>
# <li>About the Program</li>
# <li>Organization Why Mars?</li>
# </ul>
# </div>
# <div class="col-md-3">
# <h5>Multimedia</h5>
# <ul>
# <li>Images</li>
# <li>Videos</li>
# <li>More Resources</li>
# </ul>
# </div>
# <div class="col-md-3">
# <h5>Missions</h5>
# <ul>
# <li>Past</li>
# <li>Present</li>
# <li>Future</li>
# </ul>
# </div>
# </div>, <div class="col-md-3">
# <h5>The Red Planet</h5>
# <ul>
# <li>Dashboard</li>
# <li>Science Goals</li>
# <li>The Planet</li>
# </ul>
# </div>, <div class="col-md-3">
# <h5>The Program</h5>
# <ul>
# <li>Mission Statement</li>
# <li>About the Program</li>
# <li>Organization Why Mars?</li>
# </ul>
# </div>, <div class="col-md-3">
# <h5>Multimedia</h5>
# <ul>
# <li>Images</li>
# <li>Videos</li>
# <li>More Resources</li>
# </ul>
# </div>, <div class="col-md-3">
# <h5>Missions</h5>
# <ul>
# <li>Past</li>
# <li>Present</li>
# <li>Future</li>
# </ul>
# </div>]

# %%
#slide_elem = html_soup.find_all('div')
#slide_elem

# %%
#title_elem = html_soup.find('div', class_='content_title').text
#print(title_elem)

# %%
#Title = title_elem
#print(Title)

# %%
title= [tag.text for tag in html_soup.find_all('div', class_='content_title')]
title
# Out:
# ["NASA's MAVEN Maps Winds in the Martian Upper Atmosphere that Mirror the Terrain Below and Gives Clues to Martian Climate",
#  "NASA's Perseverance Rover 100 Days Out",
#  "NASA InSight's 'Mole' Is Out of Sight",
#  'Join NASA for the Launch of the Mars 2020 Perseverance Rover',
#  "NASA Wins 4 Webbys, 4 People's Voice Awards",
#  "The Detective Aboard NASA's Perseverance Rover",
#  "NASA's Curiosity Keeps Rolling As Team Operates Rover From Home",
#  "3 Things We've Learned From NASA's Mars InSight ",
#  "NASA's Mars 2020 Rover Tests Descent-Stage Separation",
#  '7 Things to Know About the Mars 2020 Perseverance Rover Mission',
#  "How NASA's Perseverance Mars Team Adjusted to Work in the Time of Coronavirus ",
#  "Curiosity Mars Rover's Summer Road Trip Has Begun",
#  "NASA's Mars Perseverance Rover Gets Its Sample Handling System",
#  "NASA's MAVEN Observes Martian Night Sky Pulsing in Ultraviolet Light",
#  "NASA's Perseverance Rover Will Carry First Spacesuit Materials to Mars"]

# %%
preview = [tag.text for tag in html_soup.find_all('div', class_='article_teaser_body')]
#preview = html_soup.find_all('div', class_='article_teaser_body')
preview
# Out:
# ['Researchers have created the first map of wind circulation in the upper atmosphere of a planet besides Earth, using data from NASA’s MAVEN spacecraft that were collected during the last two years.',
#  "Mark your calendars: The agency's latest rover has only about 8,640,000 seconds to go before it touches down on the Red Planet, becoming history's next Mars car.",
#  "Now that the heat probe is just below the Martian surface, InSight's arm will scoop some additional soil on top to help it keep digging so it can take Mars' temperature.",
#  'No matter where you live, choose from a menu of activities to join NASA as we "Countdown to Mars" and launch the Perseverance rover to the Red Planet.',
#  'Winners include the JPL-managed "Send Your Name to Mars" campaign, NASA\'s Global Climate Change website and Solar System Interactive.',
#  'An instrument called SHERLOC will, with the help of its partner WATSON, hunt for signs of ancient life by detecting organic molecules and minerals.',
#  'The team has learned to meet new challenges as they work remotely on the Mars mission.',
#  'Scientists are finding new mysteries since the geophysics mission landed two years ago.',
#  "A crane lifts the rocket-powered descent stage away from NASA's Mars 2020 rover after technicians tested the pyrotechnic charges that separate the two spacecraft.",
#  "NASA's next rover to the Red Planet is slated to launch no earlier than July 30. These highlights will get you up to speed on the ambitious mission.",
#  'Like much of the rest of the world, the Mars rover team is pushing forward with its mission-critical work while putting the health and safety of their colleagues and community first.',
#  'After more than a year in the "clay-bearing unit," Curiosity is making a mile-long journey around some deep sand so that it can explore higher up Mount Sharp.',
#  'The system will be collecting and storing Martian rock and soil. Its installation marks another milestone in the march toward the July launch period.',
#  'Vast areas of the Martian night sky pulse in ultraviolet light, according to images from NASA’s MAVEN spacecraft. The results are being used to illuminate complex circulation patterns in the Martian atmosphere.',
#  'In a Q&A, spacesuit designer Amy Ross explains how five samples, including a piece of helmet visor, will be tested aboard the rover, which is targeting a July 30 launch. ']

# %%
# Create an empty list to store the dictionaries
articles_list = []

# %%
# Loop through the text elements
articles= html_soup.find_all('div',class_= 'list_text')
for article in articles:
    
# Extract the title and preview text from the elements
    title =  article.find(class_='content_title').text
    preview = article.find(class_='article_teaser_body').text
   
#Store each title and preview pair in a dictionary
    article_dict={}
    article_dict['title'] = title
    article_dict['preview'] = preview

    
#Add the dictionary to the list
    articles_list.append(article_dict)

# %%
print(articles_list)
# Out:
# [{'title': "NASA's MAVEN Maps Winds in the Martian Upper Atmosphere that Mirror the Terrain Below and Gives Clues to Martian Climate", 'preview': 'Researchers have created the first map of wind circulation in the upper atmosphere of a planet besides Earth, using data from NASA’s MAVEN spacecraft that were collected during the last two years.'}, {'title': "NASA's Perseverance Rover 100 Days Out", 'preview': "Mark your calendars: The agency's latest rover has only about 8,640,000 seconds to go before it touches down on the Red Planet, becoming history's next Mars car."}, {'title': "NASA InSight's 'Mole' Is Out of Sight", 'preview': "Now that the heat probe is just below the Martian surface, InSight's arm will scoop some additional soil on top to help it keep digging so it can take Mars' temperature."}, {'title': 'Join NASA for the Launch of the Mars 2020 Perseverance Rover', 'preview': 'No matter where you live, choose from a menu of activities to join NASA as we "Countdown to Mars" and launch the Perseverance rover to the Red Planet.'}, {'title': "NASA Wins 4 Webbys, 4 People's Voice Awards", 'preview': 'Winners include the JPL-managed "Send Your Name to Mars" campaign, NASA\'s Global Climate Change website and Solar System Interactive.'}, {'title': "The Detective Aboard NASA's Perseverance Rover", 'preview': 'An instrument called SHERLOC will, with the help of its partner WATSON, hunt for signs of ancient life by detecting organic molecules and minerals.'}, {'title': "NASA's Curiosity Keeps Rolling As Team Operates Rover From Home", 'preview': 'The team has learned to meet new challenges as they work remotely on the Mars mission.'}, {'title': "3 Things We've Learned From NASA's Mars InSight ", 'preview': 'Scientists are finding new mysteries since the geophysics mission landed two years ago.'}, {'title': "NASA's Mars 2020 Rover Tests Descent-Stage Separation", 'preview': "A crane lifts the rocket-powered descent stage away from NASA's Mars 2020 rover after technicians tested the pyrotechnic charges that separate the two spacecraft."}, {'title': '7 Things to Know About the Mars 2020 Perseverance Rover Mission', 'preview': "NASA's next rover to the Red Planet is slated to launch no earlier than July 30. These highlights will get you up to speed on the ambitious mission."}, {'title': "How NASA's Perseverance Mars Team Adjusted to Work in the Time of Coronavirus ", 'preview': 'Like much of the rest of the world, the Mars rover team is pushing forward with its mission-critical work while putting the health and safety of their colleagues and community first.'}, {'title': "Curiosity Mars Rover's Summer Road Trip Has Begun", 'preview': 'After more than a year in the "clay-bearing unit," Curiosity is making a mile-long journey around some deep sand so that it can explore higher up Mount Sharp.'}, {'title': "NASA's Mars Perseverance Rover Gets Its Sample Handling System", 'preview': 'The system will be collecting and storing Martian rock and soil. Its installation marks another milestone in the march toward the July launch period.'}, {'title': "NASA's MAVEN Observes Martian Night Sky Pulsing in Ultraviolet Light", 'preview': 'Vast areas of the Martian night sky pulse in ultraviolet light, according to images from NASA’s MAVEN spacecraft. The results are being used to illuminate complex circulation patterns in the Martian atmosphere.'}, {'title': "NASA's Perseverance Rover Will Carry First Spacesuit Materials to Mars", 'preview': 'In a Q&A, spacesuit designer Amy Ross explains how five samples, including a piece of helmet visor, will be tested aboard the rover, which is targeting a July 30 launch. '}]

# %%
# browser.quit()

# %% [markdown]
# ### (Optional) Step 4: Export the Data
#
# Optionally, store the scraped data in a file or database (to ease sharing the data with others). To do so, export the scraped data to either a JSON file or a MongoDB database.

# %%
# Export data to JSON

# %%
# Export data to MongoDB
