# %% [markdown]
# # Module 12 Challenge
# ## Deliverable 1: Scrape Titles and Preview Text from Mars News

# %%
# Import Splinter and BeautifulSoup
from splinter import Browser
from bs4 import BeautifulSoup as soup
from webdriver_manager.chrome import ChromeDriverManager

# %%
executable_path = {'executable_path': ChromeDriverManager().install()}
browser = Browser('chrome', **executable_path, headless=False)

# %% [markdown]
# ### Step 1: Visit the Website
#
# 1. Use automated browsing to visit the [Mars NASA news site](https://redplanetscience.com). Inspect the page to identify which elements to scrape.
#
#       > **Hint** To identify which elements to scrape, you might want to inspect the page by using Chrome DevTools.

# %%
# Visit the Mars NASA news site: https://redplanetscience.com
url = 'https://redplanetscience.com'
browser.visit(url)

# %% [markdown]
# ### Step 2: Scrape the Website
#
# Create a Beautiful Soup object and use it to extract text elements from the website.

# %%
# Create a Beautiful Soup object
# Set up HTML parser
html = browser.html
html_soup = soup(html, 'html.parser')

# %%
# Extract all the text elements
for text in html_soup.find_all(text=True):
    print(text)
# Out:
# News - Mars Exploration Program
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# MARS Planet Science
#
#
# Exploration Program
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# The Red Planet
#
#
#
#
#
#
# The Program
#
#
#
#
#
#
# News & Events
#
#
#
#
#
#
# Multimedia
#
#
#
#
#
#
# Missions
#
#
#
#
#
#
# More
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# News
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Latest
#
#
# 2020
# 2019
#
#
#
#
#
#
#
#
# All Categories
#
#
# Press Releases
# Feature Stories
# Status Reports
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# March 5, 2023
#
#
# Alabama High School Student Names NASA's Mars Helicopter
#
#
# Vaneeza Rupani's essay was chosen as the name for the small spacecraft, which will mark NASA's first attempt at powered flight on another planet.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# March 4, 2023
#
#
# NASA's Perseverance Rover Will Look at Mars Through These 'Eyes'
#
#
# A pair of zoomable cameras will help scientists and rover drivers with high-resolution color images.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# March 1, 2023
#
#
# NASA's Perseverance Rover 100 Days Out
#
#
# Mark your calendars: The agency's latest rover has only about 8,640,000 seconds to go before it touches down on the Red Planet, becoming history's next Mars car.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# February 28, 2023
#
#
# NASA's Mars 2020 Rover Goes Coast-to-Coast to Prep for Launch
#
#
# The agency's first step in returning rocks from Mars just arrived at Kennedy Space Center. The Mars 2020 team now begins readying for a launch to the Red Planet this July.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# February 26, 2023
#
#
# Scientists Explore Outback as Testbed for Mars
#
#
# Australia provides a great place for NASA's Mars 2020 and the ESA-Roscosmos ExoMars scientists to hone techniques in preparation for searching for signs ancient life on Mars.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# February 24, 2023
#
#
# My Culture, My Voice
#
#
# In honor of Hispanic Heritage Month, Christina Hernandez, an instrument engineer on the Mars 2020 mission, talks about her childhood and journey to NASA.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# February 23, 2023
#
#
# 8 Martian Postcards to Celebrate Curiosity's Landing Anniversary
#
#
# The NASA rover touched down eight years ago, on Aug. 5, 2012, and will soon be joined by a second rover, Perseverance.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# February 23, 2023
#
#
# NASA's Mars Reconnaissance Orbiter Undergoes Memory Update
#
#
# Other orbiters will continue relaying data from Mars surface missions for a two-week period.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# February 20, 2023
#
#
# How NASA's Mars Helicopter Will Reach the Red Planet's Surface
#
#
# The small craft will seek to prove that powered, controlled flight is possible on another planet. But just getting it onto the surface of Mars will take a whole lot of ingenuity.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# February 20, 2023
#
#
# NASA to Reveal Name of Its Next Mars Rover
#
#
# After a months-long contest among students to name NASA's newest Mars rover, the agency will reveal the winning name — and the winning student — this Thursday.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# February 15, 2023
#
#
# NASA Adds Return Sample Scientists to Mars 2020 Leadership Team
#
#
# The leadership council for Mars 2020 science added two new members who represent the interests of scientists destined to handle and study the first samples from Red Planet.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# February 12, 2023
#
#
# NASA's Perseverance Rover Bringing 3D-Printed Metal Parts to Mars
#
#
# For hobbyists and makers, 3D printing expands creative possibilities; for specialized engineers, it's also key to next-generation spacecraft design.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# February 11, 2023
#
#
# NASA's Perseverance Mars Rover Gets Its Wheels and Air Brakes
#
#
# After the rover was shipped from JPL to Kennedy Space Center, the team is getting closer to finalizing the spacecraft for launch later this summer.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# February 9, 2023
#
#
# NASA's InSight 'Hears' Peculiar Sounds on Mars
#
#
# Listen to the marsquakes and other, less-expected sounds that the Mars lander has been detecting.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# February 5, 2023
#
#
# Mars Helicopter Attached to NASA's Perseverance Rover
#
#
# The team also fueled the rover's sky crane to get ready for this summer's history-making launch.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# More
#
#
#
#
#
#
#
#
#
#
#
#
# You Might Also Like
#
#
#
#
#   <a class=" prev" href="#carouselExampleIndicators2" role="button" data-slide="prev">
#                   <i class="fas fa-angle-left"></i>
#                   </a>
#                   <a class=" next" href="#carouselExampleIndicators2" role="button" data-slide="next">
#                   <i class="fas fa-angle-right"></i>
#                   </a>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# NASA to Broadcast Mars 2020 Perseverance Launch, Prelaunch Activities
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# The Launch Is Approaching for NASA's Next Mars Rover, Perseverance
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# NASA to Hold Mars 2020 Perseverance Rover Launch Briefing
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# With supporting text below as a natural lead-in to additional content.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# With supporting text below as a natural lead-in to additional content.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# With supporting text below as a natural lead-in to additional content.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# With supporting text below as a natural lead-in to additional content.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# With supporting text below as a natural lead-in to additional content.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# With supporting text below as a natural lead-in to additional content.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# The Red Planet
#
#
#
#
# Dashboard
#
#
# Science Goals
#
#
# The Planet
#
#
#
#
#
#
#
#
# The Program
#
#
#
#
# Mission Statement
#
#
# About the Program
#
#
# Organization Why Mars?
#
#
#
#
#
#
#
#
# Multimedia
#
#
#
#
# Images
#
#
# Videos
#
#
# More Resources
#
#
#
#
#
#
#
#
# Missions
#
#
#
#
# Past
#
#
# Present
#
#
# Future

# %% [markdown]
# ### Step 3: Store the Results
#
# Extract the titles and preview text of the news articles that you scraped. Store the scraping results in Python data structures as follows:
#
# * Store each title-and-preview pair in a Python dictionary. And, give each dictionary two keys: `title` and `preview`. An example is the following:
#
#   ```python
#   {'title': "Mars Rover Begins Mission!",
#         'preview': "NASA's Mars Rover begins a multiyear mission to collect data about the little-explored planet."}
#   ```
#
# * Store all the dictionaries in a Python list.
#
# * Print the list in your notebook.

# %%
div = html_soup.find_all("div")
print(div)
# Out:
# [<div class="col-md-12">
# <div class="row">
# <nav class="navbar navbar-expand-lg navbar-light fixed-top">
# <div class="container-fluid">
# <a class="navbar-brand" href="#">
# <img src="image/nasa.png" width="80"/><span class="logo">MARS Planet Science</span>
# <span class="logo1">Exploration Program</span>
# </a>
# <button aria-controls="navbarNav" aria-expanded="false" aria-label="Toggle navigation" class="navbar-toggler" data-bs-target="#navbarNav" data-bs-toggle="collapse" type="button">
# <span class="navbar-toggler-icon"></span>
# </button>
# <div class="collapse navbar-collapse justify-content-end" id="navbarNav">
# <ul class="navbar-nav">
# <li class="nav-item">
# <a aria-current="page" class="nav-link active" href="#">The Red Planet</a>
# </li>
# <li class="nav-item">
# <a class="nav-link" href="#">The Program</a>
# </li>
# <li class="nav-item">
# <a class="nav-link" href="#">News &amp; Events</a>
# </li>
# <li class="nav-item">
# <a class="nav-link" href="#">Multimedia</a>
# </li>
# <li class="nav-item">
# <a class="nav-link" href="#">Missions</a>
# </li>
# <li class="nav-item">
# <a class="nav-link" href="#">More</a>
# </li>
# <li class="nav-item nav_search">
# <a class="nav-link" href="#"></a>
# </li>
# </ul>
# </div>
# </div>
# </nav>
# <section class="search">
# <div class="container">
# <h1>News</h1>
# <div class="col-md-12 filter">
# <div class="row">
# <div class="col-md-3 search_binder">
# <input class="search_field" name="search" type="text"/>
# <input class="search_submit" name="search" type="text"/>
# </div>
# <div class="col-md-3">
# <select aria-label="Default select example" class="form-select" id="year">
# <option selected="">Latest</option>
# <option>2020</option><option>2019</option></select>
# </div>
# <div class="col-md-3">
# <select aria-label="Default select example" class="form-select" id="cat">
# <option selected="">All Categories</option>
# <option>Press Releases</option><option>Feature Stories</option><option>Status Reports</option></select>
# </div>
# <div class="col-md-3">
# </div>
# </div>
# </div>
# </div>
# </section>
# <section class="image_and_description_container">
# <div class="container" id="news">
# <div class="col-md-12">
# <hr/>
# <div class="row">
# <div class="col-md-4">
# <div class="list_image">
# <img src="https://mars.nasa.gov/system/news_items/list_view_images/8659_1-PIA23883-MAIN-320x240.jpg"/>
# </div>
# </div>
# <div class="col-md-8">
# <div class="list_text">
# <div class="list_date">March 5, 2023</div>
# <div class="content_title">Alabama High School Student Names NASA's Mars Helicopter</div>
# <div class="article_teaser_body">Vaneeza Rupani's essay was chosen as the name for the small spacecraft, which will mark NASA's first attempt at powered flight on another planet.</div>
# </div>
# </div>
# </div>
# </div>
# <div class="col-md-12">
# <hr/>
# <div class="row">
# <div class="col-md-4">
# <div class="list_image">
# <img src="https://mars.nasa.gov/system/news_items/list_view_images/8663_PIA23316-annotated-16-320x240.jpg"/>
# </div>
# </div>
# <div class="col-md-8">
# <div class="list_text">
# <div class="list_date">March 4, 2023</div>
# <div class="content_title">NASA's Perseverance Rover Will Look at Mars Through These 'Eyes'</div>
# <div class="article_teaser_body">A pair of zoomable cameras will help scientists and rover drivers with high-resolution color images.</div>
# </div>
# </div>
# </div>
# </div>
# <div class="col-md-12">
# <hr/>
# <div class="row">
# <div class="col-md-4">
# <div class="list_image">
# <img src="https://mars.nasa.gov/system/news_items/list_view_images/8792_parachute-320x240.jpg"/>
# </div>
# </div>
# <div class="col-md-8">
# <div class="list_text">
# <div class="list_date">March 1, 2023</div>
# <div class="content_title">NASA's Perseverance Rover 100 Days Out</div>
# <div class="article_teaser_body">Mark your calendars: The agency's latest rover has only about 8,640,000 seconds to go before it touches down on the Red Planet, becoming history's next Mars car.</div>
# </div>
# </div>
# </div>
# </div>
# <div class="col-md-12">
# <hr/>
# <div class="row">
# <div class="col-md-4">
# <div class="list_image">
# <img src="https://mars.nasa.gov/system/news_items/list_view_images/8607_PIA23591-320x240.jpg"/>
# </div>
# </div>
# <div class="col-md-8">
# <div class="list_text">
# <div class="list_date">February 28, 2023</div>
# <div class="content_title">NASA's Mars 2020 Rover Goes Coast-to-Coast to Prep for Launch</div>
# <div class="article_teaser_body">The agency's first step in returning rocks from Mars just arrived at Kennedy Space Center. The Mars 2020 team now begins readying for a launch to the Red Planet this July.</div>
# </div>
# </div>
# </div>
# </div>
# <div class="col-md-12">
# <hr/>
# <div class="row">
# <div class="col-md-4">
# <div class="list_image">
# <img src="https://mars.nasa.gov/system/news_items/list_view_images/8505_PIA23275-th.jpg"/>
# </div>
# </div>
# <div class="col-md-8">
# <div class="list_text">
# <div class="list_date">February 26, 2023</div>
# <div class="content_title">Scientists Explore Outback as Testbed for Mars </div>
# <div class="article_teaser_body">Australia provides a great place for NASA's Mars 2020 and the ESA-Roscosmos ExoMars scientists to hone techniques in preparation for searching for signs ancient life on Mars.</div>
# </div>
# </div>
# </div>
# </div>
# <div class="col-md-12">
# <hr/>
# <div class="row">
# <div class="col-md-4">
# <div class="list_image">
# <img src="https://mars.nasa.gov/system/news_items/list_view_images/8756_25254_Christina_hernandez_mainmax-320x240.png"/>
# </div>
# </div>
# <div class="col-md-8">
# <div class="list_text">
# <div class="list_date">February 24, 2023</div>
# <div class="content_title">My Culture, My Voice</div>
# <div class="article_teaser_body">In honor of Hispanic Heritage Month, Christina Hernandez, an instrument engineer on the Mars 2020 mission, talks about her childhood and journey to NASA.</div>
# </div>
# </div>
# </div>
# </div>
# <div class="col-md-12">
# <hr/>
# <div class="row">
# <div class="col-md-4">
# <div class="list_image">
# <img src="https://mars.nasa.gov/system/news_items/list_view_images/8726_PIA23898-320.jpg"/>
# </div>
# </div>
# <div class="col-md-8">
# <div class="list_text">
# <div class="list_date">February 23, 2023</div>
# <div class="content_title">8 Martian Postcards to Celebrate Curiosity's Landing Anniversary</div>
# <div class="article_teaser_body">The NASA rover touched down eight years ago, on Aug. 5, 2012, and will soon be joined by a second rover, Perseverance.</div>
# </div>
# </div>
# </div>
# </div>
# <div class="col-md-12">
# <hr/>
# <div class="row">
# <div class="col-md-4">
# <div class="list_image">
# <img src="https://mars.nasa.gov/system/news_items/list_view_images/8609_list_image.jpg"/>
# </div>
# </div>
# <div class="col-md-8">
# <div class="list_text">
# <div class="list_date">February 23, 2023</div>
# <div class="content_title">NASA's Mars Reconnaissance Orbiter Undergoes Memory Update</div>
# <div class="article_teaser_body">Other orbiters will continue relaying data from Mars surface missions for a two-week period.</div>
# </div>
# </div>
# </div>
# </div>
# <div class="col-md-12">
# <hr/>
# <div class="row">
# <div class="col-md-4">
# <div class="list_image">
# <img src="https://mars.nasa.gov/system/news_items/list_view_images/8699_helicopter-delivery-system-320.jpg"/>
# </div>
# </div>
# <div class="col-md-8">
# <div class="list_text">
# <div class="list_date">February 20, 2023</div>
# <div class="content_title">How NASA's Mars Helicopter Will Reach the Red Planet's Surface</div>
# <div class="article_teaser_body">The small craft will seek to prove that powered, controlled flight is possible on another planet. But just getting it onto the surface of Mars will take a whole lot of ingenuity.</div>
# </div>
# </div>
# </div>
# </div>
# <div class="col-md-12">
# <hr/>
# <div class="row">
# <div class="col-md-4">
# <div class="list_image">
# <img src="https://mars.nasa.gov/system/news_items/list_view_images/8619_8588_name20190625-320x240.jpg"/>
# </div>
# </div>
# <div class="col-md-8">
# <div class="list_text">
# <div class="list_date">February 20, 2023</div>
# <div class="content_title">NASA to Reveal Name of Its Next Mars Rover</div>
# <div class="article_teaser_body">After a months-long contest among students to name NASA's newest Mars rover, the agency will reveal the winning name — and the winning student — this Thursday. </div>
# </div>
# </div>
# </div>
# </div>
# <div class="col-md-12">
# <hr/>
# <div class="row">
# <div class="col-md-4">
# <div class="list_image">
# <img src="https://mars.nasa.gov/system/news_items/list_view_images/8611_PIA22111-320x240.jpg"/>
# </div>
# </div>
# <div class="col-md-8">
# <div class="list_text">
# <div class="list_date">February 15, 2023</div>
# <div class="content_title">NASA Adds Return Sample Scientists to Mars 2020 Leadership Team</div>
# <div class="article_teaser_body">The leadership council for Mars 2020 science added two new members who represent the interests of scientists destined to handle and study the first samples from Red Planet.</div>
# </div>
# </div>
# </div>
# </div>
# <div class="col-md-12">
# <hr/>
# <div class="row">
# <div class="col-md-4">
# <div class="list_image">
# <img src="https://mars.nasa.gov/system/news_items/list_view_images/8778_3d-320x240.jpg"/>
# </div>
# </div>
# <div class="col-md-8">
# <div class="list_text">
# <div class="list_date">February 12, 2023</div>
# <div class="content_title">NASA's Perseverance Rover Bringing 3D-Printed Metal Parts to Mars</div>
# <div class="article_teaser_body">For hobbyists and makers, 3D printing expands creative possibilities; for specialized engineers, it's also key to next-generation spacecraft design.</div>
# </div>
# </div>
# </div>
# </div>
# <div class="col-md-12">
# <hr/>
# <div class="row">
# <div class="col-md-4">
# <div class="list_image">
# <img src="https://mars.nasa.gov/system/news_items/list_view_images/8641_PIA-23821-320x240.jpg"/>
# </div>
# </div>
# <div class="col-md-8">
# <div class="list_text">
# <div class="list_date">February 11, 2023</div>
# <div class="content_title">NASA's Perseverance Mars Rover Gets Its Wheels and Air Brakes</div>
# <div class="article_teaser_body">After the rover was shipped from JPL to Kennedy Space Center, the team is getting closer to finalizing the spacecraft for launch later this summer.</div>
# </div>
# </div>
# </div>
# </div>
# <div class="col-md-12">
# <hr/>
# <div class="row">
# <div class="col-md-4">
# <div class="list_image">
# <img src="https://mars.nasa.gov/system/news_items/list_view_images/8517_PIA23180-226.gif"/>
# </div>
# </div>
# <div class="col-md-8">
# <div class="list_text">
# <div class="list_date">February 9, 2023</div>
# <div class="content_title">NASA's InSight 'Hears' Peculiar Sounds on Mars</div>
# <div class="article_teaser_body">Listen to the marsquakes and other, less-expected sounds that the Mars lander has been detecting.</div>
# </div>
# </div>
# </div>
# </div>
# <div class="col-md-12">
# <hr/>
# <div class="row">
# <div class="col-md-4">
# <div class="list_image">
# <img src="https://mars.nasa.gov/system/news_items/list_view_images/8645_PIA23824-RoverWithHelicopter-32x24.jpg"/>
# </div>
# </div>
# <div class="col-md-8">
# <div class="list_text">
# <div class="list_date">February 5, 2023</div>
# <div class="content_title">Mars Helicopter Attached to NASA's Perseverance Rover</div>
# <div class="article_teaser_body">The team also fueled the rover's sky crane to get ready for this summer's history-making launch.</div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <hr class="container" style="margin: 25px auto;width: 83%;"/>
# <button class="btn disable" id="more" onclick="populateContent()">More</button>
# </section>
# <section class="last_news">
# <div class="container">
# <div class="row">
# <div class="col-12">
# <h2>You Might Also Like</h2>
# </div>
# <!--  <a class=" prev" href="#carouselExampleIndicators2" role="button" data-slide="prev">
#                   <i class="fas fa-angle-left"></i>
#                   </a>
#                   <a class=" next" href="#carouselExampleIndicators2" role="button" data-slide="next">
#                   <i class="fas fa-angle-right"></i>
#                   </a> -->
# <div class="col-12">
# <div class="carousel slide" data-ride="carousel" id="carouselExampleIndicators2">
# <div class="carousel-inner">
# <div class="carousel-item active">
# <div class="row">
# <div class="col-md-4 mb-3">
# <div class="card">
# <img alt="100%x280" class="img-fluid" src="https://mars.nasa.gov/system/news_items/main_images/8716_PIA23499-16.jpg"/>
# <div class="card-body">
# <p class="card-text">NASA to Broadcast Mars 2020 Perseverance Launch, Prelaunch Activities</p>
# </div>
# </div>
# </div>
# <div class="col-md-4 mb-3">
# <div class="card">
# <img alt="100%x280" class="img-fluid" src="https://mars.nasa.gov/system/news_items/main_images/8716_PIA23499-16.jpg"/>
# <div class="card-body">
# <p class="card-text">The Launch Is Approaching for NASA's Next Mars Rover, Perseverance</p>
# </div>
# </div>
# </div>
# <div class="col-md-4 mb-3">
# <div class="card">
# <img alt="100%x280" class="img-fluid" src="https://mars.nasa.gov/system/news_items/main_images/8692_PIA23920-web.jpg"/>
# <div class="card-body">
# <p class="card-text">NASA to Hold Mars 2020 Perseverance Rover Launch Briefing</p>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="carousel-item">
# <div class="row">
# <div class="col-md-4 mb-3">
# <div class="card">
# <img alt="100%x280" class="img-fluid" src="https://images.unsplash.com/photo-1532771098148-525cefe10c23?ixlib=rb-0.3.5&amp;q=80&amp;fm=jpg&amp;crop=entropy&amp;cs=tinysrgb&amp;w=1080&amp;fit=max&amp;ixid=eyJhcHBfaWQiOjMyMDc0fQ&amp;s=3f317c1f7a16116dec454fbc267dd8e4"/>
# <div class="card-body">
# <p class="card-text">With supporting text below as a natural lead-in to additional content.</p>
# </div>
# </div>
# </div>
# <div class="col-md-4 mb-3">
# <div class="card">
# <img alt="100%x280" class="img-fluid" src="https://images.unsplash.com/photo-1532715088550-62f09305f765?ixlib=rb-0.3.5&amp;q=80&amp;fm=jpg&amp;crop=entropy&amp;cs=tinysrgb&amp;w=1080&amp;fit=max&amp;ixid=eyJhcHBfaWQiOjMyMDc0fQ&amp;s=ebadb044b374504ef8e81bdec4d0e840"/>
# <div class="card-body">
# <p class="card-text">With supporting text below as a natural lead-in to additional content.</p>
# </div>
# </div>
# </div>
# <div class="col-md-4 mb-3">
# <div class="card">
# <img alt="100%x280" class="img-fluid" src="https://images.unsplash.com/photo-1506197603052-3cc9c3a201bd?ixlib=rb-0.3.5&amp;q=80&amp;fm=jpg&amp;crop=entropy&amp;cs=tinysrgb&amp;w=1080&amp;fit=max&amp;ixid=eyJhcHBfaWQiOjMyMDc0fQ&amp;s=0754ab085804ae8a3b562548e6b4aa2e"/>
# <div class="card-body">
# <p class="card-text">With supporting text below as a natural lead-in to additional content.</p>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="carousel-item">
# <div class="row">
# <div class="col-md-4 mb-3">
# <div class="card">
# <img alt="100%x280" class="img-fluid" src="https://images.unsplash.com/photo-1507525428034-b723cf961d3e?ixlib=rb-0.3.5&amp;q=80&amp;fm=jpg&amp;crop=entropy&amp;cs=tinysrgb&amp;w=1080&amp;fit=max&amp;ixid=eyJhcHBfaWQiOjMyMDc0fQ&amp;s=ee8417f0ea2a50d53a12665820b54e23"/>
# <div class="card-body">
# <p class="card-text">With supporting text below as a natural lead-in to additional content.</p>
# </div>
# </div>
# </div>
# <div class="col-md-4 mb-3">
# <div class="card">
# <img alt="100%x280" class="img-fluid" src="https://images.unsplash.com/photo-1532777946373-b6783242f211?ixlib=rb-0.3.5&amp;q=80&amp;fm=jpg&amp;crop=entropy&amp;cs=tinysrgb&amp;w=1080&amp;fit=max&amp;ixid=eyJhcHBfaWQiOjMyMDc0fQ&amp;s=8ac55cf3a68785643998730839663129"/>
# <div class="card-body">
# <p class="card-text">With supporting text below as a natural lead-in to additional content.</p>
# </div>
# </div>
# </div>
# <div class="col-md-4 mb-3">
# <div class="card">
# <img alt="100%x280" class="img-fluid" src="https://images.unsplash.com/photo-1532763303805-529d595877c5?ixlib=rb-0.3.5&amp;q=80&amp;fm=jpg&amp;crop=entropy&amp;cs=tinysrgb&amp;w=1080&amp;fit=max&amp;ixid=eyJhcHBfaWQiOjMyMDc0fQ&amp;s=5ee4fd5d19b40f93eadb21871757eda6"/>
# <div class="card-body">
# <p class="card-text">With supporting text below as a natural lead-in to additional content.</p>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </section>
# <section class="footer">
# <div class="container">
# <div class="col-md-12">
# <div class="row">
# <div class="col-md-3">
# <h5>The Red Planet</h5>
# <ul>
# <li>Dashboard</li>
# <li>Science Goals</li>
# <li>The Planet</li>
# </ul>
# </div>
# <div class="col-md-3">
# <h5>The Program</h5>
# <ul>
# <li>Mission Statement</li>
# <li>About the Program</li>
# <li>Organization Why Mars?</li>
# </ul>
# </div>
# <div class="col-md-3">
# <h5>Multimedia</h5>
# <ul>
# <li>Images</li>
# <li>Videos</li>
# <li>More Resources</li>
# </ul>
# </div>
# <div class="col-md-3">
# <h5>Missions</h5>
# <ul>
# <li>Past</li>
# <li>Present</li>
# <li>Future</li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </section>
# <script src="https://code.jquery.com/jquery-1.12.4.min.js" type="text/javascript"></script>
# <script src="https://cdn.jsdelivr.net/npm/@popperjs/core@2.5.4/dist/umd/popper.min.js"></script>
# <script src="https://cdn.jsdelivr.net/npm/bootstrap@5.0.0-beta1/dist/js/bootstrap.min.js"></script>
# <script src="js/app.js"></script>
# </div></div>, <div class="row">
# <nav class="navbar navbar-expand-lg navbar-light fixed-top">
# <div class="container-fluid">
# <a class="navbar-brand" href="#">
# <img src="image/nasa.png" width="80"/><span class="logo">MARS Planet Science</span>
# <span class="logo1">Exploration Program</span>
# </a>
# <button aria-controls="navbarNav" aria-expanded="false" aria-label="Toggle navigation" class="navbar-toggler" data-bs-target="#navbarNav" data-bs-toggle="collapse" type="button">
# <span class="navbar-toggler-icon"></span>
# </button>
# <div class="collapse navbar-collapse justify-content-end" id="navbarNav">
# <ul class="navbar-nav">
# <li class="nav-item">
# <a aria-current="page" class="nav-link active" href="#">The Red Planet</a>
# </li>
# <li class="nav-item">
# <a class="nav-link" href="#">The Program</a>
# </li>
# <li class="nav-item">
# <a class="nav-link" href="#">News &amp; Events</a>
# </li>
# <li class="nav-item">
# <a class="nav-link" href="#">Multimedia</a>
# </li>
# <li class="nav-item">
# <a class="nav-link" href="#">Missions</a>
# </li>
# <li class="nav-item">
# <a class="nav-link" href="#">More</a>
# </li>
# <li class="nav-item nav_search">
# <a class="nav-link" href="#"></a>
# </li>
# </ul>
# </div>
# </div>
# </nav>
# <section class="search">
# <div class="container">
# <h1>News</h1>
# <div class="col-md-12 filter">
# <div class="row">
# <div class="col-md-3 search_binder">
# <input class="search_field" name="search" type="text"/>
# <input class="search_submit" name="search" type="text"/>
# </div>
# <div class="col-md-3">
# <select aria-label="Default select example" class="form-select" id="year">
# <option selected="">Latest</option>
# <option>2020</option><option>2019</option></select>
# </div>
# <div class="col-md-3">
# <select aria-label="Default select example" class="form-select" id="cat">
# <option selected="">All Categories</option>
# <option>Press Releases</option><option>Feature Stories</option><option>Status Reports</option></select>
# </div>
# <div class="col-md-3">
# </div>
# </div>
# </div>
# </div>
# </section>
# <section class="image_and_description_container">
# <div class="container" id="news">
# <div class="col-md-12">
# <hr/>
# <div class="row">
# <div class="col-md-4">
# <div class="list_image">
# <img src="https://mars.nasa.gov/system/news_items/list_view_images/8659_1-PIA23883-MAIN-320x240.jpg"/>
# </div>
# </div>
# <div class="col-md-8">
# <div class="list_text">
# <div class="list_date">March 5, 2023</div>
# <div class="content_title">Alabama High School Student Names NASA's Mars Helicopter</div>
# <div class="article_teaser_body">Vaneeza Rupani's essay was chosen as the name for the small spacecraft, which will mark NASA's first attempt at powered flight on another planet.</div>
# </div>
# </div>
# </div>
# </div>
# <div class="col-md-12">
# <hr/>
# <div class="row">
# <div class="col-md-4">
# <div class="list_image">
# <img src="https://mars.nasa.gov/system/news_items/list_view_images/8663_PIA23316-annotated-16-320x240.jpg"/>
# </div>
# </div>
# <div class="col-md-8">
# <div class="list_text">
# <div class="list_date">March 4, 2023</div>
# <div class="content_title">NASA's Perseverance Rover Will Look at Mars Through These 'Eyes'</div>
# <div class="article_teaser_body">A pair of zoomable cameras will help scientists and rover drivers with high-resolution color images.</div>
# </div>
# </div>
# </div>
# </div>
# <div class="col-md-12">
# <hr/>
# <div class="row">
# <div class="col-md-4">
# <div class="list_image">
# <img src="https://mars.nasa.gov/system/news_items/list_view_images/8792_parachute-320x240.jpg"/>
# </div>
# </div>
# <div class="col-md-8">
# <div class="list_text">
# <div class="list_date">March 1, 2023</div>
# <div class="content_title">NASA's Perseverance Rover 100 Days Out</div>
# <div class="article_teaser_body">Mark your calendars: The agency's latest rover has only about 8,640,000 seconds to go before it touches down on the Red Planet, becoming history's next Mars car.</div>
# </div>
# </div>
# </div>
# </div>
# <div class="col-md-12">
# <hr/>
# <div class="row">
# <div class="col-md-4">
# <div class="list_image">
# <img src="https://mars.nasa.gov/system/news_items/list_view_images/8607_PIA23591-320x240.jpg"/>
# </div>
# </div>
# <div class="col-md-8">
# <div class="list_text">
# <div class="list_date">February 28, 2023</div>
# <div class="content_title">NASA's Mars 2020 Rover Goes Coast-to-Coast to Prep for Launch</div>
# <div class="article_teaser_body">The agency's first step in returning rocks from Mars just arrived at Kennedy Space Center. The Mars 2020 team now begins readying for a launch to the Red Planet this July.</div>
# </div>
# </div>
# </div>
# </div>
# <div class="col-md-12">
# <hr/>
# <div class="row">
# <div class="col-md-4">
# <div class="list_image">
# <img src="https://mars.nasa.gov/system/news_items/list_view_images/8505_PIA23275-th.jpg"/>
# </div>
# </div>
# <div class="col-md-8">
# <div class="list_text">
# <div class="list_date">February 26, 2023</div>
# <div class="content_title">Scientists Explore Outback as Testbed for Mars </div>
# <div class="article_teaser_body">Australia provides a great place for NASA's Mars 2020 and the ESA-Roscosmos ExoMars scientists to hone techniques in preparation for searching for signs ancient life on Mars.</div>
# </div>
# </div>
# </div>
# </div>
# <div class="col-md-12">
# <hr/>
# <div class="row">
# <div class="col-md-4">
# <div class="list_image">
# <img src="https://mars.nasa.gov/system/news_items/list_view_images/8756_25254_Christina_hernandez_mainmax-320x240.png"/>
# </div>
# </div>
# <div class="col-md-8">
# <div class="list_text">
# <div class="list_date">February 24, 2023</div>
# <div class="content_title">My Culture, My Voice</div>
# <div class="article_teaser_body">In honor of Hispanic Heritage Month, Christina Hernandez, an instrument engineer on the Mars 2020 mission, talks about her childhood and journey to NASA.</div>
# </div>
# </div>
# </div>
# </div>
# <div class="col-md-12">
# <hr/>
# <div class="row">
# <div class="col-md-4">
# <div class="list_image">
# <img src="https://mars.nasa.gov/system/news_items/list_view_images/8726_PIA23898-320.jpg"/>
# </div>
# </div>
# <div class="col-md-8">
# <div class="list_text">
# <div class="list_date">February 23, 2023</div>
# <div class="content_title">8 Martian Postcards to Celebrate Curiosity's Landing Anniversary</div>
# <div class="article_teaser_body">The NASA rover touched down eight years ago, on Aug. 5, 2012, and will soon be joined by a second rover, Perseverance.</div>
# </div>
# </div>
# </div>
# </div>
# <div class="col-md-12">
# <hr/>
# <div class="row">
# <div class="col-md-4">
# <div class="list_image">
# <img src="https://mars.nasa.gov/system/news_items/list_view_images/8609_list_image.jpg"/>
# </div>
# </div>
# <div class="col-md-8">
# <div class="list_text">
# <div class="list_date">February 23, 2023</div>
# <div class="content_title">NASA's Mars Reconnaissance Orbiter Undergoes Memory Update</div>
# <div class="article_teaser_body">Other orbiters will continue relaying data from Mars surface missions for a two-week period.</div>
# </div>
# </div>
# </div>
# </div>
# <div class="col-md-12">
# <hr/>
# <div class="row">
# <div class="col-md-4">
# <div class="list_image">
# <img src="https://mars.nasa.gov/system/news_items/list_view_images/8699_helicopter-delivery-system-320.jpg"/>
# </div>
# </div>
# <div class="col-md-8">
# <div class="list_text">
# <div class="list_date">February 20, 2023</div>
# <div class="content_title">How NASA's Mars Helicopter Will Reach the Red Planet's Surface</div>
# <div class="article_teaser_body">The small craft will seek to prove that powered, controlled flight is possible on another planet. But just getting it onto the surface of Mars will take a whole lot of ingenuity.</div>
# </div>
# </div>
# </div>
# </div>
# <div class="col-md-12">
# <hr/>
# <div class="row">
# <div class="col-md-4">
# <div class="list_image">
# <img src="https://mars.nasa.gov/system/news_items/list_view_images/8619_8588_name20190625-320x240.jpg"/>
# </div>
# </div>
# <div class="col-md-8">
# <div class="list_text">
# <div class="list_date">February 20, 2023</div>
# <div class="content_title">NASA to Reveal Name of Its Next Mars Rover</div>
# <div class="article_teaser_body">After a months-long contest among students to name NASA's newest Mars rover, the agency will reveal the winning name — and the winning student — this Thursday. </div>
# </div>
# </div>
# </div>
# </div>
# <div class="col-md-12">
# <hr/>
# <div class="row">
# <div class="col-md-4">
# <div class="list_image">
# <img src="https://mars.nasa.gov/system/news_items/list_view_images/8611_PIA22111-320x240.jpg"/>
# </div>
# </div>
# <div class="col-md-8">
# <div class="list_text">
# <div class="list_date">February 15, 2023</div>
# <div class="content_title">NASA Adds Return Sample Scientists to Mars 2020 Leadership Team</div>
# <div class="article_teaser_body">The leadership council for Mars 2020 science added two new members who represent the interests of scientists destined to handle and study the first samples from Red Planet.</div>
# </div>
# </div>
# </div>
# </div>
# <div class="col-md-12">
# <hr/>
# <div class="row">
# <div class="col-md-4">
# <div class="list_image">
# <img src="https://mars.nasa.gov/system/news_items/list_view_images/8778_3d-320x240.jpg"/>
# </div>
# </div>
# <div class="col-md-8">
# <div class="list_text">
# <div class="list_date">February 12, 2023</div>
# <div class="content_title">NASA's Perseverance Rover Bringing 3D-Printed Metal Parts to Mars</div>
# <div class="article_teaser_body">For hobbyists and makers, 3D printing expands creative possibilities; for specialized engineers, it's also key to next-generation spacecraft design.</div>
# </div>
# </div>
# </div>
# </div>
# <div class="col-md-12">
# <hr/>
# <div class="row">
# <div class="col-md-4">
# <div class="list_image">
# <img src="https://mars.nasa.gov/system/news_items/list_view_images/8641_PIA-23821-320x240.jpg"/>
# </div>
# </div>
# <div class="col-md-8">
# <div class="list_text">
# <div class="list_date">February 11, 2023</div>
# <div class="content_title">NASA's Perseverance Mars Rover Gets Its Wheels and Air Brakes</div>
# <div class="article_teaser_body">After the rover was shipped from JPL to Kennedy Space Center, the team is getting closer to finalizing the spacecraft for launch later this summer.</div>
# </div>
# </div>
# </div>
# </div>
# <div class="col-md-12">
# <hr/>
# <div class="row">
# <div class="col-md-4">
# <div class="list_image">
# <img src="https://mars.nasa.gov/system/news_items/list_view_images/8517_PIA23180-226.gif"/>
# </div>
# </div>
# <div class="col-md-8">
# <div class="list_text">
# <div class="list_date">February 9, 2023</div>
# <div class="content_title">NASA's InSight 'Hears' Peculiar Sounds on Mars</div>
# <div class="article_teaser_body">Listen to the marsquakes and other, less-expected sounds that the Mars lander has been detecting.</div>
# </div>
# </div>
# </div>
# </div>
# <div class="col-md-12">
# <hr/>
# <div class="row">
# <div class="col-md-4">
# <div class="list_image">
# <img src="https://mars.nasa.gov/system/news_items/list_view_images/8645_PIA23824-RoverWithHelicopter-32x24.jpg"/>
# </div>
# </div>
# <div class="col-md-8">
# <div class="list_text">
# <div class="list_date">February 5, 2023</div>
# <div class="content_title">Mars Helicopter Attached to NASA's Perseverance Rover</div>
# <div class="article_teaser_body">The team also fueled the rover's sky crane to get ready for this summer's history-making launch.</div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <hr class="container" style="margin: 25px auto;width: 83%;"/>
# <button class="btn disable" id="more" onclick="populateContent()">More</button>
# </section>
# <section class="last_news">
# <div class="container">
# <div class="row">
# <div class="col-12">
# <h2>You Might Also Like</h2>
# </div>
# <!--  <a class=" prev" href="#carouselExampleIndicators2" role="button" data-slide="prev">
#                   <i class="fas fa-angle-left"></i>
#                   </a>
#                   <a class=" next" href="#carouselExampleIndicators2" role="button" data-slide="next">
#                   <i class="fas fa-angle-right"></i>
#                   </a> -->
# <div class="col-12">
# <div class="carousel slide" data-ride="carousel" id="carouselExampleIndicators2">
# <div class="carousel-inner">
# <div class="carousel-item active">
# <div class="row">
# <div class="col-md-4 mb-3">
# <div class="card">
# <img alt="100%x280" class="img-fluid" src="https://mars.nasa.gov/system/news_items/main_images/8716_PIA23499-16.jpg"/>
# <div class="card-body">
# <p class="card-text">NASA to Broadcast Mars 2020 Perseverance Launch, Prelaunch Activities</p>
# </div>
# </div>
# </div>
# <div class="col-md-4 mb-3">
# <div class="card">
# <img alt="100%x280" class="img-fluid" src="https://mars.nasa.gov/system/news_items/main_images/8716_PIA23499-16.jpg"/>
# <div class="card-body">
# <p class="card-text">The Launch Is Approaching for NASA's Next Mars Rover, Perseverance</p>
# </div>
# </div>
# </div>
# <div class="col-md-4 mb-3">
# <div class="card">
# <img alt="100%x280" class="img-fluid" src="https://mars.nasa.gov/system/news_items/main_images/8692_PIA23920-web.jpg"/>
# <div class="card-body">
# <p class="card-text">NASA to Hold Mars 2020 Perseverance Rover Launch Briefing</p>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="carousel-item">
# <div class="row">
# <div class="col-md-4 mb-3">
# <div class="card">
# <img alt="100%x280" class="img-fluid" src="https://images.unsplash.com/photo-1532771098148-525cefe10c23?ixlib=rb-0.3.5&amp;q=80&amp;fm=jpg&amp;crop=entropy&amp;cs=tinysrgb&amp;w=1080&amp;fit=max&amp;ixid=eyJhcHBfaWQiOjMyMDc0fQ&amp;s=3f317c1f7a16116dec454fbc267dd8e4"/>
# <div class="card-body">
# <p class="card-text">With supporting text below as a natural lead-in to additional content.</p>
# </div>
# </div>
# </div>
# <div class="col-md-4 mb-3">
# <div class="card">
# <img alt="100%x280" class="img-fluid" src="https://images.unsplash.com/photo-1532715088550-62f09305f765?ixlib=rb-0.3.5&amp;q=80&amp;fm=jpg&amp;crop=entropy&amp;cs=tinysrgb&amp;w=1080&amp;fit=max&amp;ixid=eyJhcHBfaWQiOjMyMDc0fQ&amp;s=ebadb044b374504ef8e81bdec4d0e840"/>
# <div class="card-body">
# <p class="card-text">With supporting text below as a natural lead-in to additional content.</p>
# </div>
# </div>
# </div>
# <div class="col-md-4 mb-3">
# <div class="card">
# <img alt="100%x280" class="img-fluid" src="https://images.unsplash.com/photo-1506197603052-3cc9c3a201bd?ixlib=rb-0.3.5&amp;q=80&amp;fm=jpg&amp;crop=entropy&amp;cs=tinysrgb&amp;w=1080&amp;fit=max&amp;ixid=eyJhcHBfaWQiOjMyMDc0fQ&amp;s=0754ab085804ae8a3b562548e6b4aa2e"/>
# <div class="card-body">
# <p class="card-text">With supporting text below as a natural lead-in to additional content.</p>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="carousel-item">
# <div class="row">
# <div class="col-md-4 mb-3">
# <div class="card">
# <img alt="100%x280" class="img-fluid" src="https://images.unsplash.com/photo-1507525428034-b723cf961d3e?ixlib=rb-0.3.5&amp;q=80&amp;fm=jpg&amp;crop=entropy&amp;cs=tinysrgb&amp;w=1080&amp;fit=max&amp;ixid=eyJhcHBfaWQiOjMyMDc0fQ&amp;s=ee8417f0ea2a50d53a12665820b54e23"/>
# <div class="card-body">
# <p class="card-text">With supporting text below as a natural lead-in to additional content.</p>
# </div>
# </div>
# </div>
# <div class="col-md-4 mb-3">
# <div class="card">
# <img alt="100%x280" class="img-fluid" src="https://images.unsplash.com/photo-1532777946373-b6783242f211?ixlib=rb-0.3.5&amp;q=80&amp;fm=jpg&amp;crop=entropy&amp;cs=tinysrgb&amp;w=1080&amp;fit=max&amp;ixid=eyJhcHBfaWQiOjMyMDc0fQ&amp;s=8ac55cf3a68785643998730839663129"/>
# <div class="card-body">
# <p class="card-text">With supporting text below as a natural lead-in to additional content.</p>
# </div>
# </div>
# </div>
# <div class="col-md-4 mb-3">
# <div class="card">
# <img alt="100%x280" class="img-fluid" src="https://images.unsplash.com/photo-1532763303805-529d595877c5?ixlib=rb-0.3.5&amp;q=80&amp;fm=jpg&amp;crop=entropy&amp;cs=tinysrgb&amp;w=1080&amp;fit=max&amp;ixid=eyJhcHBfaWQiOjMyMDc0fQ&amp;s=5ee4fd5d19b40f93eadb21871757eda6"/>
# <div class="card-body">
# <p class="card-text">With supporting text below as a natural lead-in to additional content.</p>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </section>
# <section class="footer">
# <div class="container">
# <div class="col-md-12">
# <div class="row">
# <div class="col-md-3">
# <h5>The Red Planet</h5>
# <ul>
# <li>Dashboard</li>
# <li>Science Goals</li>
# <li>The Planet</li>
# </ul>
# </div>
# <div class="col-md-3">
# <h5>The Program</h5>
# <ul>
# <li>Mission Statement</li>
# <li>About the Program</li>
# <li>Organization Why Mars?</li>
# </ul>
# </div>
# <div class="col-md-3">
# <h5>Multimedia</h5>
# <ul>
# <li>Images</li>
# <li>Videos</li>
# <li>More Resources</li>
# </ul>
# </div>
# <div class="col-md-3">
# <h5>Missions</h5>
# <ul>
# <li>Past</li>
# <li>Present</li>
# <li>Future</li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </section>
# <script src="https://code.jquery.com/jquery-1.12.4.min.js" type="text/javascript"></script>
# <script src="https://cdn.jsdelivr.net/npm/@popperjs/core@2.5.4/dist/umd/popper.min.js"></script>
# <script src="https://cdn.jsdelivr.net/npm/bootstrap@5.0.0-beta1/dist/js/bootstrap.min.js"></script>
# <script src="js/app.js"></script>
# </div>, <div class="container-fluid">
# <a class="navbar-brand" href="#">
# <img src="image/nasa.png" width="80"/><span class="logo">MARS Planet Science</span>
# <span class="logo1">Exploration Program</span>
# </a>
# <button aria-controls="navbarNav" aria-expanded="false" aria-label="Toggle navigation" class="navbar-toggler" data-bs-target="#navbarNav" data-bs-toggle="collapse" type="button">
# <span class="navbar-toggler-icon"></span>
# </button>
# <div class="collapse navbar-collapse justify-content-end" id="navbarNav">
# <ul class="navbar-nav">
# <li class="nav-item">
# <a aria-current="page" class="nav-link active" href="#">The Red Planet</a>
# </li>
# <li class="nav-item">
# <a class="nav-link" href="#">The Program</a>
# </li>
# <li class="nav-item">
# <a class="nav-link" href="#">News &amp; Events</a>
# </li>
# <li class="nav-item">
# <a class="nav-link" href="#">Multimedia</a>
# </li>
# <li class="nav-item">
# <a class="nav-link" href="#">Missions</a>
# </li>
# <li class="nav-item">
# <a class="nav-link" href="#">More</a>
# </li>
# <li class="nav-item nav_search">
# <a class="nav-link" href="#"></a>
# </li>
# </ul>
# </div>
# </div>, <div class="collapse navbar-collapse justify-content-end" id="navbarNav">
# <ul class="navbar-nav">
# <li class="nav-item">
# <a aria-current="page" class="nav-link active" href="#">The Red Planet</a>
# </li>
# <li class="nav-item">
# <a class="nav-link" href="#">The Program</a>
# </li>
# <li class="nav-item">
# <a class="nav-link" href="#">News &amp; Events</a>
# </li>
# <li class="nav-item">
# <a class="nav-link" href="#">Multimedia</a>
# </li>
# <li class="nav-item">
# <a class="nav-link" href="#">Missions</a>
# </li>
# <li class="nav-item">
# <a class="nav-link" href="#">More</a>
# </li>
# <li class="nav-item nav_search">
# <a class="nav-link" href="#"></a>
# </li>
# </ul>
# </div>, <div class="container">
# <h1>News</h1>
# <div class="col-md-12 filter">
# <div class="row">
# <div class="col-md-3 search_binder">
# <input class="search_field" name="search" type="text"/>
# <input class="search_submit" name="search" type="text"/>
# </div>
# <div class="col-md-3">
# <select aria-label="Default select example" class="form-select" id="year">
# <option selected="">Latest</option>
# <option>2020</option><option>2019</option></select>
# </div>
# <div class="col-md-3">
# <select aria-label="Default select example" class="form-select" id="cat">
# <option selected="">All Categories</option>
# <option>Press Releases</option><option>Feature Stories</option><option>Status Reports</option></select>
# </div>
# <div class="col-md-3">
# </div>
# </div>
# </div>
# </div>, <div class="col-md-12 filter">
# <div class="row">
# <div class="col-md-3 search_binder">
# <input class="search_field" name="search" type="text"/>
# <input class="search_submit" name="search" type="text"/>
# </div>
# <div class="col-md-3">
# <select aria-label="Default select example" class="form-select" id="year">
# <option selected="">Latest</option>
# <option>2020</option><option>2019</option></select>
# </div>
# <div class="col-md-3">
# <select aria-label="Default select example" class="form-select" id="cat">
# <option selected="">All Categories</option>
# <option>Press Releases</option><option>Feature Stories</option><option>Status Reports</option></select>
# </div>
# <div class="col-md-3">
# </div>
# </div>
# </div>, <div class="row">
# <div class="col-md-3 search_binder">
# <input class="search_field" name="search" type="text"/>
# <input class="search_submit" name="search" type="text"/>
# </div>
# <div class="col-md-3">
# <select aria-label="Default select example" class="form-select" id="year">
# <option selected="">Latest</option>
# <option>2020</option><option>2019</option></select>
# </div>
# <div class="col-md-3">
# <select aria-label="Default select example" class="form-select" id="cat">
# <option selected="">All Categories</option>
# <option>Press Releases</option><option>Feature Stories</option><option>Status Reports</option></select>
# </div>
# <div class="col-md-3">
# </div>
# </div>, <div class="col-md-3 search_binder">
# <input class="search_field" name="search" type="text"/>
# <input class="search_submit" name="search" type="text"/>
# </div>, <div class="col-md-3">
# <select aria-label="Default select example" class="form-select" id="year">
# <option selected="">Latest</option>
# <option>2020</option><option>2019</option></select>
# </div>, <div class="col-md-3">
# <select aria-label="Default select example" class="form-select" id="cat">
# <option selected="">All Categories</option>
# <option>Press Releases</option><option>Feature Stories</option><option>Status Reports</option></select>
# </div>, <div class="col-md-3">
# </div>, <div class="container" id="news">
# <div class="col-md-12">
# <hr/>
# <div class="row">
# <div class="col-md-4">
# <div class="list_image">
# <img src="https://mars.nasa.gov/system/news_items/list_view_images/8659_1-PIA23883-MAIN-320x240.jpg"/>
# </div>
# </div>
# <div class="col-md-8">
# <div class="list_text">
# <div class="list_date">March 5, 2023</div>
# <div class="content_title">Alabama High School Student Names NASA's Mars Helicopter</div>
# <div class="article_teaser_body">Vaneeza Rupani's essay was chosen as the name for the small spacecraft, which will mark NASA's first attempt at powered flight on another planet.</div>
# </div>
# </div>
# </div>
# </div>
# <div class="col-md-12">
# <hr/>
# <div class="row">
# <div class="col-md-4">
# <div class="list_image">
# <img src="https://mars.nasa.gov/system/news_items/list_view_images/8663_PIA23316-annotated-16-320x240.jpg"/>
# </div>
# </div>
# <div class="col-md-8">
# <div class="list_text">
# <div class="list_date">March 4, 2023</div>
# <div class="content_title">NASA's Perseverance Rover Will Look at Mars Through These 'Eyes'</div>
# <div class="article_teaser_body">A pair of zoomable cameras will help scientists and rover drivers with high-resolution color images.</div>
# </div>
# </div>
# </div>
# </div>
# <div class="col-md-12">
# <hr/>
# <div class="row">
# <div class="col-md-4">
# <div class="list_image">
# <img src="https://mars.nasa.gov/system/news_items/list_view_images/8792_parachute-320x240.jpg"/>
# </div>
# </div>
# <div class="col-md-8">
# <div class="list_text">
# <div class="list_date">March 1, 2023</div>
# <div class="content_title">NASA's Perseverance Rover 100 Days Out</div>
# <div class="article_teaser_body">Mark your calendars: The agency's latest rover has only about 8,640,000 seconds to go before it touches down on the Red Planet, becoming history's next Mars car.</div>
# </div>
# </div>
# </div>
# </div>
# <div class="col-md-12">
# <hr/>
# <div class="row">
# <div class="col-md-4">
# <div class="list_image">
# <img src="https://mars.nasa.gov/system/news_items/list_view_images/8607_PIA23591-320x240.jpg"/>
# </div>
# </div>
# <div class="col-md-8">
# <div class="list_text">
# <div class="list_date">February 28, 2023</div>
# <div class="content_title">NASA's Mars 2020 Rover Goes Coast-to-Coast to Prep for Launch</div>
# <div class="article_teaser_body">The agency's first step in returning rocks from Mars just arrived at Kennedy Space Center. The Mars 2020 team now begins readying for a launch to the Red Planet this July.</div>
# </div>
# </div>
# </div>
# </div>
# <div class="col-md-12">
# <hr/>
# <div class="row">
# <div class="col-md-4">
# <div class="list_image">
# <img src="https://mars.nasa.gov/system/news_items/list_view_images/8505_PIA23275-th.jpg"/>
# </div>
# </div>
# <div class="col-md-8">
# <div class="list_text">
# <div class="list_date">February 26, 2023</div>
# <div class="content_title">Scientists Explore Outback as Testbed for Mars </div>
# <div class="article_teaser_body">Australia provides a great place for NASA's Mars 2020 and the ESA-Roscosmos ExoMars scientists to hone techniques in preparation for searching for signs ancient life on Mars.</div>
# </div>
# </div>
# </div>
# </div>
# <div class="col-md-12">
# <hr/>
# <div class="row">
# <div class="col-md-4">
# <div class="list_image">
# <img src="https://mars.nasa.gov/system/news_items/list_view_images/8756_25254_Christina_hernandez_mainmax-320x240.png"/>
# </div>
# </div>
# <div class="col-md-8">
# <div class="list_text">
# <div class="list_date">February 24, 2023</div>
# <div class="content_title">My Culture, My Voice</div>
# <div class="article_teaser_body">In honor of Hispanic Heritage Month, Christina Hernandez, an instrument engineer on the Mars 2020 mission, talks about her childhood and journey to NASA.</div>
# </div>
# </div>
# </div>
# </div>
# <div class="col-md-12">
# <hr/>
# <div class="row">
# <div class="col-md-4">
# <div class="list_image">
# <img src="https://mars.nasa.gov/system/news_items/list_view_images/8726_PIA23898-320.jpg"/>
# </div>
# </div>
# <div class="col-md-8">
# <div class="list_text">
# <div class="list_date">February 23, 2023</div>
# <div class="content_title">8 Martian Postcards to Celebrate Curiosity's Landing Anniversary</div>
# <div class="article_teaser_body">The NASA rover touched down eight years ago, on Aug. 5, 2012, and will soon be joined by a second rover, Perseverance.</div>
# </div>
# </div>
# </div>
# </div>
# <div class="col-md-12">
# <hr/>
# <div class="row">
# <div class="col-md-4">
# <div class="list_image">
# <img src="https://mars.nasa.gov/system/news_items/list_view_images/8609_list_image.jpg"/>
# </div>
# </div>
# <div class="col-md-8">
# <div class="list_text">
# <div class="list_date">February 23, 2023</div>
# <div class="content_title">NASA's Mars Reconnaissance Orbiter Undergoes Memory Update</div>
# <div class="article_teaser_body">Other orbiters will continue relaying data from Mars surface missions for a two-week period.</div>
# </div>
# </div>
# </div>
# </div>
# <div class="col-md-12">
# <hr/>
# <div class="row">
# <div class="col-md-4">
# <div class="list_image">
# <img src="https://mars.nasa.gov/system/news_items/list_view_images/8699_helicopter-delivery-system-320.jpg"/>
# </div>
# </div>
# <div class="col-md-8">
# <div class="list_text">
# <div class="list_date">February 20, 2023</div>
# <div class="content_title">How NASA's Mars Helicopter Will Reach the Red Planet's Surface</div>
# <div class="article_teaser_body">The small craft will seek to prove that powered, controlled flight is possible on another planet. But just getting it onto the surface of Mars will take a whole lot of ingenuity.</div>
# </div>
# </div>
# </div>
# </div>
# <div class="col-md-12">
# <hr/>
# <div class="row">
# <div class="col-md-4">
# <div class="list_image">
# <img src="https://mars.nasa.gov/system/news_items/list_view_images/8619_8588_name20190625-320x240.jpg"/>
# </div>
# </div>
# <div class="col-md-8">
# <div class="list_text">
# <div class="list_date">February 20, 2023</div>
# <div class="content_title">NASA to Reveal Name of Its Next Mars Rover</div>
# <div class="article_teaser_body">After a months-long contest among students to name NASA's newest Mars rover, the agency will reveal the winning name — and the winning student — this Thursday. </div>
# </div>
# </div>
# </div>
# </div>
# <div class="col-md-12">
# <hr/>
# <div class="row">
# <div class="col-md-4">
# <div class="list_image">
# <img src="https://mars.nasa.gov/system/news_items/list_view_images/8611_PIA22111-320x240.jpg"/>
# </div>
# </div>
# <div class="col-md-8">
# <div class="list_text">
# <div class="list_date">February 15, 2023</div>
# <div class="content_title">NASA Adds Return Sample Scientists to Mars 2020 Leadership Team</div>
# <div class="article_teaser_body">The leadership council for Mars 2020 science added two new members who represent the interests of scientists destined to handle and study the first samples from Red Planet.</div>
# </div>
# </div>
# </div>
# </div>
# <div class="col-md-12">
# <hr/>
# <div class="row">
# <div class="col-md-4">
# <div class="list_image">
# <img src="https://mars.nasa.gov/system/news_items/list_view_images/8778_3d-320x240.jpg"/>
# </div>
# </div>
# <div class="col-md-8">
# <div class="list_text">
# <div class="list_date">February 12, 2023</div>
# <div class="content_title">NASA's Perseverance Rover Bringing 3D-Printed Metal Parts to Mars</div>
# <div class="article_teaser_body">For hobbyists and makers, 3D printing expands creative possibilities; for specialized engineers, it's also key to next-generation spacecraft design.</div>
# </div>
# </div>
# </div>
# </div>
# <div class="col-md-12">
# <hr/>
# <div class="row">
# <div class="col-md-4">
# <div class="list_image">
# <img src="https://mars.nasa.gov/system/news_items/list_view_images/8641_PIA-23821-320x240.jpg"/>
# </div>
# </div>
# <div class="col-md-8">
# <div class="list_text">
# <div class="list_date">February 11, 2023</div>
# <div class="content_title">NASA's Perseverance Mars Rover Gets Its Wheels and Air Brakes</div>
# <div class="article_teaser_body">After the rover was shipped from JPL to Kennedy Space Center, the team is getting closer to finalizing the spacecraft for launch later this summer.</div>
# </div>
# </div>
# </div>
# </div>
# <div class="col-md-12">
# <hr/>
# <div class="row">
# <div class="col-md-4">
# <div class="list_image">
# <img src="https://mars.nasa.gov/system/news_items/list_view_images/8517_PIA23180-226.gif"/>
# </div>
# </div>
# <div class="col-md-8">
# <div class="list_text">
# <div class="list_date">February 9, 2023</div>
# <div class="content_title">NASA's InSight 'Hears' Peculiar Sounds on Mars</div>
# <div class="article_teaser_body">Listen to the marsquakes and other, less-expected sounds that the Mars lander has been detecting.</div>
# </div>
# </div>
# </div>
# </div>
# <div class="col-md-12">
# <hr/>
# <div class="row">
# <div class="col-md-4">
# <div class="list_image">
# <img src="https://mars.nasa.gov/system/news_items/list_view_images/8645_PIA23824-RoverWithHelicopter-32x24.jpg"/>
# </div>
# </div>
# <div class="col-md-8">
# <div class="list_text">
# <div class="list_date">February 5, 2023</div>
# <div class="content_title">Mars Helicopter Attached to NASA's Perseverance Rover</div>
# <div class="article_teaser_body">The team also fueled the rover's sky crane to get ready for this summer's history-making launch.</div>
# </div>
# </div>
# </div>
# </div>
# </div>, <div class="col-md-12">
# <hr/>
# <div class="row">
# <div class="col-md-4">
# <div class="list_image">
# <img src="https://mars.nasa.gov/system/news_items/list_view_images/8659_1-PIA23883-MAIN-320x240.jpg"/>
# </div>
# </div>
# <div class="col-md-8">
# <div class="list_text">
# <div class="list_date">March 5, 2023</div>
# <div class="content_title">Alabama High School Student Names NASA's Mars Helicopter</div>
# <div class="article_teaser_body">Vaneeza Rupani's essay was chosen as the name for the small spacecraft, which will mark NASA's first attempt at powered flight on another planet.</div>
# </div>
# </div>
# </div>
# </div>, <div class="row">
# <div class="col-md-4">
# <div class="list_image">
# <img src="https://mars.nasa.gov/system/news_items/list_view_images/8659_1-PIA23883-MAIN-320x240.jpg"/>
# </div>
# </div>
# <div class="col-md-8">
# <div class="list_text">
# <div class="list_date">March 5, 2023</div>
# <div class="content_title">Alabama High School Student Names NASA's Mars Helicopter</div>
# <div class="article_teaser_body">Vaneeza Rupani's essay was chosen as the name for the small spacecraft, which will mark NASA's first attempt at powered flight on another planet.</div>
# </div>
# </div>
# </div>, <div class="col-md-4">
# <div class="list_image">
# ...
# </div>
# </div>
# </div>
# </div>, <div class="col-md-4 mb-3">
# <div class="card">
# <img alt="100%x280" class="img-fluid" src="https://mars.nasa.gov/system/news_items/main_images/8716_PIA23499-16.jpg"/>
# <div class="card-body">
# <p class="card-text">NASA to Broadcast Mars 2020 Perseverance Launch, Prelaunch Activities</p>
# </div>
# </div>
# </div>, <div class="card">
# <img alt="100%x280" class="img-fluid" src="https://mars.nasa.gov/system/news_items/main_images/8716_PIA23499-16.jpg"/>
# <div class="card-body">
# <p class="card-text">NASA to Broadcast Mars 2020 Perseverance Launch, Prelaunch Activities</p>
# </div>
# </div>, <div class="card-body">
# <p class="card-text">NASA to Broadcast Mars 2020 Perseverance Launch, Prelaunch Activities</p>
# </div>, <div class="col-md-4 mb-3">
# <div class="card">
# <img alt="100%x280" class="img-fluid" src="https://mars.nasa.gov/system/news_items/main_images/8716_PIA23499-16.jpg"/>
# <div class="card-body">
# <p class="card-text">The Launch Is Approaching for NASA's Next Mars Rover, Perseverance</p>
# </div>
# </div>
# </div>, <div class="card">
# <img alt="100%x280" class="img-fluid" src="https://mars.nasa.gov/system/news_items/main_images/8716_PIA23499-16.jpg"/>
# <div class="card-body">
# <p class="card-text">The Launch Is Approaching for NASA's Next Mars Rover, Perseverance</p>
# </div>
# </div>, <div class="card-body">
# <p class="card-text">The Launch Is Approaching for NASA's Next Mars Rover, Perseverance</p>
# </div>, <div class="col-md-4 mb-3">
# <div class="card">
# <img alt="100%x280" class="img-fluid" src="https://mars.nasa.gov/system/news_items/main_images/8692_PIA23920-web.jpg"/>
# <div class="card-body">
# <p class="card-text">NASA to Hold Mars 2020 Perseverance Rover Launch Briefing</p>
# </div>
# </div>
# </div>, <div class="card">
# <img alt="100%x280" class="img-fluid" src="https://mars.nasa.gov/system/news_items/main_images/8692_PIA23920-web.jpg"/>
# <div class="card-body">
# <p class="card-text">NASA to Hold Mars 2020 Perseverance Rover Launch Briefing</p>
# </div>
# </div>, <div class="card-body">
# <p class="card-text">NASA to Hold Mars 2020 Perseverance Rover Launch Briefing</p>
# </div>, <div class="carousel-item">
# <div class="row">
# <div class="col-md-4 mb-3">
# <div class="card">
# <img alt="100%x280" class="img-fluid" src="https://images.unsplash.com/photo-1532771098148-525cefe10c23?ixlib=rb-0.3.5&amp;q=80&amp;fm=jpg&amp;crop=entropy&amp;cs=tinysrgb&amp;w=1080&amp;fit=max&amp;ixid=eyJhcHBfaWQiOjMyMDc0fQ&amp;s=3f317c1f7a16116dec454fbc267dd8e4"/>
# <div class="card-body">
# <p class="card-text">With supporting text below as a natural lead-in to additional content.</p>
# </div>
# </div>
# </div>
# <div class="col-md-4 mb-3">
# <div class="card">
# <img alt="100%x280" class="img-fluid" src="https://images.unsplash.com/photo-1532715088550-62f09305f765?ixlib=rb-0.3.5&amp;q=80&amp;fm=jpg&amp;crop=entropy&amp;cs=tinysrgb&amp;w=1080&amp;fit=max&amp;ixid=eyJhcHBfaWQiOjMyMDc0fQ&amp;s=ebadb044b374504ef8e81bdec4d0e840"/>
# <div class="card-body">
# <p class="card-text">With supporting text below as a natural lead-in to additional content.</p>
# </div>
# </div>
# </div>
# <div class="col-md-4 mb-3">
# <div class="card">
# <img alt="100%x280" class="img-fluid" src="https://images.unsplash.com/photo-1506197603052-3cc9c3a201bd?ixlib=rb-0.3.5&amp;q=80&amp;fm=jpg&amp;crop=entropy&amp;cs=tinysrgb&amp;w=1080&amp;fit=max&amp;ixid=eyJhcHBfaWQiOjMyMDc0fQ&amp;s=0754ab085804ae8a3b562548e6b4aa2e"/>
# <div class="card-body">
# <p class="card-text">With supporting text below as a natural lead-in to additional content.</p>
# </div>
# </div>
# </div>
# </div>
# </div>, <div class="row">
# <div class="col-md-4 mb-3">
# <div class="card">
# <img alt="100%x280" class="img-fluid" src="https://images.unsplash.com/photo-1532771098148-525cefe10c23?ixlib=rb-0.3.5&amp;q=80&amp;fm=jpg&amp;crop=entropy&amp;cs=tinysrgb&amp;w=1080&amp;fit=max&amp;ixid=eyJhcHBfaWQiOjMyMDc0fQ&amp;s=3f317c1f7a16116dec454fbc267dd8e4"/>
# <div class="card-body">
# <p class="card-text">With supporting text below as a natural lead-in to additional content.</p>
# </div>
# </div>
# </div>
# <div class="col-md-4 mb-3">
# <div class="card">
# <img alt="100%x280" class="img-fluid" src="https://images.unsplash.com/photo-1532715088550-62f09305f765?ixlib=rb-0.3.5&amp;q=80&amp;fm=jpg&amp;crop=entropy&amp;cs=tinysrgb&amp;w=1080&amp;fit=max&amp;ixid=eyJhcHBfaWQiOjMyMDc0fQ&amp;s=ebadb044b374504ef8e81bdec4d0e840"/>
# <div class="card-body">
# <p class="card-text">With supporting text below as a natural lead-in to additional content.</p>
# </div>
# </div>
# </div>
# <div class="col-md-4 mb-3">
# <div class="card">
# <img alt="100%x280" class="img-fluid" src="https://images.unsplash.com/photo-1506197603052-3cc9c3a201bd?ixlib=rb-0.3.5&amp;q=80&amp;fm=jpg&amp;crop=entropy&amp;cs=tinysrgb&amp;w=1080&amp;fit=max&amp;ixid=eyJhcHBfaWQiOjMyMDc0fQ&amp;s=0754ab085804ae8a3b562548e6b4aa2e"/>
# <div class="card-body">
# <p class="card-text">With supporting text below as a natural lead-in to additional content.</p>
# </div>
# </div>
# </div>
# </div>, <div class="col-md-4 mb-3">
# <div class="card">
# <img alt="100%x280" class="img-fluid" src="https://images.unsplash.com/photo-1532771098148-525cefe10c23?ixlib=rb-0.3.5&amp;q=80&amp;fm=jpg&amp;crop=entropy&amp;cs=tinysrgb&amp;w=1080&amp;fit=max&amp;ixid=eyJhcHBfaWQiOjMyMDc0fQ&amp;s=3f317c1f7a16116dec454fbc267dd8e4"/>
# <div class="card-body">
# <p class="card-text">With supporting text below as a natural lead-in to additional content.</p>
# </div>
# </div>
# </div>, <div class="card">
# <img alt="100%x280" class="img-fluid" src="https://images.unsplash.com/photo-1532771098148-525cefe10c23?ixlib=rb-0.3.5&amp;q=80&amp;fm=jpg&amp;crop=entropy&amp;cs=tinysrgb&amp;w=1080&amp;fit=max&amp;ixid=eyJhcHBfaWQiOjMyMDc0fQ&amp;s=3f317c1f7a16116dec454fbc267dd8e4"/>
# <div class="card-body">
# <p class="card-text">With supporting text below as a natural lead-in to additional content.</p>
# </div>
# </div>, <div class="card-body">
# <p class="card-text">With supporting text below as a natural lead-in to additional content.</p>
# </div>, <div class="col-md-4 mb-3">
# <div class="card">
# <img alt="100%x280" class="img-fluid" src="https://images.unsplash.com/photo-1532715088550-62f09305f765?ixlib=rb-0.3.5&amp;q=80&amp;fm=jpg&amp;crop=entropy&amp;cs=tinysrgb&amp;w=1080&amp;fit=max&amp;ixid=eyJhcHBfaWQiOjMyMDc0fQ&amp;s=ebadb044b374504ef8e81bdec4d0e840"/>
# <div class="card-body">
# <p class="card-text">With supporting text below as a natural lead-in to additional content.</p>
# </div>
# </div>
# </div>, <div class="card">
# <img alt="100%x280" class="img-fluid" src="https://images.unsplash.com/photo-1532715088550-62f09305f765?ixlib=rb-0.3.5&amp;q=80&amp;fm=jpg&amp;crop=entropy&amp;cs=tinysrgb&amp;w=1080&amp;fit=max&amp;ixid=eyJhcHBfaWQiOjMyMDc0fQ&amp;s=ebadb044b374504ef8e81bdec4d0e840"/>
# <div class="card-body">
# <p class="card-text">With supporting text below as a natural lead-in to additional content.</p>
# </div>
# </div>, <div class="card-body">
# <p class="card-text">With supporting text below as a natural lead-in to additional content.</p>
# </div>, <div class="col-md-4 mb-3">
# <div class="card">
# <img alt="100%x280" class="img-fluid" src="https://images.unsplash.com/photo-1506197603052-3cc9c3a201bd?ixlib=rb-0.3.5&amp;q=80&amp;fm=jpg&amp;crop=entropy&amp;cs=tinysrgb&amp;w=1080&amp;fit=max&amp;ixid=eyJhcHBfaWQiOjMyMDc0fQ&amp;s=0754ab085804ae8a3b562548e6b4aa2e"/>
# <div class="card-body">
# <p class="card-text">With supporting text below as a natural lead-in to additional content.</p>
# </div>
# </div>
# </div>, <div class="card">
# <img alt="100%x280" class="img-fluid" src="https://images.unsplash.com/photo-1506197603052-3cc9c3a201bd?ixlib=rb-0.3.5&amp;q=80&amp;fm=jpg&amp;crop=entropy&amp;cs=tinysrgb&amp;w=1080&amp;fit=max&amp;ixid=eyJhcHBfaWQiOjMyMDc0fQ&amp;s=0754ab085804ae8a3b562548e6b4aa2e"/>
# <div class="card-body">
# <p class="card-text">With supporting text below as a natural lead-in to additional content.</p>
# </div>
# </div>, <div class="card-body">
# <p class="card-text">With supporting text below as a natural lead-in to additional content.</p>
# </div>, <div class="carousel-item">
# <div class="row">
# <div class="col-md-4 mb-3">
# <div class="card">
# <img alt="100%x280" class="img-fluid" src="https://images.unsplash.com/photo-1507525428034-b723cf961d3e?ixlib=rb-0.3.5&amp;q=80&amp;fm=jpg&amp;crop=entropy&amp;cs=tinysrgb&amp;w=1080&amp;fit=max&amp;ixid=eyJhcHBfaWQiOjMyMDc0fQ&amp;s=ee8417f0ea2a50d53a12665820b54e23"/>
# <div class="card-body">
# <p class="card-text">With supporting text below as a natural lead-in to additional content.</p>
# </div>
# </div>
# </div>
# <div class="col-md-4 mb-3">
# <div class="card">
# <img alt="100%x280" class="img-fluid" src="https://images.unsplash.com/photo-1532777946373-b6783242f211?ixlib=rb-0.3.5&amp;q=80&amp;fm=jpg&amp;crop=entropy&amp;cs=tinysrgb&amp;w=1080&amp;fit=max&amp;ixid=eyJhcHBfaWQiOjMyMDc0fQ&amp;s=8ac55cf3a68785643998730839663129"/>
# <div class="card-body">
# <p class="card-text">With supporting text below as a natural lead-in to additional content.</p>
# </div>
# </div>
# </div>
# <div class="col-md-4 mb-3">
# <div class="card">
# <img alt="100%x280" class="img-fluid" src="https://images.unsplash.com/photo-1532763303805-529d595877c5?ixlib=rb-0.3.5&amp;q=80&amp;fm=jpg&amp;crop=entropy&amp;cs=tinysrgb&amp;w=1080&amp;fit=max&amp;ixid=eyJhcHBfaWQiOjMyMDc0fQ&amp;s=5ee4fd5d19b40f93eadb21871757eda6"/>
# <div class="card-body">
# <p class="card-text">With supporting text below as a natural lead-in to additional content.</p>
# </div>
# </div>
# </div>
# </div>
# </div>, <div class="row">
# <div class="col-md-4 mb-3">
# <div class="card">
# <img alt="100%x280" class="img-fluid" src="https://images.unsplash.com/photo-1507525428034-b723cf961d3e?ixlib=rb-0.3.5&amp;q=80&amp;fm=jpg&amp;crop=entropy&amp;cs=tinysrgb&amp;w=1080&amp;fit=max&amp;ixid=eyJhcHBfaWQiOjMyMDc0fQ&amp;s=ee8417f0ea2a50d53a12665820b54e23"/>
# <div class="card-body">
# <p class="card-text">With supporting text below as a natural lead-in to additional content.</p>
# </div>
# </div>
# </div>
# <div class="col-md-4 mb-3">
# <div class="card">
# <img alt="100%x280" class="img-fluid" src="https://images.unsplash.com/photo-1532777946373-b6783242f211?ixlib=rb-0.3.5&amp;q=80&amp;fm=jpg&amp;crop=entropy&amp;cs=tinysrgb&amp;w=1080&amp;fit=max&amp;ixid=eyJhcHBfaWQiOjMyMDc0fQ&amp;s=8ac55cf3a68785643998730839663129"/>
# <div class="card-body">
# <p class="card-text">With supporting text below as a natural lead-in to additional content.</p>
# </div>
# </div>
# </div>
# <div class="col-md-4 mb-3">
# <div class="card">
# <img alt="100%x280" class="img-fluid" src="https://images.unsplash.com/photo-1532763303805-529d595877c5?ixlib=rb-0.3.5&amp;q=80&amp;fm=jpg&amp;crop=entropy&amp;cs=tinysrgb&amp;w=1080&amp;fit=max&amp;ixid=eyJhcHBfaWQiOjMyMDc0fQ&amp;s=5ee4fd5d19b40f93eadb21871757eda6"/>
# <div class="card-body">
# <p class="card-text">With supporting text below as a natural lead-in to additional content.</p>
# </div>
# </div>
# </div>
# </div>, <div class="col-md-4 mb-3">
# <div class="card">
# <img alt="100%x280" class="img-fluid" src="https://images.unsplash.com/photo-1507525428034-b723cf961d3e?ixlib=rb-0.3.5&amp;q=80&amp;fm=jpg&amp;crop=entropy&amp;cs=tinysrgb&amp;w=1080&amp;fit=max&amp;ixid=eyJhcHBfaWQiOjMyMDc0fQ&amp;s=ee8417f0ea2a50d53a12665820b54e23"/>
# <div class="card-body">
# <p class="card-text">With supporting text below as a natural lead-in to additional content.</p>
# </div>
# </div>
# </div>, <div class="card">
# <img alt="100%x280" class="img-fluid" src="https://images.unsplash.com/photo-1507525428034-b723cf961d3e?ixlib=rb-0.3.5&amp;q=80&amp;fm=jpg&amp;crop=entropy&amp;cs=tinysrgb&amp;w=1080&amp;fit=max&amp;ixid=eyJhcHBfaWQiOjMyMDc0fQ&amp;s=ee8417f0ea2a50d53a12665820b54e23"/>
# <div class="card-body">
# <p class="card-text">With supporting text below as a natural lead-in to additional content.</p>
# </div>
# </div>, <div class="card-body">
# <p class="card-text">With supporting text below as a natural lead-in to additional content.</p>
# </div>, <div class="col-md-4 mb-3">
# <div class="card">
# <img alt="100%x280" class="img-fluid" src="https://images.unsplash.com/photo-1532777946373-b6783242f211?ixlib=rb-0.3.5&amp;q=80&amp;fm=jpg&amp;crop=entropy&amp;cs=tinysrgb&amp;w=1080&amp;fit=max&amp;ixid=eyJhcHBfaWQiOjMyMDc0fQ&amp;s=8ac55cf3a68785643998730839663129"/>
# <div class="card-body">
# <p class="card-text">With supporting text below as a natural lead-in to additional content.</p>
# </div>
# </div>
# </div>, <div class="card">
# <img alt="100%x280" class="img-fluid" src="https://images.unsplash.com/photo-1532777946373-b6783242f211?ixlib=rb-0.3.5&amp;q=80&amp;fm=jpg&amp;crop=entropy&amp;cs=tinysrgb&amp;w=1080&amp;fit=max&amp;ixid=eyJhcHBfaWQiOjMyMDc0fQ&amp;s=8ac55cf3a68785643998730839663129"/>
# <div class="card-body">
# <p class="card-text">With supporting text below as a natural lead-in to additional content.</p>
# </div>
# </div>, <div class="card-body">
# <p class="card-text">With supporting text below as a natural lead-in to additional content.</p>
# </div>, <div class="col-md-4 mb-3">
# <div class="card">
# <img alt="100%x280" class="img-fluid" src="https://images.unsplash.com/photo-1532763303805-529d595877c5?ixlib=rb-0.3.5&amp;q=80&amp;fm=jpg&amp;crop=entropy&amp;cs=tinysrgb&amp;w=1080&amp;fit=max&amp;ixid=eyJhcHBfaWQiOjMyMDc0fQ&amp;s=5ee4fd5d19b40f93eadb21871757eda6"/>
# <div class="card-body">
# <p class="card-text">With supporting text below as a natural lead-in to additional content.</p>
# </div>
# </div>
# </div>, <div class="card">
# <img alt="100%x280" class="img-fluid" src="https://images.unsplash.com/photo-1532763303805-529d595877c5?ixlib=rb-0.3.5&amp;q=80&amp;fm=jpg&amp;crop=entropy&amp;cs=tinysrgb&amp;w=1080&amp;fit=max&amp;ixid=eyJhcHBfaWQiOjMyMDc0fQ&amp;s=5ee4fd5d19b40f93eadb21871757eda6"/>
# <div class="card-body">
# <p class="card-text">With supporting text below as a natural lead-in to additional content.</p>
# </div>
# </div>, <div class="card-body">
# <p class="card-text">With supporting text below as a natural lead-in to additional content.</p>
# </div>, <div class="container">
# <div class="col-md-12">
# <div class="row">
# <div class="col-md-3">
# <h5>The Red Planet</h5>
# <ul>
# <li>Dashboard</li>
# <li>Science Goals</li>
# <li>The Planet</li>
# </ul>
# </div>
# <div class="col-md-3">
# <h5>The Program</h5>
# <ul>
# <li>Mission Statement</li>
# <li>About the Program</li>
# <li>Organization Why Mars?</li>
# </ul>
# </div>
# <div class="col-md-3">
# <h5>Multimedia</h5>
# <ul>
# <li>Images</li>
# <li>Videos</li>
# <li>More Resources</li>
# </ul>
# </div>
# <div class="col-md-3">
# <h5>Missions</h5>
# <ul>
# <li>Past</li>
# <li>Present</li>
# <li>Future</li>
# </ul>
# </div>
# </div>
# </div>
# </div>, <div class="col-md-12">
# <div class="row">
# <div class="col-md-3">
# <h5>The Red Planet</h5>
# <ul>
# <li>Dashboard</li>
# <li>Science Goals</li>
# <li>The Planet</li>
# </ul>
# </div>
# <div class="col-md-3">
# <h5>The Program</h5>
# <ul>
# <li>Mission Statement</li>
# <li>About the Program</li>
# <li>Organization Why Mars?</li>
# </ul>
# </div>
# <div class="col-md-3">
# <h5>Multimedia</h5>
# <ul>
# <li>Images</li>
# <li>Videos</li>
# <li>More Resources</li>
# </ul>
# </div>
# <div class="col-md-3">
# <h5>Missions</h5>
# <ul>
# <li>Past</li>
# <li>Present</li>
# <li>Future</li>
# </ul>
# </div>
# </div>
# </div>, <div class="row">
# <div class="col-md-3">
# <h5>The Red Planet</h5>
# <ul>
# <li>Dashboard</li>
# <li>Science Goals</li>
# <li>The Planet</li>
# </ul>
# </div>
# <div class="col-md-3">
# <h5>The Program</h5>
# <ul>
# <li>Mission Statement</li>
# <li>About the Program</li>
# <li>Organization Why Mars?</li>
# </ul>
# </div>
# <div class="col-md-3">
# <h5>Multimedia</h5>
# <ul>
# <li>Images</li>
# <li>Videos</li>
# <li>More Resources</li>
# </ul>
# </div>
# <div class="col-md-3">
# <h5>Missions</h5>
# <ul>
# <li>Past</li>
# <li>Present</li>
# <li>Future</li>
# </ul>
# </div>
# </div>, <div class="col-md-3">
# <h5>The Red Planet</h5>
# <ul>
# <li>Dashboard</li>
# <li>Science Goals</li>
# <li>The Planet</li>
# </ul>
# </div>, <div class="col-md-3">
# <h5>The Program</h5>
# <ul>
# <li>Mission Statement</li>
# <li>About the Program</li>
# <li>Organization Why Mars?</li>
# </ul>
# </div>, <div class="col-md-3">
# <h5>Multimedia</h5>
# <ul>
# <li>Images</li>
# <li>Videos</li>
# <li>More Resources</li>
# </ul>
# </div>, <div class="col-md-3">
# <h5>Missions</h5>
# <ul>
# <li>Past</li>
# <li>Present</li>
# <li>Future</li>
# </ul>
# </div>]

# %%
slide_elem = html_soup.find_all('div')
slide_elem
# Out:
# [<div class="col-md-12">
#  <div class="row">
#  <nav class="navbar navbar-expand-lg navbar-light fixed-top">
#  <div class="container-fluid">
#  <a class="navbar-brand" href="#">
#  <img src="image/nasa.png" width="80"/><span class="logo">MARS Planet Science</span>
#  <span class="logo1">Exploration Program</span>
#  </a>
#  <button aria-controls="navbarNav" aria-expanded="false" aria-label="Toggle navigation" class="navbar-toggler" data-bs-target="#navbarNav" data-bs-toggle="collapse" type="button">
#  <span class="navbar-toggler-icon"></span>
#  </button>
#  <div class="collapse navbar-collapse justify-content-end" id="navbarNav">
#  <ul class="navbar-nav">
#  <li class="nav-item">
#  <a aria-current="page" class="nav-link active" href="#">The Red Planet</a>
#  </li>
#  <li class="nav-item">
#  <a class="nav-link" href="#">The Program</a>
#  </li>
#  <li class="nav-item">
#  <a class="nav-link" href="#">News &amp; Events</a>
#  </li>
#  <li class="nav-item">
#  <a class="nav-link" href="#">Multimedia</a>
#  </li>
#  <li class="nav-item">
#  <a class="nav-link" href="#">Missions</a>
#  </li>
#  <li class="nav-item">
#  <a class="nav-link" href="#">More</a>
#  </li>
#  <li class="nav-item nav_search">
#  <a class="nav-link" href="#"></a>
#  </li>
#  </ul>
#  </div>
#  </div>
#  </nav>
#  <section class="search">
#  <div class="container">
#  <h1>News</h1>
#  <div class="col-md-12 filter">
#  <div class="row">
#  <div class="col-md-3 search_binder">
#  <input class="search_field" name="search" type="text"/>
#  <input class="search_submit" name="search" type="text"/>
#  </div>
#  <div class="col-md-3">
#  <select aria-label="Default select example" class="form-select" id="year">
#  <option selected="">Latest</option>
#  <option>2020</option><option>2019</option></select>
#  </div>
#  <div class="col-md-3">
#  <select aria-label="Default select example" class="form-select" id="cat">
#  <option selected="">All Categories</option>
#  <option>Press Releases</option><option>Feature Stories</option><option>Status Reports</option></select>
#  </div>
#  <div class="col-md-3">
#  </div>
#  </div>
#  </div>
#  </div>
#  </section>
#  <section class="image_and_description_container">
#  <div class="container" id="news">
#  <div class="col-md-12">
#  <hr/>
#  <div class="row">
#  <div class="col-md-4">
#  <div class="list_image">
#  <img src="https://mars.nasa.gov/system/news_items/list_view_images/8659_1-PIA23883-MAIN-320x240.jpg"/>
#  </div>
#  </div>
#  <div class="col-md-8">
#  <div class="list_text">
#  <div class="list_date">March 5, 2023</div>
#  <div class="content_title">Alabama High School Student Names NASA's Mars Helicopter</div>
#  <div class="article_teaser_body">Vaneeza Rupani's essay was chosen as the name for the small spacecraft, which will mark NASA's first attempt at powered flight on another planet.</div>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="col-md-12">
#  <hr/>
#  <div class="row">
#  <div class="col-md-4">
#  <div class="list_image">
#  <img src="https://mars.nasa.gov/system/news_items/list_view_images/8663_PIA23316-annotated-16-320x240.jpg"/>
#  </div>
#  </div>
#  <div class="col-md-8">
#  <div class="list_text">
#  <div class="list_date">March 4, 2023</div>
#  <div class="content_title">NASA's Perseverance Rover Will Look at Mars Through These 'Eyes'</div>
#  <div class="article_teaser_body">A pair of zoomable cameras will help scientists and rover drivers with high-resolution color images.</div>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="col-md-12">
#  <hr/>
#  <div class="row">
#  <div class="col-md-4">
#  <div class="list_image">
#  <img src="https://mars.nasa.gov/system/news_items/list_view_images/8792_parachute-320x240.jpg"/>
#  </div>
#  </div>
#  <div class="col-md-8">
#  <div class="list_text">
#  <div class="list_date">March 1, 2023</div>
#  <div class="content_title">NASA's Perseverance Rover 100 Days Out</div>
#  <div class="article_teaser_body">Mark your calendars: The agency's latest rover has only about 8,640,000 seconds to go before it touches down on the Red Planet, becoming history's next Mars car.</div>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="col-md-12">
#  <hr/>
#  <div class="row">
#  <div class="col-md-4">
#  <div class="list_image">
#  <img src="https://mars.nasa.gov/system/news_items/list_view_images/8607_PIA23591-320x240.jpg"/>
#  </div>
#  </div>
#  <div class="col-md-8">
#  <div class="list_text">
#  <div class="list_date">February 28, 2023</div>
#  <div class="content_title">NASA's Mars 2020 Rover Goes Coast-to-Coast to Prep for Launch</div>
#  <div class="article_teaser_body">The agency's first step in returning rocks from Mars just arrived at Kennedy Space Center. The Mars 2020 team now begins readying for a launch to the Red Planet this July.</div>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="col-md-12">
#  <hr/>
#  <div class="row">
#  <div class="col-md-4">
#  <div class="list_image">
#  <img src="https://mars.nasa.gov/system/news_items/list_view_images/8505_PIA23275-th.jpg"/>
#  </div>
#  </div>
#  <div class="col-md-8">
#  <div class="list_text">
#  <div class="list_date">February 26, 2023</div>
#  <div class="content_title">Scientists Explore Outback as Testbed for Mars </div>
#  <div class="article_teaser_body">Australia provides a great place for NASA's Mars 2020 and the ESA-Roscosmos ExoMars scientists to hone techniques in preparation for searching for signs ancient life on Mars.</div>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="col-md-12">
#  <hr/>
#  <div class="row">
#  <div class="col-md-4">
#  <div class="list_image">
#  <img src="https://mars.nasa.gov/system/news_items/list_view_images/8756_25254_Christina_hernandez_mainmax-320x240.png"/>
#  </div>
#  </div>
#  <div class="col-md-8">
#  <div class="list_text">
#  <div class="list_date">February 24, 2023</div>
#  <div class="content_title">My Culture, My Voice</div>
#  <div class="article_teaser_body">In honor of Hispanic Heritage Month, Christina Hernandez, an instrument engineer on the Mars 2020 mission, talks about her childhood and journey to NASA.</div>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="col-md-12">
#  <hr/>
#  <div class="row">
#  <div class="col-md-4">
#  <div class="list_image">
#  <img src="https://mars.nasa.gov/system/news_items/list_view_images/8726_PIA23898-320.jpg"/>
#  </div>
#  </div>
#  <div class="col-md-8">
#  <div class="list_text">
#  <div class="list_date">February 23, 2023</div>
#  <div class="content_title">8 Martian Postcards to Celebrate Curiosity's Landing Anniversary</div>
#  <div class="article_teaser_body">The NASA rover touched down eight years ago, on Aug. 5, 2012, and will soon be joined by a second rover, Perseverance.</div>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="col-md-12">
#  <hr/>
#  <div class="row">
#  <div class="col-md-4">
#  <div class="list_image">
#  <img src="https://mars.nasa.gov/system/news_items/list_view_images/8609_list_image.jpg"/>
#  </div>
#  </div>
#  <div class="col-md-8">
#  <div class="list_text">
#  <div class="list_date">February 23, 2023</div>
#  <div class="content_title">NASA's Mars Reconnaissance Orbiter Undergoes Memory Update</div>
#  <div class="article_teaser_body">Other orbiters will continue relaying data from Mars surface missions for a two-week period.</div>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="col-md-12">
#  <hr/>
#  <div class="row">
#  <div class="col-md-4">
#  <div class="list_image">
#  <img src="https://mars.nasa.gov/system/news_items/list_view_images/8699_helicopter-delivery-system-320.jpg"/>
#  </div>
#  </div>
#  <div class="col-md-8">
#  <div class="list_text">
#  <div class="list_date">February 20, 2023</div>
#  <div class="content_title">How NASA's Mars Helicopter Will Reach the Red Planet's Surface</div>
#  <div class="article_teaser_body">The small craft will seek to prove that powered, controlled flight is possible on another planet. But just getting it onto the surface of Mars will take a whole lot of ingenuity.</div>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="col-md-12">
#  <hr/>
#  <div class="row">
#  <div class="col-md-4">
#  <div class="list_image">
#  <img src="https://mars.nasa.gov/system/news_items/list_view_images/8619_8588_name20190625-320x240.jpg"/>
#  </div>
#  </div>
#  <div class="col-md-8">
#  <div class="list_text">
#  <div class="list_date">February 20, 2023</div>
#  <div class="content_title">NASA to Reveal Name of Its Next Mars Rover</div>
#  <div class="article_teaser_body">After a months-long contest among students to name NASA's newest Mars rover, the agency will reveal the winning name — and the winning student — this Thursday. </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="col-md-12">
#  <hr/>
#  <div class="row">
#  <div class="col-md-4">
#  <div class="list_image">
#  <img src="https://mars.nasa.gov/system/news_items/list_view_images/8611_PIA22111-320x240.jpg"/>
#  </div>
#  </div>
#  <div class="col-md-8">
#  <div class="list_text">
#  <div class="list_date">February 15, 2023</div>
#  <div class="content_title">NASA Adds Return Sample Scientists to Mars 2020 Leadership Team</div>
#  <div class="article_teaser_body">The leadership council for Mars 2020 science added two new members who represent the interests of scientists destined to handle and study the first samples from Red Planet.</div>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="col-md-12">
#  <hr/>
#  <div class="row">
#  <div class="col-md-4">
#  <div class="list_image">
#  <img src="https://mars.nasa.gov/system/news_items/list_view_images/8778_3d-320x240.jpg"/>
#  </div>
#  </div>
#  <div class="col-md-8">
#  <div class="list_text">
#  <div class="list_date">February 12, 2023</div>
#  <div class="content_title">NASA's Perseverance Rover Bringing 3D-Printed Metal Parts to Mars</div>
#  <div class="article_teaser_body">For hobbyists and makers, 3D printing expands creative possibilities; for specialized engineers, it's also key to next-generation spacecraft design.</div>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="col-md-12">
#  <hr/>
#  <div class="row">
#  <div class="col-md-4">
#  <div class="list_image">
#  <img src="https://mars.nasa.gov/system/news_items/list_view_images/8641_PIA-23821-320x240.jpg"/>
#  </div>
#  </div>
#  <div class="col-md-8">
#  <div class="list_text">
#  <div class="list_date">February 11, 2023</div>
#  <div class="content_title">NASA's Perseverance Mars Rover Gets Its Wheels and Air Brakes</div>
#  <div class="article_teaser_body">After the rover was shipped from JPL to Kennedy Space Center, the team is getting closer to finalizing the spacecraft for launch later this summer.</div>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="col-md-12">
#  <hr/>
#  <div class="row">
#  <div class="col-md-4">
#  <div class="list_image">
#  <img src="https://mars.nasa.gov/system/news_items/list_view_images/8517_PIA23180-226.gif"/>
#  </div>
#  </div>
#  <div class="col-md-8">
#  <div class="list_text">
#  <div class="list_date">February 9, 2023</div>
#  <div class="content_title">NASA's InSight 'Hears' Peculiar Sounds on Mars</div>
#  <div class="article_teaser_body">Listen to the marsquakes and other, less-expected sounds that the Mars lander has been detecting.</div>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="col-md-12">
#  <hr/>
#  <div class="row">
#  <div class="col-md-4">
#  <div class="list_image">
#  <img src="https://mars.nasa.gov/system/news_items/list_view_images/8645_PIA23824-RoverWithHelicopter-32x24.jpg"/>
#  </div>
#  </div>
#  <div class="col-md-8">
#  <div class="list_text">
#  <div class="list_date">February 5, 2023</div>
#  <div class="content_title">Mars Helicopter Attached to NASA's Perseverance Rover</div>
#  <div class="article_teaser_body">The team also fueled the rover's sky crane to get ready for this summer's history-making launch.</div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  <hr class="container" style="margin: 25px auto;width: 83%;"/>
#  <button class="btn disable" id="more" onclick="populateContent()">More</button>
#  </section>
#  <section class="last_news">
#  <div class="container">
#  <div class="row">
#  <div class="col-12">
#  <h2>You Might Also Like</h2>
#  </div>
#  <!--  <a class=" prev" href="#carouselExampleIndicators2" role="button" data-slide="prev">
#                    <i class="fas fa-angle-left"></i>
#                    </a>
#                    <a class=" next" href="#carouselExampleIndicators2" role="button" data-slide="next">
#                    <i class="fas fa-angle-right"></i>
#                    </a> -->
#  <div class="col-12">
#  <div class="carousel slide" data-ride="carousel" id="carouselExampleIndicators2">
#  <div class="carousel-inner">
#  <div class="carousel-item active">
#  <div class="row">
#  <div class="col-md-4 mb-3">
#  <div class="card">
#  <img alt="100%x280" class="img-fluid" src="https://mars.nasa.gov/system/news_items/main_images/8716_PIA23499-16.jpg"/>
#  <div class="card-body">
#  <p class="card-text">NASA to Broadcast Mars 2020 Perseverance Launch, Prelaunch Activities</p>
#  </div>
#  </div>
#  </div>
#  <div class="col-md-4 mb-3">
#  <div class="card">
#  <img alt="100%x280" class="img-fluid" src="https://mars.nasa.gov/system/news_items/main_images/8716_PIA23499-16.jpg"/>
#  <div class="card-body">
#  <p class="card-text">The Launch Is Approaching for NASA's Next Mars Rover, Perseverance</p>
#  </div>
#  </div>
#  </div>
#  <div class="col-md-4 mb-3">
#  <div class="card">
#  <img alt="100%x280" class="img-fluid" src="https://mars.nasa.gov/system/news_items/main_images/8692_PIA23920-web.jpg"/>
#  <div class="card-body">
#  <p class="card-text">NASA to Hold Mars 2020 Perseverance Rover Launch Briefing</p>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="carousel-item">
#  <div class="row">
#  <div class="col-md-4 mb-3">
#  <div class="card">
#  <img alt="100%x280" class="img-fluid" src="https://images.unsplash.com/photo-1532771098148-525cefe10c23?ixlib=rb-0.3.5&amp;q=80&amp;fm=jpg&amp;crop=entropy&amp;cs=tinysrgb&amp;w=1080&amp;fit=max&amp;ixid=eyJhcHBfaWQiOjMyMDc0fQ&amp;s=3f317c1f7a16116dec454fbc267dd8e4"/>
#  <div class="card-body">
#  <p class="card-text">With supporting text below as a natural lead-in to additional content.</p>
#  </div>
#  </div>
#  </div>
#  <div class="col-md-4 mb-3">
#  <div class="card">
#  <img alt="100%x280" class="img-fluid" src="https://images.unsplash.com/photo-1532715088550-62f09305f765?ixlib=rb-0.3.5&amp;q=80&amp;fm=jpg&amp;crop=entropy&amp;cs=tinysrgb&amp;w=1080&amp;fit=max&amp;ixid=eyJhcHBfaWQiOjMyMDc0fQ&amp;s=ebadb044b374504ef8e81bdec4d0e840"/>
#  <div class="card-body">
#  <p class="card-text">With supporting text below as a natural lead-in to additional content.</p>
#  </div>
#  </div>
#  </div>
#  <div class="col-md-4 mb-3">
#  <div class="card">
#  <img alt="100%x280" class="img-fluid" src="https://images.unsplash.com/photo-1506197603052-3cc9c3a201bd?ixlib=rb-0.3.5&amp;q=80&amp;fm=jpg&amp;crop=entropy&amp;cs=tinysrgb&amp;w=1080&amp;fit=max&amp;ixid=eyJhcHBfaWQiOjMyMDc0fQ&amp;s=0754ab085804ae8a3b562548e6b4aa2e"/>
#  <div class="card-body">
#  <p class="card-text">With supporting text below as a natural lead-in to additional content.</p>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="carousel-item">
#  <div class="row">
#  <div class="col-md-4 mb-3">
#  <div class="card">
#  <img alt="100%x280" class="img-fluid" src="https://images.unsplash.com/photo-1507525428034-b723cf961d3e?ixlib=rb-0.3.5&amp;q=80&amp;fm=jpg&amp;crop=entropy&amp;cs=tinysrgb&amp;w=1080&amp;fit=max&amp;ixid=eyJhcHBfaWQiOjMyMDc0fQ&amp;s=ee8417f0ea2a50d53a12665820b54e23"/>
#  <div class="card-body">
#  <p class="card-text">With supporting text below as a natural lead-in to additional content.</p>
#  </div>
#  </div>
#  </div>
#  <div class="col-md-4 mb-3">
#  <div class="card">
#  <img alt="100%x280" class="img-fluid" src="https://images.unsplash.com/photo-1532777946373-b6783242f211?ixlib=rb-0.3.5&amp;q=80&amp;fm=jpg&amp;crop=entropy&amp;cs=tinysrgb&amp;w=1080&amp;fit=max&amp;ixid=eyJhcHBfaWQiOjMyMDc0fQ&amp;s=8ac55cf3a68785643998730839663129"/>
#  <div class="card-body">
#  <p class="card-text">With supporting text below as a natural lead-in to additional content.</p>
#  </div>
#  </div>
#  </div>
#  <div class="col-md-4 mb-3">
#  <div class="card">
#  <img alt="100%x280" class="img-fluid" src="https://images.unsplash.com/photo-1532763303805-529d595877c5?ixlib=rb-0.3.5&amp;q=80&amp;fm=jpg&amp;crop=entropy&amp;cs=tinysrgb&amp;w=1080&amp;fit=max&amp;ixid=eyJhcHBfaWQiOjMyMDc0fQ&amp;s=5ee4fd5d19b40f93eadb21871757eda6"/>
#  <div class="card-body">
#  <p class="card-text">With supporting text below as a natural lead-in to additional content.</p>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </section>
#  <section class="footer">
#  <div class="container">
#  <div class="col-md-12">
#  <div class="row">
#  <div class="col-md-3">
#  <h5>The Red Planet</h5>
#  <ul>
#  <li>Dashboard</li>
#  <li>Science Goals</li>
#  <li>The Planet</li>
#  </ul>
#  </div>
#  <div class="col-md-3">
#  <h5>The Program</h5>
#  <ul>
#  <li>Mission Statement</li>
#  <li>About the Program</li>
#  <li>Organization Why Mars?</li>
#  </ul>
#  </div>
#  <div class="col-md-3">
#  <h5>Multimedia</h5>
#  <ul>
#  <li>Images</li>
#  <li>Videos</li>
#  <li>More Resources</li>
#  </ul>
#  </div>
#  <div class="col-md-3">
#  <h5>Missions</h5>
#  <ul>
#  <li>Past</li>
#  <li>Present</li>
#  <li>Future</li>
#  </ul>
#  </div>
#  </div>
#  </div>
#  </div>
#  </section>
#  <script src="https://code.jquery.com/jquery-1.12.4.min.js" type="text/javascript"></script>
#  <script src="https://cdn.jsdelivr.net/npm/@popperjs/core@2.5.4/dist/umd/popper.min.js"></script>
#  <script src="https://cdn.jsdelivr.net/npm/bootstrap@5.0.0-beta1/dist/js/bootstrap.min.js"></script>
#  <script src="js/app.js"></script>
#  </div></div>,
#  <div class="row">
#  <nav class="navbar navbar-expand-lg navbar-light fixed-top">
#  <div class="container-fluid">
#  <a class="navbar-brand" href="#">
#  <img src="image/nasa.png" width="80"/><span class="logo">MARS Planet Science</span>
#  <span class="logo1">Exploration Program</span>
#  </a>
#  <button aria-controls="navbarNav" aria-expanded="false" aria-label="Toggle navigation" class="navbar-toggler" data-bs-target="#navbarNav" data-bs-toggle="collapse" type="button">
#  <span class="navbar-toggler-icon"></span>
#  </button>
#  <div class="collapse navbar-collapse justify-content-end" id="navbarNav">
#  <ul class="navbar-nav">
#  <li class="nav-item">
#  <a aria-current="page" class="nav-link active" href="#">The Red Planet</a>
#  </li>
#  <li class="nav-item">
#  <a class="nav-link" href="#">The Program</a>
#  </li>
#  <li class="nav-item">
#  <a class="nav-link" href="#">News &amp; Events</a>
#  </li>
#  <li class="nav-item">
#  <a class="nav-link" href="#">Multimedia</a>
#  </li>
#  <li class="nav-item">
#  <a class="nav-link" href="#">Missions</a>
#  </li>
#  <li class="nav-item">
#  <a class="nav-link" href="#">More</a>
#  </li>
#  <li class="nav-item nav_search">
#  <a class="nav-link" href="#"></a>
#  </li>
#  </ul>
#  </div>
#  </div>
#  </nav>
#  <section class="search">
#  <div class="container">
#  <h1>News</h1>
#  <div class="col-md-12 filter">
#  <div class="row">
#  <div class="col-md-3 search_binder">
#  <input class="search_field" name="search" type="text"/>
#  <input class="search_submit" name="search" type="text"/>
#  </div>
#  <div class="col-md-3">
#  <select aria-label="Default select example" class="form-select" id="year">
#  <option selected="">Latest</option>
#  <option>2020</option><option>2019</option></select>
#  </div>
#  <div class="col-md-3">
#  <select aria-label="Default select example" class="form-select" id="cat">
#  <option selected="">All Categories</option>
#  <option>Press Releases</option><option>Feature Stories</option><option>Status Reports</option></select>
#  </div>
#  <div class="col-md-3">
#  </div>
#  </div>
#  </div>
#  </div>
#  </section>
#  <section class="image_and_description_container">
#  <div class="container" id="news">
#  <div class="col-md-12">
#  <hr/>
#  <div class="row">
#  <div class="col-md-4">
#  <div class="list_image">
#  <img src="https://mars.nasa.gov/system/news_items/list_view_images/8659_1-PIA23883-MAIN-320x240.jpg"/>
#  </div>
#  </div>
#  <div class="col-md-8">
#  <div class="list_text">
#  <div class="list_date">March 5, 2023</div>
#  <div class="content_title">Alabama High School Student Names NASA's Mars Helicopter</div>
#  <div class="article_teaser_body">Vaneeza Rupani's essay was chosen as the name for the small spacecraft, which will mark NASA's first attempt at powered flight on another planet.</div>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="col-md-12">
#  <hr/>
#  <div class="row">
#  <div class="col-md-4">
#  <div class="list_image">
#  <img src="https://mars.nasa.gov/system/news_items/list_view_images/8663_PIA23316-annotated-16-320x240.jpg"/>
#  </div>
#  </div>
#  <div class="col-md-8">
#  <div class="list_text">
#  <div class="list_date">March 4, 2023</div>
#  <div class="content_title">NASA's Perseverance Rover Will Look at Mars Through These 'Eyes'</div>
#  <div class="article_teaser_body">A pair of zoomable cameras will help scientists and rover drivers with high-resolution color images.</div>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="col-md-12">
#  <hr/>
#  <div class="row">
#  <div class="col-md-4">
#  <div class="list_image">
#  <img src="https://mars.nasa.gov/system/news_items/list_view_images/8792_parachute-320x240.jpg"/>
#  </div>
#  </div>
#  <div class="col-md-8">
#  <div class="list_text">
#  <div class="list_date">March 1, 2023</div>
#  <div class="content_title">NASA's Perseverance Rover 100 Days Out</div>
#  <div class="article_teaser_body">Mark your calendars: The agency's latest rover has only about 8,640,000 seconds to go before it touches down on the Red Planet, becoming history's next Mars car.</div>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="col-md-12">
#  <hr/>
#  <div class="row">
#  <div class="col-md-4">
#  <div class="list_image">
#  <img src="https://mars.nasa.gov/system/news_items/list_view_images/8607_PIA23591-320x240.jpg"/>
#  </div>
#  </div>
#  <div class="col-md-8">
#  <div class="list_text">
#  <div class="list_date">February 28, 2023</div>
#  <div class="content_title">NASA's Mars 2020 Rover Goes Coast-to-Coast to Prep for Launch</div>
#  <div class="article_teaser_body">The agency's first step in returning rocks from Mars just arrived at Kennedy Space Center. The Mars 2020 team now begins readying for a launch to the Red Planet this July.</div>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="col-md-12">
#  <hr/>
#  <div class="row">
#  <div class="col-md-4">
#  <div class="list_image">
#  <img src="https://mars.nasa.gov/system/news_items/list_view_images/8505_PIA23275-th.jpg"/>
#  </div>
#  </div>
#  <div class="col-md-8">
#  <div class="list_text">
#  <div class="list_date">February 26, 2023</div>
#  <div class="content_title">Scientists Explore Outback as Testbed for Mars </div>
#  <div class="article_teaser_body">Australia provides a great place for NASA's Mars 2020 and the ESA-Roscosmos ExoMars scientists to hone techniques in preparation for searching for signs ancient life on Mars.</div>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="col-md-12">
#  <hr/>
#  <div class="row">
#  <div class="col-md-4">
#  <div class="list_image">
#  <img src="https://mars.nasa.gov/system/news_items/list_view_images/8756_25254_Christina_hernandez_mainmax-320x240.png"/>
#  </div>
#  </div>
#  <div class="col-md-8">
#  <div class="list_text">
#  <div class="list_date">February 24, 2023</div>
#  <div class="content_title">My Culture, My Voice</div>
#  <div class="article_teaser_body">In honor of Hispanic Heritage Month, Christina Hernandez, an instrument engineer on the Mars 2020 mission, talks about her childhood and journey to NASA.</div>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="col-md-12">
#  <hr/>
#  <div class="row">
#  <div class="col-md-4">
#  <div class="list_image">
#  <img src="https://mars.nasa.gov/system/news_items/list_view_images/8726_PIA23898-320.jpg"/>
#  </div>
#  </div>
#  <div class="col-md-8">
#  <div class="list_text">
#  <div class="list_date">February 23, 2023</div>
#  <div class="content_title">8 Martian Postcards to Celebrate Curiosity's Landing Anniversary</div>
#  <div class="article_teaser_body">The NASA rover touched down eight years ago, on Aug. 5, 2012, and will soon be joined by a second rover, Perseverance.</div>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="col-md-12">
#  <hr/>
#  <div class="row">
#  <div class="col-md-4">
#  <div class="list_image">
#  <img src="https://mars.nasa.gov/system/news_items/list_view_images/8609_list_image.jpg"/>
#  </div>
#  </div>
#  <div class="col-md-8">
#  <div class="list_text">
#  <div class="list_date">February 23, 2023</div>
#  <div class="content_title">NASA's Mars Reconnaissance Orbiter Undergoes Memory Update</div>
#  <div class="article_teaser_body">Other orbiters will continue relaying data from Mars surface missions for a two-week period.</div>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="col-md-12">
#  <hr/>
#  <div class="row">
#  <div class="col-md-4">
#  <div class="list_image">
#  <img src="https://mars.nasa.gov/system/news_items/list_view_images/8699_helicopter-delivery-system-320.jpg"/>
#  </div>
#  </div>
#  <div class="col-md-8">
#  <div class="list_text">
#  <div class="list_date">February 20, 2023</div>
#  <div class="content_title">How NASA's Mars Helicopter Will Reach the Red Planet's Surface</div>
#  <div class="article_teaser_body">The small craft will seek to prove that powered, controlled flight is possible on another planet. But just getting it onto the surface of Mars will take a whole lot of ingenuity.</div>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="col-md-12">
#  <hr/>
#  <div class="row">
#  <div class="col-md-4">
#  <div class="list_image">
#  <img src="https://mars.nasa.gov/system/news_items/list_view_images/8619_8588_name20190625-320x240.jpg"/>
#  </div>
#  </div>
#  <div class="col-md-8">
#  <div class="list_text">
#  <div class="list_date">February 20, 2023</div>
#  <div class="content_title">NASA to Reveal Name of Its Next Mars Rover</div>
#  <div class="article_teaser_body">After a months-long contest among students to name NASA's newest Mars rover, the agency will reveal the winning name — and the winning student — this Thursday. </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="col-md-12">
#  <hr/>
#  <div class="row">
#  <div class="col-md-4">
#  <div class="list_image">
#  <img src="https://mars.nasa.gov/system/news_items/list_view_images/8611_PIA22111-320x240.jpg"/>
#  </div>
#  </div>
#  <div class="col-md-8">
#  <div class="list_text">
#  <div class="list_date">February 15, 2023</div>
#  <div class="content_title">NASA Adds Return Sample Scientists to Mars 2020 Leadership Team</div>
#  <div class="article_teaser_body">The leadership council for Mars 2020 science added two new members who represent the interests of scientists destined to handle and study the first samples from Red Planet.</div>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="col-md-12">
#  <hr/>
#  <div class="row">
#  <div class="col-md-4">
#  <div class="list_image">
#  <img src="https://mars.nasa.gov/system/news_items/list_view_images/8778_3d-320x240.jpg"/>
#  </div>
#  </div>
#  <div class="col-md-8">
#  <div class="list_text">
#  <div class="list_date">February 12, 2023</div>
#  <div class="content_title">NASA's Perseverance Rover Bringing 3D-Printed Metal Parts to Mars</div>
#  <div class="article_teaser_body">For hobbyists and makers, 3D printing expands creative possibilities; for specialized engineers, it's also key to next-generation spacecraft design.</div>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="col-md-12">
#  <hr/>
#  <div class="row">
#  <div class="col-md-4">
#  <div class="list_image">
#  <img src="https://mars.nasa.gov/system/news_items/list_view_images/8641_PIA-23821-320x240.jpg"/>
#  </div>
#  </div>
#  <div class="col-md-8">
#  <div class="list_text">
#  <div class="list_date">February 11, 2023</div>
#  <div class="content_title">NASA's Perseverance Mars Rover Gets Its Wheels and Air Brakes</div>
#  <div class="article_teaser_body">After the rover was shipped from JPL to Kennedy Space Center, the team is getting closer to finalizing the spacecraft for launch later this summer.</div>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="col-md-12">
#  <hr/>
#  <div class="row">
#  <div class="col-md-4">
#  <div class="list_image">
#  <img src="https://mars.nasa.gov/system/news_items/list_view_images/8517_PIA23180-226.gif"/>
#  </div>
#  </div>
#  <div class="col-md-8">
#  <div class="list_text">
#  <div class="list_date">February 9, 2023</div>
#  <div class="content_title">NASA's InSight 'Hears' Peculiar Sounds on Mars</div>
#  <div class="article_teaser_body">Listen to the marsquakes and other, less-expected sounds that the Mars lander has been detecting.</div>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="col-md-12">
#  <hr/>
#  <div class="row">
#  <div class="col-md-4">
#  <div class="list_image">
#  <img src="https://mars.nasa.gov/system/news_items/list_view_images/8645_PIA23824-RoverWithHelicopter-32x24.jpg"/>
#  </div>
#  </div>
#  <div class="col-md-8">
#  <div class="list_text">
#  <div class="list_date">February 5, 2023</div>
#  <div class="content_title">Mars Helicopter Attached to NASA's Perseverance Rover</div>
#  <div class="article_teaser_body">The team also fueled the rover's sky crane to get ready for this summer's history-making launch.</div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  <hr class="container" style="margin: 25px auto;width: 83%;"/>
#  <button class="btn disable" id="more" onclick="populateContent()">More</button>
#  </section>
#  <section class="last_news">
#  <div class="container">
#  <div class="row">
#  <div class="col-12">
#  <h2>You Might Also Like</h2>
#  </div>
#  <!--  <a class=" prev" href="#carouselExampleIndicators2" role="button" data-slide="prev">
#                    <i class="fas fa-angle-left"></i>
#                    </a>
#                    <a class=" next" href="#carouselExampleIndicators2" role="button" data-slide="next">
#                    <i class="fas fa-angle-right"></i>
#                    </a> -->
#  <div class="col-12">
#  <div class="carousel slide" data-ride="carousel" id="carouselExampleIndicators2">
#  <div class="carousel-inner">
#  <div class="carousel-item active">
#  <div class="row">
#  <div class="col-md-4 mb-3">
#  <div class="card">
#  <img alt="100%x280" class="img-fluid" src="https://mars.nasa.gov/system/news_items/main_images/8716_PIA23499-16.jpg"/>
#  <div class="card-body">
#  <p class="card-text">NASA to Broadcast Mars 2020 Perseverance Launch, Prelaunch Activities</p>
#  </div>
#  </div>
#  </div>
#  <div class="col-md-4 mb-3">
#  <div class="card">
#  <img alt="100%x280" class="img-fluid" src="https://mars.nasa.gov/system/news_items/main_images/8716_PIA23499-16.jpg"/>
#  <div class="card-body">
#  <p class="card-text">The Launch Is Approaching for NASA's Next Mars Rover, Perseverance</p>
#  </div>
#  </div>
#  </div>
#  <div class="col-md-4 mb-3">
#  <div class="card">
#  <img alt="100%x280" class="img-fluid" src="https://mars.nasa.gov/system/news_items/main_images/8692_PIA23920-web.jpg"/>
#  <div class="card-body">
#  <p class="card-text">NASA to Hold Mars 2020 Perseverance Rover Launch Briefing</p>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="carousel-item">
#  <div class="row">
#  <div class="col-md-4 mb-3">
#  <div class="card">
#  <img alt="100%x280" class="img-fluid" src="https://images.unsplash.com/photo-1532771098148-525cefe10c23?ixlib=rb-0.3.5&amp;q=80&amp;fm=jpg&amp;crop=entropy&amp;cs=tinysrgb&amp;w=1080&amp;fit=max&amp;ixid=eyJhcHBfaWQiOjMyMDc0fQ&amp;s=3f317c1f7a16116dec454fbc267dd8e4"/>
#  <div class="card-body">
#  <p class="card-text">With supporting text below as a natural lead-in to additional content.</p>
#  </div>
#  </div>
#  </div>
#  <div class="col-md-4 mb-3">
#  <div class="card">
#  <img alt="100%x280" class="img-fluid" src="https://images.unsplash.com/photo-1532715088550-62f09305f765?ixlib=rb-0.3.5&amp;q=80&amp;fm=jpg&amp;crop=entropy&amp;cs=tinysrgb&amp;w=1080&amp;fit=max&amp;ixid=eyJhcHBfaWQiOjMyMDc0fQ&amp;s=ebadb044b374504ef8e81bdec4d0e840"/>
#  <div class="card-body">
#  <p class="card-text">With supporting text below as a natural lead-in to additional content.</p>
#  </div>
#  </div>
#  </div>
#  <div class="col-md-4 mb-3">
#  <div class="card">
#  <img alt="100%x280" class="img-fluid" src="https://images.unsplash.com/photo-1506197603052-3cc9c3a201bd?ixlib=rb-0.3.5&amp;q=80&amp;fm=jpg&amp;crop=entropy&amp;cs=tinysrgb&amp;w=1080&amp;fit=max&amp;ixid=eyJhcHBfaWQiOjMyMDc0fQ&amp;s=0754ab085804ae8a3b562548e6b4aa2e"/>
#  <div class="card-body">
#  <p class="card-text">With supporting text below as a natural lead-in to additional content.</p>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="carousel-item">
#  <div class="row">
#  <div class="col-md-4 mb-3">
#  <div class="card">
#  <img alt="100%x280" class="img-fluid" src="https://images.unsplash.com/photo-1507525428034-b723cf961d3e?ixlib=rb-0.3.5&amp;q=80&amp;fm=jpg&amp;crop=entropy&amp;cs=tinysrgb&amp;w=1080&amp;fit=max&amp;ixid=eyJhcHBfaWQiOjMyMDc0fQ&amp;s=ee8417f0ea2a50d53a12665820b54e23"/>
#  <div class="card-body">
#  <p class="card-text">With supporting text below as a natural lead-in to additional content.</p>
#  </div>
#  </div>
#  </div>
#  <div class="col-md-4 mb-3">
#  <div class="card">
#  <img alt="100%x280" class="img-fluid" src="https://images.unsplash.com/photo-1532777946373-b6783242f211?ixlib=rb-0.3.5&amp;q=80&amp;fm=jpg&amp;crop=entropy&amp;cs=tinysrgb&amp;w=1080&amp;fit=max&amp;ixid=eyJhcHBfaWQiOjMyMDc0fQ&amp;s=8ac55cf3a68785643998730839663129"/>
#  <div class="card-body">
#  <p class="card-text">With supporting text below as a natural lead-in to additional content.</p>
#  </div>
#  </div>
#  </div>
#  <div class="col-md-4 mb-3">
#  <div class="card">
#  <img alt="100%x280" class="img-fluid" src="https://images.unsplash.com/photo-1532763303805-529d595877c5?ixlib=rb-0.3.5&amp;q=80&amp;fm=jpg&amp;crop=entropy&amp;cs=tinysrgb&amp;w=1080&amp;fit=max&amp;ixid=eyJhcHBfaWQiOjMyMDc0fQ&amp;s=5ee4fd5d19b40f93eadb21871757eda6"/>
#  <div class="card-body">
#  <p class="card-text">With supporting text below as a natural lead-in to additional content.</p>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </section>
#  <section class="footer">
#  <div class="container">
#  <div class="col-md-12">
#  <div class="row">
#  <div class="col-md-3">
#  <h5>The Red Planet</h5>
#  <ul>
#  <li>Dashboard</li>
#  <li>Science Goals</li>
#  <li>The Planet</li>
#  </ul>
#  </div>
#  <div class="col-md-3">
#  <h5>The Program</h5>
#  <ul>
#  <li>Mission Statement</li>
#  <li>About the Program</li>
#  <li>Organization Why Mars?</li>
#  </ul>
#  </div>
#  <div class="col-md-3">
#  <h5>Multimedia</h5>
#  <ul>
#  <li>Images</li>
#  <li>Videos</li>
#  <li>More Resources</li>
#  </ul>
#  </div>
#  <div class="col-md-3">
#  <h5>Missions</h5>
#  <ul>
#  <li>Past</li>
#  <li>Present</li>
#  <li>Future</li>
#  </ul>
#  </div>
#  </div>
#  </div>
#  </div>
#  </section>
#  <script src="https://code.jquery.com/jquery-1.12.4.min.js" type="text/javascript"></script>
#  <script src="https://cdn.jsdelivr.net/npm/@popperjs/core@2.5.4/dist/umd/popper.min.js"></script>
#  <script src="https://cdn.jsdelivr.net/npm/bootstrap@5.0.0-beta1/dist/js/bootstrap.min.js"></script>
#  <script src="js/app.js"></script>
#  </div>,
#  <div class="container-fluid">
#  <a class="navbar-brand" href="#">
#  <img src="image/nasa.png" width="80"/><span class="logo">MARS Planet Science</span>
#  <span class="logo1">Exploration Program</span>
#  </a>
#  <button aria-controls="navbarNav" aria-expanded="false" aria-label="Toggle navigation" class="navbar-toggler" data-bs-target="#navbarNav" data-bs-toggle="collapse" type="button">
#  <span class="navbar-toggler-icon"></span>
#  </button>
#  <div class="collapse navbar-collapse justify-content-end" id="navbarNav">
#  <ul class="navbar-nav">
#  <li class="nav-item">
#  <a aria-current="page" class="nav-link active" href="#">The Red Planet</a>
#  </li>
#  <li class="nav-item">
#  <a class="nav-link" href="#">The Program</a>
#  </li>
#  <li class="nav-item">
#  <a class="nav-link" href="#">News &amp; Events</a>
#  </li>
#  <li class="nav-item">
#  <a class="nav-link" href="#">Multimedia</a>
#  </li>
#  <li class="nav-item">
#  <a class="nav-link" href="#">Missions</a>
#  </li>
#  <li class="nav-item">
#  <a class="nav-link" href="#">More</a>
#  </li>
#  <li class="nav-item nav_search">
#  <a class="nav-link" href="#"></a>
#  </li>
#  </ul>
#  </div>
#  </div>,
#  <div class="collapse navbar-collapse justify-content-end" id="navbarNav">
#  <ul class="navbar-nav">
#  <li class="nav-item">
#  <a aria-current="page" class="nav-link active" href="#">The Red Planet</a>
#  </li>
#  <li class="nav-item">
#  <a class="nav-link" href="#">The Program</a>
#  </li>
#  <li class="nav-item">
#  <a class="nav-link" href="#">News &amp; Events</a>
#  </li>
#  <li class="nav-item">
#  <a class="nav-link" href="#">Multimedia</a>
#  </li>
#  <li class="nav-item">
#  <a class="nav-link" href="#">Missions</a>
#  </li>
#  <li class="nav-item">
#  <a class="nav-link" href="#">More</a>
#  </li>
#  <li class="nav-item nav_search">
#  <a class="nav-link" href="#"></a>
#  </li>
#  </ul>
#  </div>,
#  <div class="container">
#  <h1>News</h1>
#  <div class="col-md-12 filter">
#  <div class="row">
#  <div class="col-md-3 search_binder">
#  <input class="search_field" name="search" type="text"/>
#  <input class="search_submit" name="search" type="text"/>
#  </div>
#  <div class="col-md-3">
#  <select aria-label="Default select example" class="form-select" id="year">
#  <option selected="">Latest</option>
#  <option>2020</option><option>2019</option></select>
#  </div>
#  <div class="col-md-3">
#  <select aria-label="Default select example" class="form-select" id="cat">
#  <option selected="">All Categories</option>
#  <option>Press Releases</option><option>Feature Stories</option><option>Status Reports</option></select>
#  </div>
#  <div class="col-md-3">
#  </div>
#  </div>
#  </div>
#  </div>,
#  <div class="col-md-12 filter">
#  <div class="row">
#  <div class="col-md-3 search_binder">
#  <input class="search_field" name="search" type="text"/>
#  <input class="search_submit" name="search" type="text"/>
#  </div>
#  <div class="col-md-3">
#  <select aria-label="Default select example" class="form-select" id="year">
#  <option selected="">Latest</option>
#  <option>2020</option><option>2019</option></select>
#  </div>
#  <div class="col-md-3">
#  <select aria-label="Default select example" class="form-select" id="cat">
#  <option selected="">All Categories</option>
#  <option>Press Releases</option><option>Feature Stories</option><option>Status Reports</option></select>
#  </div>
#  <div class="col-md-3">
#  </div>
#  </div>
#  </div>,
#  <div class="row">
#  <div class="col-md-3 search_binder">
#  <input class="search_field" name="search" type="text"/>
#  <input class="search_submit" name="search" type="text"/>
#  </div>
#  <div class="col-md-3">
#  <select aria-label="Default select example" class="form-select" id="year">
#  <option selected="">Latest</option>
#  <option>2020</option><option>2019</option></select>
#  </div>
#  <div class="col-md-3">
#  <select aria-label="Default select example" class="form-select" id="cat">
#  <option selected="">All Categories</option>
#  <option>Press Releases</option><option>Feature Stories</option><option>Status Reports</option></select>
#  </div>
#  <div class="col-md-3">
#  </div>
#  </div>,
#  <div class="col-md-3 search_binder">
#  <input class="search_field" name="search" type="text"/>
#  <input class="search_submit" name="search" type="text"/>
#  </div>,
#  <div class="col-md-3">
#  <select aria-label="Default select example" class="form-select" id="year">
#  <option selected="">Latest</option>
#  <option>2020</option><option>2019</option></select>
#  </div>,
#  <div class="col-md-3">
#  <select aria-label="Default select example" class="form-select" id="cat">
#  <option selected="">All Categories</option>
#  <option>Press Releases</option><option>Feature Stories</option><option>Status Reports</option></select>
#  </div>,
#  <div class="col-md-3">
#  </div>,
#  <div class="container" id="news">
#  <div class="col-md-12">
#  <hr/>
#  <div class="row">
#  <div class="col-md-4">
#  <div class="list_image">
#  <img src="https://mars.nasa.gov/system/news_items/list_view_images/8659_1-PIA23883-MAIN-320x240.jpg"/>
#  </div>
#  </div>
#  <div class="col-md-8">
#  <div class="list_text">
#  <div class="list_date">March 5, 2023</div>
#  <div class="content_title">Alabama High School Student Names NASA's Mars Helicopter</div>
#  <div class="article_teaser_body">Vaneeza Rupani's essay was chosen as the name for the small spacecraft, which will mark NASA's first attempt at powered flight on another planet.</div>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="col-md-12">
#  <hr/>
#  <div class="row">
#  <div class="col-md-4">
#  <div class="list_image">
#  <img src="https://mars.nasa.gov/system/news_items/list_view_images/8663_PIA23316-annotated-16-320x240.jpg"/>
#  </div>
#  </div>
#  <div class="col-md-8">
#  <div class="list_text">
#  <div class="list_date">March 4, 2023</div>
#  <div class="content_title">NASA's Perseverance Rover Will Look at Mars Through These 'Eyes'</div>
#  <div class="article_teaser_body">A pair of zoomable cameras will help scientists and rover drivers with high-resolution color images.</div>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="col-md-12">
#  <hr/>
#  <div class="row">
#  <div class="col-md-4">
#  <div class="list_image">
#  <img src="https://mars.nasa.gov/system/news_items/list_view_images/8792_parachute-320x240.jpg"/>
#  </div>
#  </div>
#  <div class="col-md-8">
#  <div class="list_text">
#  <div class="list_date">March 1, 2023</div>
#  <div class="content_title">NASA's Perseverance Rover 100 Days Out</div>
#  <div class="article_teaser_body">Mark your calendars: The agency's latest rover has only about 8,640,000 seconds to go before it touches down on the Red Planet, becoming history's next Mars car.</div>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="col-md-12">
#  <hr/>
#  <div class="row">
#  <div class="col-md-4">
#  <div class="list_image">
#  <img src="https://mars.nasa.gov/system/news_items/list_view_images/8607_PIA23591-320x240.jpg"/>
#  </div>
#  </div>
#  <div class="col-md-8">
#  <div class="list_text">
#  <div class="list_date">February 28, 2023</div>
#  <div class="content_title">NASA's Mars 2020 Rover Goes Coast-to-Coast to Prep for Launch</div>
#  <div class="article_teaser_body">The agency's first step in returning rocks from Mars just arrived at Kennedy Space Center. The Mars 2020 team now begins readying for a launch to the Red Planet this July.</div>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="col-md-12">
#  <hr/>
#  <div class="row">
#  <div class="col-md-4">
#  <div class="list_image">
#  <img src="https://mars.nasa.gov/system/news_items/list_view_images/8505_PIA23275-th.jpg"/>
#  </div>
#  </div>
#  <div class="col-md-8">
#  <div class="list_text">
#  <div class="list_date">February 26, 2023</div>
#  <div class="content_title">Scientists Explore Outback as Testbed for Mars </div>
#  <div class="article_teaser_body">Australia provides a great place for NASA's Mars 2020 and the ESA-Roscosmos ExoMars scientists to hone techniques in preparation for searching for signs ancient life on Mars.</div>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="col-md-12">
#  <hr/>
#  <div class="row">
#  <div class="col-md-4">
#  <div class="list_image">
#  <img src="https://mars.nasa.gov/system/news_items/list_view_images/8756_25254_Christina_hernandez_mainmax-320x240.png"/>
#  </div>
#  </div>
#  <div class="col-md-8">
#  <div class="list_text">
#  <div class="list_date">February 24, 2023</div>
#  <div class="content_title">My Culture, My Voice</div>
#  <div class="article_teaser_body">In honor of Hispanic Heritage Month, Christina Hernandez, an instrument engineer on the Mars 2020 mission, talks about her childhood and journey to NASA.</div>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="col-md-12">
#  <hr/>
#  <div class="row">
#  <div class="col-md-4">
#  <div class="list_image">
#  <img src="https://mars.nasa.gov/system/news_items/list_view_images/8726_PIA23898-320.jpg"/>
#  </div>
#  </div>
#  <div class="col-md-8">
#  <div class="list_text">
#  <div class="list_date">February 23, 2023</div>
#  <div class="content_title">8 Martian Postcards to Celebrate Curiosity's Landing Anniversary</div>
#  <div class="article_teaser_body">The NASA rover touched down eight years ago, on Aug. 5, 2012, and will soon be joined by a second rover, Perseverance.</div>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="col-md-12">
#  <hr/>
#  <div class="row">
#  <div class="col-md-4">
#  <div class="list_image">
#  <img src="https://mars.nasa.gov/system/news_items/list_view_images/8609_list_image.jpg"/>
#  </div>
#  </div>
#  <div class="col-md-8">
#  <div class="list_text">
#  <div class="list_date">February 23, 2023</div>
#  <div class="content_title">NASA's Mars Reconnaissance Orbiter Undergoes Memory Update</div>
#  <div class="article_teaser_body">Other orbiters will continue relaying data from Mars surface missions for a two-week period.</div>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="col-md-12">
#  <hr/>
#  <div class="row">
#  <div class="col-md-4">
#  <div class="list_image">
#  <img src="https://mars.nasa.gov/system/news_items/list_view_images/8699_helicopter-delivery-system-320.jpg"/>
#  </div>
#  </div>
#  <div class="col-md-8">
#  <div class="list_text">
#  <div class="list_date">February 20, 2023</div>
#  <div class="content_title">How NASA's Mars Helicopter Will Reach the Red Planet's Surface</div>
#  <div class="article_teaser_body">The small craft will seek to prove that powered, controlled flight is possible on another planet. But just getting it onto the surface of Mars will take a whole lot of ingenuity.</div>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="col-md-12">
#  <hr/>
#  <div class="row">
#  <div class="col-md-4">
#  <div class="list_image">
#  <img src="https://mars.nasa.gov/system/news_items/list_view_images/8619_8588_name20190625-320x240.jpg"/>
#  </div>
#  </div>
#  <div class="col-md-8">
#  <div class="list_text">
#  <div class="list_date">February 20, 2023</div>
#  <div class="content_title">NASA to Reveal Name of Its Next Mars Rover</div>
#  <div class="article_teaser_body">After a months-long contest among students to name NASA's newest Mars rover, the agency will reveal the winning name — and the winning student — this Thursday. </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="col-md-12">
#  <hr/>
#  <div class="row">
#  <div class="col-md-4">
#  <div class="list_image">
#  <img src="https://mars.nasa.gov/system/news_items/list_view_images/8611_PIA22111-320x240.jpg"/>
#  </div>
#  </div>
#  <div class="col-md-8">
#  <div class="list_text">
#  <div class="list_date">February 15, 2023</div>
#  <div class="content_title">NASA Adds Return Sample Scientists to Mars 2020 Leadership Team</div>
#  <div class="article_teaser_body">The leadership council for Mars 2020 science added two new members who represent the interests of scientists destined to handle and study the first samples from Red Planet.</div>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="col-md-12">
#  <hr/>
#  <div class="row">
#  <div class="col-md-4">
#  <div class="list_image">
#  <img src="https://mars.nasa.gov/system/news_items/list_view_images/8778_3d-320x240.jpg"/>
#  </div>
#  </div>
#  <div class="col-md-8">
#  <div class="list_text">
#  <div class="list_date">February 12, 2023</div>
#  <div class="content_title">NASA's Perseverance Rover Bringing 3D-Printed Metal Parts to Mars</div>
#  <div class="article_teaser_body">For hobbyists and makers, 3D printing expands creative possibilities; for specialized engineers, it's also key to next-generation spacecraft design.</div>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="col-md-12">
#  <hr/>
#  <div class="row">
#  <div class="col-md-4">
#  <div class="list_image">
#  <img src="https://mars.nasa.gov/system/news_items/list_view_images/8641_PIA-23821-320x240.jpg"/>
#  </div>
#  </div>
#  <div class="col-md-8">
#  <div class="list_text">
#  <div class="list_date">February 11, 2023</div>
#  <div class="content_title">NASA's Perseverance Mars Rover Gets Its Wheels and Air Brakes</div>
#  <div class="article_teaser_body">After the rover was shipped from JPL to Kennedy Space Center, the team is getting closer to finalizing the spacecraft for launch later this summer.</div>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="col-md-12">
#  <hr/>
#  <div class="row">
#  <div class="col-md-4">
#  <div class="list_image">
#  <img src="https://mars.nasa.gov/system/news_items/list_view_images/8517_PIA23180-226.gif"/>
#  </div>
#  </div>
#  <div class="col-md-8">
#  <div class="list_text">
#  <div class="list_date">February 9, 2023</div>
#  <div class="content_title">NASA's InSight 'Hears' Peculiar Sounds on Mars</div>
#  <div class="article_teaser_body">Listen to the marsquakes and other, less-expected sounds that the Mars lander has been detecting.</div>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="col-md-12">
#  <hr/>
#  <div class="row">
#  <div class="col-md-4">
#  <div class="list_image">
#  <img src="https://mars.nasa.gov/system/news_items/list_view_images/8645_PIA23824-RoverWithHelicopter-32x24.jpg"/>
#  </div>
#  </div>
#  <div class="col-md-8">
#  <div class="list_text">
#  <div class="list_date">February 5, 2023</div>
#  <div class="content_title">Mars Helicopter Attached to NASA's Perseverance Rover</div>
# ...
#  <div class="card-body">
#  <p class="card-text">NASA to Broadcast Mars 2020 Perseverance Launch, Prelaunch Activities</p>
#  </div>
#  </div>,
#  <div class="card-body">
#  <p class="card-text">NASA to Broadcast Mars 2020 Perseverance Launch, Prelaunch Activities</p>
#  </div>,
#  <div class="col-md-4 mb-3">
#  <div class="card">
#  <img alt="100%x280" class="img-fluid" src="https://mars.nasa.gov/system/news_items/main_images/8716_PIA23499-16.jpg"/>
#  <div class="card-body">
#  <p class="card-text">The Launch Is Approaching for NASA's Next Mars Rover, Perseverance</p>
#  </div>
#  </div>
#  </div>,
#  <div class="card">
#  <img alt="100%x280" class="img-fluid" src="https://mars.nasa.gov/system/news_items/main_images/8716_PIA23499-16.jpg"/>
#  <div class="card-body">
#  <p class="card-text">The Launch Is Approaching for NASA's Next Mars Rover, Perseverance</p>
#  </div>
#  </div>,
#  <div class="card-body">
#  <p class="card-text">The Launch Is Approaching for NASA's Next Mars Rover, Perseverance</p>
#  </div>,
#  <div class="col-md-4 mb-3">
#  <div class="card">
#  <img alt="100%x280" class="img-fluid" src="https://mars.nasa.gov/system/news_items/main_images/8692_PIA23920-web.jpg"/>
#  <div class="card-body">
#  <p class="card-text">NASA to Hold Mars 2020 Perseverance Rover Launch Briefing</p>
#  </div>
#  </div>
#  </div>,
#  <div class="card">
#  <img alt="100%x280" class="img-fluid" src="https://mars.nasa.gov/system/news_items/main_images/8692_PIA23920-web.jpg"/>
#  <div class="card-body">
#  <p class="card-text">NASA to Hold Mars 2020 Perseverance Rover Launch Briefing</p>
#  </div>
#  </div>,
#  <div class="card-body">
#  <p class="card-text">NASA to Hold Mars 2020 Perseverance Rover Launch Briefing</p>
#  </div>,
#  <div class="carousel-item">
#  <div class="row">
#  <div class="col-md-4 mb-3">
#  <div class="card">
#  <img alt="100%x280" class="img-fluid" src="https://images.unsplash.com/photo-1532771098148-525cefe10c23?ixlib=rb-0.3.5&amp;q=80&amp;fm=jpg&amp;crop=entropy&amp;cs=tinysrgb&amp;w=1080&amp;fit=max&amp;ixid=eyJhcHBfaWQiOjMyMDc0fQ&amp;s=3f317c1f7a16116dec454fbc267dd8e4"/>
#  <div class="card-body">
#  <p class="card-text">With supporting text below as a natural lead-in to additional content.</p>
#  </div>
#  </div>
#  </div>
#  <div class="col-md-4 mb-3">
#  <div class="card">
#  <img alt="100%x280" class="img-fluid" src="https://images.unsplash.com/photo-1532715088550-62f09305f765?ixlib=rb-0.3.5&amp;q=80&amp;fm=jpg&amp;crop=entropy&amp;cs=tinysrgb&amp;w=1080&amp;fit=max&amp;ixid=eyJhcHBfaWQiOjMyMDc0fQ&amp;s=ebadb044b374504ef8e81bdec4d0e840"/>
#  <div class="card-body">
#  <p class="card-text">With supporting text below as a natural lead-in to additional content.</p>
#  </div>
#  </div>
#  </div>
#  <div class="col-md-4 mb-3">
#  <div class="card">
#  <img alt="100%x280" class="img-fluid" src="https://images.unsplash.com/photo-1506197603052-3cc9c3a201bd?ixlib=rb-0.3.5&amp;q=80&amp;fm=jpg&amp;crop=entropy&amp;cs=tinysrgb&amp;w=1080&amp;fit=max&amp;ixid=eyJhcHBfaWQiOjMyMDc0fQ&amp;s=0754ab085804ae8a3b562548e6b4aa2e"/>
#  <div class="card-body">
#  <p class="card-text">With supporting text below as a natural lead-in to additional content.</p>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>,
#  <div class="row">
#  <div class="col-md-4 mb-3">
#  <div class="card">
#  <img alt="100%x280" class="img-fluid" src="https://images.unsplash.com/photo-1532771098148-525cefe10c23?ixlib=rb-0.3.5&amp;q=80&amp;fm=jpg&amp;crop=entropy&amp;cs=tinysrgb&amp;w=1080&amp;fit=max&amp;ixid=eyJhcHBfaWQiOjMyMDc0fQ&amp;s=3f317c1f7a16116dec454fbc267dd8e4"/>
#  <div class="card-body">
#  <p class="card-text">With supporting text below as a natural lead-in to additional content.</p>
#  </div>
#  </div>
#  </div>
#  <div class="col-md-4 mb-3">
#  <div class="card">
#  <img alt="100%x280" class="img-fluid" src="https://images.unsplash.com/photo-1532715088550-62f09305f765?ixlib=rb-0.3.5&amp;q=80&amp;fm=jpg&amp;crop=entropy&amp;cs=tinysrgb&amp;w=1080&amp;fit=max&amp;ixid=eyJhcHBfaWQiOjMyMDc0fQ&amp;s=ebadb044b374504ef8e81bdec4d0e840"/>
#  <div class="card-body">
#  <p class="card-text">With supporting text below as a natural lead-in to additional content.</p>
#  </div>
#  </div>
#  </div>
#  <div class="col-md-4 mb-3">
#  <div class="card">
#  <img alt="100%x280" class="img-fluid" src="https://images.unsplash.com/photo-1506197603052-3cc9c3a201bd?ixlib=rb-0.3.5&amp;q=80&amp;fm=jpg&amp;crop=entropy&amp;cs=tinysrgb&amp;w=1080&amp;fit=max&amp;ixid=eyJhcHBfaWQiOjMyMDc0fQ&amp;s=0754ab085804ae8a3b562548e6b4aa2e"/>
#  <div class="card-body">
#  <p class="card-text">With supporting text below as a natural lead-in to additional content.</p>
#  </div>
#  </div>
#  </div>
#  </div>,
#  <div class="col-md-4 mb-3">
#  <div class="card">
#  <img alt="100%x280" class="img-fluid" src="https://images.unsplash.com/photo-1532771098148-525cefe10c23?ixlib=rb-0.3.5&amp;q=80&amp;fm=jpg&amp;crop=entropy&amp;cs=tinysrgb&amp;w=1080&amp;fit=max&amp;ixid=eyJhcHBfaWQiOjMyMDc0fQ&amp;s=3f317c1f7a16116dec454fbc267dd8e4"/>
#  <div class="card-body">
#  <p class="card-text">With supporting text below as a natural lead-in to additional content.</p>
#  </div>
#  </div>
#  </div>,
#  <div class="card">
#  <img alt="100%x280" class="img-fluid" src="https://images.unsplash.com/photo-1532771098148-525cefe10c23?ixlib=rb-0.3.5&amp;q=80&amp;fm=jpg&amp;crop=entropy&amp;cs=tinysrgb&amp;w=1080&amp;fit=max&amp;ixid=eyJhcHBfaWQiOjMyMDc0fQ&amp;s=3f317c1f7a16116dec454fbc267dd8e4"/>
#  <div class="card-body">
#  <p class="card-text">With supporting text below as a natural lead-in to additional content.</p>
#  </div>
#  </div>,
#  <div class="card-body">
#  <p class="card-text">With supporting text below as a natural lead-in to additional content.</p>
#  </div>,
#  <div class="col-md-4 mb-3">
#  <div class="card">
#  <img alt="100%x280" class="img-fluid" src="https://images.unsplash.com/photo-1532715088550-62f09305f765?ixlib=rb-0.3.5&amp;q=80&amp;fm=jpg&amp;crop=entropy&amp;cs=tinysrgb&amp;w=1080&amp;fit=max&amp;ixid=eyJhcHBfaWQiOjMyMDc0fQ&amp;s=ebadb044b374504ef8e81bdec4d0e840"/>
#  <div class="card-body">
#  <p class="card-text">With supporting text below as a natural lead-in to additional content.</p>
#  </div>
#  </div>
#  </div>,
#  <div class="card">
#  <img alt="100%x280" class="img-fluid" src="https://images.unsplash.com/photo-1532715088550-62f09305f765?ixlib=rb-0.3.5&amp;q=80&amp;fm=jpg&amp;crop=entropy&amp;cs=tinysrgb&amp;w=1080&amp;fit=max&amp;ixid=eyJhcHBfaWQiOjMyMDc0fQ&amp;s=ebadb044b374504ef8e81bdec4d0e840"/>
#  <div class="card-body">
#  <p class="card-text">With supporting text below as a natural lead-in to additional content.</p>
#  </div>
#  </div>,
#  <div class="card-body">
#  <p class="card-text">With supporting text below as a natural lead-in to additional content.</p>
#  </div>,
#  <div class="col-md-4 mb-3">
#  <div class="card">
#  <img alt="100%x280" class="img-fluid" src="https://images.unsplash.com/photo-1506197603052-3cc9c3a201bd?ixlib=rb-0.3.5&amp;q=80&amp;fm=jpg&amp;crop=entropy&amp;cs=tinysrgb&amp;w=1080&amp;fit=max&amp;ixid=eyJhcHBfaWQiOjMyMDc0fQ&amp;s=0754ab085804ae8a3b562548e6b4aa2e"/>
#  <div class="card-body">
#  <p class="card-text">With supporting text below as a natural lead-in to additional content.</p>
#  </div>
#  </div>
#  </div>,
#  <div class="card">
#  <img alt="100%x280" class="img-fluid" src="https://images.unsplash.com/photo-1506197603052-3cc9c3a201bd?ixlib=rb-0.3.5&amp;q=80&amp;fm=jpg&amp;crop=entropy&amp;cs=tinysrgb&amp;w=1080&amp;fit=max&amp;ixid=eyJhcHBfaWQiOjMyMDc0fQ&amp;s=0754ab085804ae8a3b562548e6b4aa2e"/>
#  <div class="card-body">
#  <p class="card-text">With supporting text below as a natural lead-in to additional content.</p>
#  </div>
#  </div>,
#  <div class="card-body">
#  <p class="card-text">With supporting text below as a natural lead-in to additional content.</p>
#  </div>,
#  <div class="carousel-item">
#  <div class="row">
#  <div class="col-md-4 mb-3">
#  <div class="card">
#  <img alt="100%x280" class="img-fluid" src="https://images.unsplash.com/photo-1507525428034-b723cf961d3e?ixlib=rb-0.3.5&amp;q=80&amp;fm=jpg&amp;crop=entropy&amp;cs=tinysrgb&amp;w=1080&amp;fit=max&amp;ixid=eyJhcHBfaWQiOjMyMDc0fQ&amp;s=ee8417f0ea2a50d53a12665820b54e23"/>
#  <div class="card-body">
#  <p class="card-text">With supporting text below as a natural lead-in to additional content.</p>
#  </div>
#  </div>
#  </div>
#  <div class="col-md-4 mb-3">
#  <div class="card">
#  <img alt="100%x280" class="img-fluid" src="https://images.unsplash.com/photo-1532777946373-b6783242f211?ixlib=rb-0.3.5&amp;q=80&amp;fm=jpg&amp;crop=entropy&amp;cs=tinysrgb&amp;w=1080&amp;fit=max&amp;ixid=eyJhcHBfaWQiOjMyMDc0fQ&amp;s=8ac55cf3a68785643998730839663129"/>
#  <div class="card-body">
#  <p class="card-text">With supporting text below as a natural lead-in to additional content.</p>
#  </div>
#  </div>
#  </div>
#  <div class="col-md-4 mb-3">
#  <div class="card">
#  <img alt="100%x280" class="img-fluid" src="https://images.unsplash.com/photo-1532763303805-529d595877c5?ixlib=rb-0.3.5&amp;q=80&amp;fm=jpg&amp;crop=entropy&amp;cs=tinysrgb&amp;w=1080&amp;fit=max&amp;ixid=eyJhcHBfaWQiOjMyMDc0fQ&amp;s=5ee4fd5d19b40f93eadb21871757eda6"/>
#  <div class="card-body">
#  <p class="card-text">With supporting text below as a natural lead-in to additional content.</p>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>,
#  <div class="row">
#  <div class="col-md-4 mb-3">
#  <div class="card">
#  <img alt="100%x280" class="img-fluid" src="https://images.unsplash.com/photo-1507525428034-b723cf961d3e?ixlib=rb-0.3.5&amp;q=80&amp;fm=jpg&amp;crop=entropy&amp;cs=tinysrgb&amp;w=1080&amp;fit=max&amp;ixid=eyJhcHBfaWQiOjMyMDc0fQ&amp;s=ee8417f0ea2a50d53a12665820b54e23"/>
#  <div class="card-body">
#  <p class="card-text">With supporting text below as a natural lead-in to additional content.</p>
#  </div>
#  </div>
#  </div>
#  <div class="col-md-4 mb-3">
#  <div class="card">
#  <img alt="100%x280" class="img-fluid" src="https://images.unsplash.com/photo-1532777946373-b6783242f211?ixlib=rb-0.3.5&amp;q=80&amp;fm=jpg&amp;crop=entropy&amp;cs=tinysrgb&amp;w=1080&amp;fit=max&amp;ixid=eyJhcHBfaWQiOjMyMDc0fQ&amp;s=8ac55cf3a68785643998730839663129"/>
#  <div class="card-body">
#  <p class="card-text">With supporting text below as a natural lead-in to additional content.</p>
#  </div>
#  </div>
#  </div>
#  <div class="col-md-4 mb-3">
#  <div class="card">
#  <img alt="100%x280" class="img-fluid" src="https://images.unsplash.com/photo-1532763303805-529d595877c5?ixlib=rb-0.3.5&amp;q=80&amp;fm=jpg&amp;crop=entropy&amp;cs=tinysrgb&amp;w=1080&amp;fit=max&amp;ixid=eyJhcHBfaWQiOjMyMDc0fQ&amp;s=5ee4fd5d19b40f93eadb21871757eda6"/>
#  <div class="card-body">
#  <p class="card-text">With supporting text below as a natural lead-in to additional content.</p>
#  </div>
#  </div>
#  </div>
#  </div>,
#  <div class="col-md-4 mb-3">
#  <div class="card">
#  <img alt="100%x280" class="img-fluid" src="https://images.unsplash.com/photo-1507525428034-b723cf961d3e?ixlib=rb-0.3.5&amp;q=80&amp;fm=jpg&amp;crop=entropy&amp;cs=tinysrgb&amp;w=1080&amp;fit=max&amp;ixid=eyJhcHBfaWQiOjMyMDc0fQ&amp;s=ee8417f0ea2a50d53a12665820b54e23"/>
#  <div class="card-body">
#  <p class="card-text">With supporting text below as a natural lead-in to additional content.</p>
#  </div>
#  </div>
#  </div>,
#  <div class="card">
#  <img alt="100%x280" class="img-fluid" src="https://images.unsplash.com/photo-1507525428034-b723cf961d3e?ixlib=rb-0.3.5&amp;q=80&amp;fm=jpg&amp;crop=entropy&amp;cs=tinysrgb&amp;w=1080&amp;fit=max&amp;ixid=eyJhcHBfaWQiOjMyMDc0fQ&amp;s=ee8417f0ea2a50d53a12665820b54e23"/>
#  <div class="card-body">
#  <p class="card-text">With supporting text below as a natural lead-in to additional content.</p>
#  </div>
#  </div>,
#  <div class="card-body">
#  <p class="card-text">With supporting text below as a natural lead-in to additional content.</p>
#  </div>,
#  <div class="col-md-4 mb-3">
#  <div class="card">
#  <img alt="100%x280" class="img-fluid" src="https://images.unsplash.com/photo-1532777946373-b6783242f211?ixlib=rb-0.3.5&amp;q=80&amp;fm=jpg&amp;crop=entropy&amp;cs=tinysrgb&amp;w=1080&amp;fit=max&amp;ixid=eyJhcHBfaWQiOjMyMDc0fQ&amp;s=8ac55cf3a68785643998730839663129"/>
#  <div class="card-body">
#  <p class="card-text">With supporting text below as a natural lead-in to additional content.</p>
#  </div>
#  </div>
#  </div>,
#  <div class="card">
#  <img alt="100%x280" class="img-fluid" src="https://images.unsplash.com/photo-1532777946373-b6783242f211?ixlib=rb-0.3.5&amp;q=80&amp;fm=jpg&amp;crop=entropy&amp;cs=tinysrgb&amp;w=1080&amp;fit=max&amp;ixid=eyJhcHBfaWQiOjMyMDc0fQ&amp;s=8ac55cf3a68785643998730839663129"/>
#  <div class="card-body">
#  <p class="card-text">With supporting text below as a natural lead-in to additional content.</p>
#  </div>
#  </div>,
#  <div class="card-body">
#  <p class="card-text">With supporting text below as a natural lead-in to additional content.</p>
#  </div>,
#  <div class="col-md-4 mb-3">
#  <div class="card">
#  <img alt="100%x280" class="img-fluid" src="https://images.unsplash.com/photo-1532763303805-529d595877c5?ixlib=rb-0.3.5&amp;q=80&amp;fm=jpg&amp;crop=entropy&amp;cs=tinysrgb&amp;w=1080&amp;fit=max&amp;ixid=eyJhcHBfaWQiOjMyMDc0fQ&amp;s=5ee4fd5d19b40f93eadb21871757eda6"/>
#  <div class="card-body">
#  <p class="card-text">With supporting text below as a natural lead-in to additional content.</p>
#  </div>
#  </div>
#  </div>,
#  <div class="card">
#  <img alt="100%x280" class="img-fluid" src="https://images.unsplash.com/photo-1532763303805-529d595877c5?ixlib=rb-0.3.5&amp;q=80&amp;fm=jpg&amp;crop=entropy&amp;cs=tinysrgb&amp;w=1080&amp;fit=max&amp;ixid=eyJhcHBfaWQiOjMyMDc0fQ&amp;s=5ee4fd5d19b40f93eadb21871757eda6"/>
#  <div class="card-body">
#  <p class="card-text">With supporting text below as a natural lead-in to additional content.</p>
#  </div>
#  </div>,
#  <div class="card-body">
#  <p class="card-text">With supporting text below as a natural lead-in to additional content.</p>
#  </div>,
#  <div class="container">
#  <div class="col-md-12">
#  <div class="row">
#  <div class="col-md-3">
#  <h5>The Red Planet</h5>
#  <ul>
#  <li>Dashboard</li>
#  <li>Science Goals</li>
#  <li>The Planet</li>
#  </ul>
#  </div>
#  <div class="col-md-3">
#  <h5>The Program</h5>
#  <ul>
#  <li>Mission Statement</li>
#  <li>About the Program</li>
#  <li>Organization Why Mars?</li>
#  </ul>
#  </div>
#  <div class="col-md-3">
#  <h5>Multimedia</h5>
#  <ul>
#  <li>Images</li>
#  <li>Videos</li>
#  <li>More Resources</li>
#  </ul>
#  </div>
#  <div class="col-md-3">
#  <h5>Missions</h5>
#  <ul>
#  <li>Past</li>
#  <li>Present</li>
#  <li>Future</li>
#  </ul>
#  </div>
#  </div>
#  </div>
#  </div>,
#  <div class="col-md-12">
#  <div class="row">
#  <div class="col-md-3">
#  <h5>The Red Planet</h5>
#  <ul>
#  <li>Dashboard</li>
#  <li>Science Goals</li>
#  <li>The Planet</li>
#  </ul>
#  </div>
#  <div class="col-md-3">
#  <h5>The Program</h5>
#  <ul>
#  <li>Mission Statement</li>
#  <li>About the Program</li>
#  <li>Organization Why Mars?</li>
#  </ul>
#  </div>
#  <div class="col-md-3">
#  <h5>Multimedia</h5>
#  <ul>
#  <li>Images</li>
#  <li>Videos</li>
#  <li>More Resources</li>
#  </ul>
#  </div>
#  <div class="col-md-3">
#  <h5>Missions</h5>
#  <ul>
#  <li>Past</li>
#  <li>Present</li>
#  <li>Future</li>
#  </ul>
#  </div>
#  </div>
#  </div>,
#  <div class="row">
#  <div class="col-md-3">
#  <h5>The Red Planet</h5>
#  <ul>
#  <li>Dashboard</li>
#  <li>Science Goals</li>
#  <li>The Planet</li>
#  </ul>
#  </div>
#  <div class="col-md-3">
#  <h5>The Program</h5>
#  <ul>
#  <li>Mission Statement</li>
#  <li>About the Program</li>
#  <li>Organization Why Mars?</li>
#  </ul>
#  </div>
#  <div class="col-md-3">
#  <h5>Multimedia</h5>
#  <ul>
#  <li>Images</li>
#  <li>Videos</li>
#  <li>More Resources</li>
#  </ul>
#  </div>
#  <div class="col-md-3">
#  <h5>Missions</h5>
#  <ul>
#  <li>Past</li>
#  <li>Present</li>
#  <li>Future</li>
#  </ul>
#  </div>
#  </div>,
#  <div class="col-md-3">
#  <h5>The Red Planet</h5>
#  <ul>
#  <li>Dashboard</li>
#  <li>Science Goals</li>
#  <li>The Planet</li>
#  </ul>
#  </div>,
#  <div class="col-md-3">
#  <h5>The Program</h5>
#  <ul>
#  <li>Mission Statement</li>
#  <li>About the Program</li>
#  <li>Organization Why Mars?</li>
#  </ul>
#  </div>,
#  <div class="col-md-3">
#  <h5>Multimedia</h5>
#  <ul>
#  <li>Images</li>
#  <li>Videos</li>
#  <li>More Resources</li>
#  </ul>
#  </div>,
#  <div class="col-md-3">
#  <h5>Missions</h5>
#  <ul>
#  <li>Past</li>
#  <li>Present</li>
#  <li>Future</li>
#  </ul>
#  </div>]

# %%
title_elem = html_soup.find('div', class_='content_title').text
print(title_elem)
# Out:
# Alabama High School Student Names NASA's Mars Helicopter

# %%
title = title_elem
print(title)
# Out:
# Alabama High School Student Names NASA's Mars Helicopter

# %%
preview = html_soup.find_all('div', class_='article_teaser_body')
preview
# Out:
# [<div class="article_teaser_body">Vaneeza Rupani's essay was chosen as the name for the small spacecraft, which will mark NASA's first attempt at powered flight on another planet.</div>,
#  <div class="article_teaser_body">A pair of zoomable cameras will help scientists and rover drivers with high-resolution color images.</div>,
#  <div class="article_teaser_body">Mark your calendars: The agency's latest rover has only about 8,640,000 seconds to go before it touches down on the Red Planet, becoming history's next Mars car.</div>,
#  <div class="article_teaser_body">The agency's first step in returning rocks from Mars just arrived at Kennedy Space Center. The Mars 2020 team now begins readying for a launch to the Red Planet this July.</div>,
#  <div class="article_teaser_body">Australia provides a great place for NASA's Mars 2020 and the ESA-Roscosmos ExoMars scientists to hone techniques in preparation for searching for signs ancient life on Mars.</div>,
#  <div class="article_teaser_body">In honor of Hispanic Heritage Month, Christina Hernandez, an instrument engineer on the Mars 2020 mission, talks about her childhood and journey to NASA.</div>,
#  <div class="article_teaser_body">The NASA rover touched down eight years ago, on Aug. 5, 2012, and will soon be joined by a second rover, Perseverance.</div>,
#  <div class="article_teaser_body">Other orbiters will continue relaying data from Mars surface missions for a two-week period.</div>,
#  <div class="article_teaser_body">The small craft will seek to prove that powered, controlled flight is possible on another planet. But just getting it onto the surface of Mars will take a whole lot of ingenuity.</div>,
#  <div class="article_teaser_body">After a months-long contest among students to name NASA's newest Mars rover, the agency will reveal the winning name — and the winning student — this Thursday. </div>,
#  <div class="article_teaser_body">The leadership council for Mars 2020 science added two new members who represent the interests of scientists destined to handle and study the first samples from Red Planet.</div>,
#  <div class="article_teaser_body">For hobbyists and makers, 3D printing expands creative possibilities; for specialized engineers, it's also key to next-generation spacecraft design.</div>,
#  <div class="article_teaser_body">After the rover was shipped from JPL to Kennedy Space Center, the team is getting closer to finalizing the spacecraft for launch later this summer.</div>,
#  <div class="article_teaser_body">Listen to the marsquakes and other, less-expected sounds that the Mars lander has been detecting.</div>,
#  <div class="article_teaser_body">The team also fueled the rover's sky crane to get ready for this summer's history-making launch.</div>]

# %%
# Create an empty list to store the dictionaries
articles = []

# %%
# Loop through the text elements
article= html_soup.find_all('div')
for article in articles:
    
# Extract the title and preview text from the elements
    title =  html_soup.find_all('div', class_='content_title')
    preview = slide_elem.find_all('div', class_='article_teaser_body')
        
# Store each title and preview pair in a dictionary
    article_dict={}
    article_dict = {'title': title, 'preview': preview}

# Add the dictionary to the list
    articles.append(article_dict)

# %%
print(title)
# Out:
# Alabama High School Student Names NASA's Mars Helicopter

# %%
print(preview)
# Out:
# [<div class="article_teaser_body">Vaneeza Rupani's essay was chosen as the name for the small spacecraft, which will mark NASA's first attempt at powered flight on another planet.</div>, <div class="article_teaser_body">A pair of zoomable cameras will help scientists and rover drivers with high-resolution color images.</div>, <div class="article_teaser_body">Mark your calendars: The agency's latest rover has only about 8,640,000 seconds to go before it touches down on the Red Planet, becoming history's next Mars car.</div>, <div class="article_teaser_body">The agency's first step in returning rocks from Mars just arrived at Kennedy Space Center. The Mars 2020 team now begins readying for a launch to the Red Planet this July.</div>, <div class="article_teaser_body">Australia provides a great place for NASA's Mars 2020 and the ESA-Roscosmos ExoMars scientists to hone techniques in preparation for searching for signs ancient life on Mars.</div>, <div class="article_teaser_body">In honor of Hispanic Heritage Month, Christina Hernandez, an instrument engineer on the Mars 2020 mission, talks about her childhood and journey to NASA.</div>, <div class="article_teaser_body">The NASA rover touched down eight years ago, on Aug. 5, 2012, and will soon be joined by a second rover, Perseverance.</div>, <div class="article_teaser_body">Other orbiters will continue relaying data from Mars surface missions for a two-week period.</div>, <div class="article_teaser_body">The small craft will seek to prove that powered, controlled flight is possible on another planet. But just getting it onto the surface of Mars will take a whole lot of ingenuity.</div>, <div class="article_teaser_body">After a months-long contest among students to name NASA's newest Mars rover, the agency will reveal the winning name — and the winning student — this Thursday. </div>, <div class="article_teaser_body">The leadership council for Mars 2020 science added two new members who represent the interests of scientists destined to handle and study the first samples from Red Planet.</div>, <div class="article_teaser_body">For hobbyists and makers, 3D printing expands creative possibilities; for specialized engineers, it's also key to next-generation spacecraft design.</div>, <div class="article_teaser_body">After the rover was shipped from JPL to Kennedy Space Center, the team is getting closer to finalizing the spacecraft for launch later this summer.</div>, <div class="article_teaser_body">Listen to the marsquakes and other, less-expected sounds that the Mars lander has been detecting.</div>, <div class="article_teaser_body">The team also fueled the rover's sky crane to get ready for this summer's history-making launch.</div>]

# %%
article_dict ={}
article_dict['title'] = title
article_dict['preview'] = preview
print(article_dict)
# Out:
# {'title': "Alabama High School Student Names NASA's Mars Helicopter", 'preview': [<div class="article_teaser_body">Vaneeza Rupani's essay was chosen as the name for the small spacecraft, which will mark NASA's first attempt at powered flight on another planet.</div>, <div class="article_teaser_body">A pair of zoomable cameras will help scientists and rover drivers with high-resolution color images.</div>, <div class="article_teaser_body">Mark your calendars: The agency's latest rover has only about 8,640,000 seconds to go before it touches down on the Red Planet, becoming history's next Mars car.</div>, <div class="article_teaser_body">The agency's first step in returning rocks from Mars just arrived at Kennedy Space Center. The Mars 2020 team now begins readying for a launch to the Red Planet this July.</div>, <div class="article_teaser_body">Australia provides a great place for NASA's Mars 2020 and the ESA-Roscosmos ExoMars scientists to hone techniques in preparation for searching for signs ancient life on Mars.</div>, <div class="article_teaser_body">In honor of Hispanic Heritage Month, Christina Hernandez, an instrument engineer on the Mars 2020 mission, talks about her childhood and journey to NASA.</div>, <div class="article_teaser_body">The NASA rover touched down eight years ago, on Aug. 5, 2012, and will soon be joined by a second rover, Perseverance.</div>, <div class="article_teaser_body">Other orbiters will continue relaying data from Mars surface missions for a two-week period.</div>, <div class="article_teaser_body">The small craft will seek to prove that powered, controlled flight is possible on another planet. But just getting it onto the surface of Mars will take a whole lot of ingenuity.</div>, <div class="article_teaser_body">After a months-long contest among students to name NASA's newest Mars rover, the agency will reveal the winning name — and the winning student — this Thursday. </div>, <div class="article_teaser_body">The leadership council for Mars 2020 science added two new members who represent the interests of scientists destined to handle and study the first samples from Red Planet.</div>, <div class="article_teaser_body">For hobbyists and makers, 3D printing expands creative possibilities; for specialized engineers, it's also key to next-generation spacecraft design.</div>, <div class="article_teaser_body">After the rover was shipped from JPL to Kennedy Space Center, the team is getting closer to finalizing the spacecraft for launch later this summer.</div>, <div class="article_teaser_body">Listen to the marsquakes and other, less-expected sounds that the Mars lander has been detecting.</div>, <div class="article_teaser_body">The team also fueled the rover's sky crane to get ready for this summer's history-making launch.</div>]}

# %%
articles.append(article_dict)

# %%
# Print the list to confirm success
# Print the list of article dictionaries
print(articles)
# Out:
# [{'title': "Alabama High School Student Names NASA's Mars Helicopter", 'preview': [<div class="article_teaser_body">Vaneeza Rupani's essay was chosen as the name for the small spacecraft, which will mark NASA's first attempt at powered flight on another planet.</div>, <div class="article_teaser_body">A pair of zoomable cameras will help scientists and rover drivers with high-resolution color images.</div>, <div class="article_teaser_body">Mark your calendars: The agency's latest rover has only about 8,640,000 seconds to go before it touches down on the Red Planet, becoming history's next Mars car.</div>, <div class="article_teaser_body">The agency's first step in returning rocks from Mars just arrived at Kennedy Space Center. The Mars 2020 team now begins readying for a launch to the Red Planet this July.</div>, <div class="article_teaser_body">Australia provides a great place for NASA's Mars 2020 and the ESA-Roscosmos ExoMars scientists to hone techniques in preparation for searching for signs ancient life on Mars.</div>, <div class="article_teaser_body">In honor of Hispanic Heritage Month, Christina Hernandez, an instrument engineer on the Mars 2020 mission, talks about her childhood and journey to NASA.</div>, <div class="article_teaser_body">The NASA rover touched down eight years ago, on Aug. 5, 2012, and will soon be joined by a second rover, Perseverance.</div>, <div class="article_teaser_body">Other orbiters will continue relaying data from Mars surface missions for a two-week period.</div>, <div class="article_teaser_body">The small craft will seek to prove that powered, controlled flight is possible on another planet. But just getting it onto the surface of Mars will take a whole lot of ingenuity.</div>, <div class="article_teaser_body">After a months-long contest among students to name NASA's newest Mars rover, the agency will reveal the winning name — and the winning student — this Thursday. </div>, <div class="article_teaser_body">The leadership council for Mars 2020 science added two new members who represent the interests of scientists destined to handle and study the first samples from Red Planet.</div>, <div class="article_teaser_body">For hobbyists and makers, 3D printing expands creative possibilities; for specialized engineers, it's also key to next-generation spacecraft design.</div>, <div class="article_teaser_body">After the rover was shipped from JPL to Kennedy Space Center, the team is getting closer to finalizing the spacecraft for launch later this summer.</div>, <div class="article_teaser_body">Listen to the marsquakes and other, less-expected sounds that the Mars lander has been detecting.</div>, <div class="article_teaser_body">The team also fueled the rover's sky crane to get ready for this summer's history-making launch.</div>]}]

# %%
# browser.quit()

# %% [markdown]
# ### (Optional) Step 4: Export the Data
#
# Optionally, store the scraped data in a file or database (to ease sharing the data with others). To do so, export the scraped data to either a JSON file or a MongoDB database.

# %%
# Export data to JSON

# %%
# Export data to MongoDB
