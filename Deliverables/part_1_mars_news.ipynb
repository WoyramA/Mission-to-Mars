# %% [markdown]
# # Module 12 Challenge
# ## Deliverable 1: Scrape Titles and Preview Text from Mars News

# %%
# Import Splinter and BeautifulSoup
from splinter import Browser
from bs4 import BeautifulSoup as soup
from webdriver_manager.chrome import ChromeDriverManager

# %%
executable_path = {'executable_path': ChromeDriverManager().install()}
browser = Browser('chrome', **executable_path, headless=False)
# Out:
# [WDM] - Downloading: 100%|████████████████████████████████████████████████████████| 6.78M/6.78M [00:00<00:00, 8.51MB/s]

# %% [markdown]
# ### Step 1: Visit the Website
#
# 1. Use automated browsing to visit the [Mars NASA news site](https://redplanetscience.com). Inspect the page to identify which elements to scrape.
#
#       > **Hint** To identify which elements to scrape, you might want to inspect the page by using Chrome DevTools.

# %%
# Visit the Mars NASA news site: https://redplanetscience.com
url = 'https://redplanetscience.com'
browser.visit(url)

# %% [markdown]
# ### Step 2: Scrape the Website
#
# Create a Beautiful Soup object and use it to extract text elements from the website.

# %%
# Create a Beautiful Soup object
# Set up HTML parser
html = browser.html
html_soup = soup(html, 'html.parser')

# %%
# Extract all the text elements
for text in html_soup.find_all(text=True):
    print(text)
# Out:
# News - Mars Exploration Program
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# MARS Planet Science
#
#
# Exploration Program
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# The Red Planet
#
#
#
#
#
#
# The Program
#
#
#
#
#
#
# News & Events
#
#
#
#
#
#
# Multimedia
#
#
#
#
#
#
# Missions
#
#
#
#
#
#
# More
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# News
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Latest
#
#
# 2020
# 2019
#
#
#
#
#
#
#
#
# All Categories
#
#
# Feature Stories
# Press Releases
# Status Reports
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# March 7, 2023
#
#
# NASA's Curiosity Takes Selfie With 'Mary Anning' on the Red Planet
#
#
# The Mars rover has drilled three samples of rock in this clay-enriched region since arriving in July.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# March 6, 2023
#
#
# Mars Scientists Investigate Ancient Life in Australia
#
#
# ...

# %% [markdown]
# ### Step 3: Store the Results
#
# Extract the titles and preview text of the news articles that you scraped. Store the scraping results in Python data structures as follows:
#
# * Store each title-and-preview pair in a Python dictionary. And, give each dictionary two keys: `title` and `preview`. An example is the following:
#
#   ```python
#   {'title': "Mars Rover Begins Mission!",
#         'preview': "NASA's Mars Rover begins a multiyear mission to collect data about the little-explored planet."}
#   ```
#
# * Store all the dictionaries in a Python list.
#
# * Print the list in your notebook.

# %%
div = html_soup.find_all("div")
print(div)
# Out:
# [<div class="col-md-12">
# <div class="row">
# <nav class="navbar navbar-expand-lg navbar-light fixed-top">
# <div class="container-fluid">
# <a class="navbar-brand" href="#">
# <img src="image/nasa.png" width="80"/><span class="logo">MARS Planet Science</span>
# <span class="logo1">Exploration Program</span>
# </a>
# <button aria-controls="navbarNav" aria-expanded="false" aria-label="Toggle navigation" class="navbar-toggler" data-bs-target="#navbarNav" data-bs-toggle="collapse" type="button">
# <span class="navbar-toggler-icon"></span>
# </button>
# <div class="collapse navbar-collapse justify-content-end" id="navbarNav">
# <ul class="navbar-nav">
# <li class="nav-item">
# <a aria-current="page" class="nav-link active" href="#">The Red Planet</a>
# </li>
# <li class="nav-item">
# <a class="nav-link" href="#">The Program</a>
# </li>
# <li class="nav-item">
# <a class="nav-link" href="#">News &amp; Events</a>
# </li>
# <li class="nav-item">
# ...

# %%
#slide_elem = html_soup.find_all('div')
#slide_elem

# %%
#title_elem = html_soup.find('div', class_='content_title').text
#print(title_elem)

# %%
#Title = title_elem
#print(Title)

# %%
title= [tag.text for tag in html_soup.find_all('div', class_='content_title')]
title
# Out:
# ["NASA's Curiosity Takes Selfie With 'Mary Anning' on the Red Planet",
#  'Mars Scientists Investigate Ancient Life in Australia',
#  "NASA's Perseverance Rover Mission Getting in Shape for Launch",
#  "NASA's Mars Perseverance Rover Gets Its Sample Handling System",
#  "10.9 Million Names Now Aboard NASA's Perseverance Mars Rover",
#  "NASA's Mars Perseverance Rover Passes Flight Readiness Review",
#  'Scientists Explore Outback as Testbed for Mars ',
#  'NASA Adds Return Sample Scientists to Mars 2020 Leadership Team',
#  "NASA's Curiosity Mars Rover Takes a New Selfie Before Record Climb",
#  "NASA's MAVEN Maps Winds in the Martian Upper Atmosphere that Mirror the Terrain Below and Gives Clues to Martian Climate",
#  'NASA Updates Mars 2020 Mission Environmental Review',
#  "HiRISE Views NASA's InSight and Curiosity on Mars",
#  "Deadline Closing for Names to Fly on NASA's Next Mars Rover",
#  "NASA's Treasure Map for Water Ice on Mars",
#  "NASA's Mars 2020 Comes Full Circle"]

# %%
preview = [tag.text for tag in html_soup.find_all('div', class_='article_teaser_body')]
#preview = html_soup.find_all('div', class_='article_teaser_body')
preview
# Out:
# ['The Mars rover has drilled three samples of rock in this clay-enriched region since arriving in July.',
#  "Teams with NASA's Mars 2020 and ESA's ExoMars practiced hunting for fossilized microbial life in the Australian Outback in preparation for their Red Planet missions. ",
#  'Stacking spacecraft components on top of each other is one of the final assembly steps before a mission launches to the Red Planet. ',
#  'The system will be collecting and storing Martian rock and soil. Its installation marks another milestone in the march toward the July launch period.',
#  "As part of NASA's 'Send Your Name to Mars' campaign, they've been stenciled onto three microchips along with essays from NASA's 'Name the Rover' contest. Next stop: Mars.",
#  "\u200bThe agency's Mars 2020 mission has one more big prelaunch review – the Launch Readiness Review, on July 27.",
# ...

# %%
# Create an empty list to store the dictionaries
articles = []

# %%
# Loop through the text elements
article= html_soup.find_all('div')
for article in articles:
    
# Extract the title and preview text from the elements
    #title =  html_soup.find_all('div', class_='content_title')
    #preview = slide_elem.find_all('div', class_='article_teaser_body')
    title= [tag.text for tag in html_soup.find_all('div', class_='content_title')]
    preview = [tag.text for tag in html_soup.find_all('div', class_='article_teaser_body')]
       
#Store each title and preview pair in a dictionary
    article_dict={}
    article_dict['title'] = title
    article_dict['preview'] = preview
    #article_dict = {'title': title, 'preview': preview}
    
#Add the dictionary to the list
    articles.append(article_dict)

# %%
print(title)
# Out:
# ["NASA's Curiosity Takes Selfie With 'Mary Anning' on the Red Planet", 'Mars Scientists Investigate Ancient Life in Australia', "NASA's Perseverance Rover Mission Getting in Shape for Launch", "NASA's Mars Perseverance Rover Gets Its Sample Handling System", "10.9 Million Names Now Aboard NASA's Perseverance Mars Rover", "NASA's Mars Perseverance Rover Passes Flight Readiness Review", 'Scientists Explore Outback as Testbed for Mars ', 'NASA Adds Return Sample Scientists to Mars 2020 Leadership Team', "NASA's Curiosity Mars Rover Takes a New Selfie Before Record Climb", "NASA's MAVEN Maps Winds in the Martian Upper Atmosphere that Mirror the Terrain Below and Gives Clues to Martian Climate", 'NASA Updates Mars 2020 Mission Environmental Review', "HiRISE Views NASA's InSight and Curiosity on Mars", "Deadline Closing for Names to Fly on NASA's Next Mars Rover", "NASA's Treasure Map for Water Ice on Mars", "NASA's Mars 2020 Comes Full Circle"]

# %%
print(preview)
# Out:
# ['The Mars rover has drilled three samples of rock in this clay-enriched region since arriving in July.', "Teams with NASA's Mars 2020 and ESA's ExoMars practiced hunting for fossilized microbial life in the Australian Outback in preparation for their Red Planet missions. ", 'Stacking spacecraft components on top of each other is one of the final assembly steps before a mission launches to the Red Planet. ', 'The system will be collecting and storing Martian rock and soil. Its installation marks another milestone in the march toward the July launch period.', "As part of NASA's 'Send Your Name to Mars' campaign, they've been stenciled onto three microchips along with essays from NASA's 'Name the Rover' contest. Next stop: Mars.", "\u200bThe agency's Mars 2020 mission has one more big prelaunch review – the Launch Readiness Review, on July 27.", "Australia provides a great place for NASA's Mars 2020 and the ESA-Roscosmos ExoMars scientists to hone techniques in preparation for searchin
# ...

# %%
# print(f'{"title":title, "preview":preview})

# %%
# article_dict ={}
# article_dict['title'] = title
# article_dict['preview'] = preview
# print(article_dict)

# %%
#articles.append(article_dict)

# %%
# Print the list to confirm success
# Print the list of article dictionaries
print(articles)
# Out:
# []

# %%
# browser.quit()

# %% [markdown]
# ### (Optional) Step 4: Export the Data
#
# Optionally, store the scraped data in a file or database (to ease sharing the data with others). To do so, export the scraped data to either a JSON file or a MongoDB database.

# %%
# Export data to JSON

# %%
# Export data to MongoDB
